# %% [markdown]
# 加载所有数据集，和LSTM提取特征数据集

# %%
import time
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %%
def reduce_mem_usage(data, verbose = True):
    start_mem = data.memory_usage().sum() / 1024**2
    if verbose:
        print('Memory usage of dataframe: {:.2f} MB'.format(start_mem))
    
    for col in data.columns:
        col_type = data[col].dtype
        
        if col_type != object:
            c_min = data[col].min()
            c_max = data[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    data[col] = data[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    data[col] = data[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    data[col] = data[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    data[col] = data[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    data[col] = data[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    data[col] = data[col].astype(np.float32)
                else:
                    data[col] = data[col].astype(np.float64)

    end_mem = data.memory_usage().sum() / 1024**2
    if verbose:
        print('Memory usage after optimization: {:.2f} MB'.format(end_mem))
        print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return data

# %%
all_data = pd.read_csv("C:/data/processing_data/all_data.csv")
all_data = reduce_mem_usage(all_data)


# lstm = pd.read_csv("C:/data/processing_data/LSTM_Feature.csv")
# lstm = reduce_mem_usage(lstm)
# Out:
# Memory usage of dataframe: 1081.56 MB
# Memory usage after optimization: 340.48 MB
# Decreased by 68.5%

# %%
all_data.head(10)
# Out:
#    SK_ID_CURR  NAME_CONTRACT_TYPE  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 0      100002           -0.324463     -0.717773         0.664551
# 1      100003           -0.324463     -0.717773        -1.504883
# 2      100004            3.082031      1.392578         0.664551
# 3      100006           -0.324463     -0.717773         0.664551
# 4      100007           -0.324463     -0.717773         0.664551
# 5      100008           -0.324463     -0.717773         0.664551
# 6      100009           -0.324463      1.392578         0.664551
# 7      100010           -0.324463      1.392578         0.664551
# 8      100011           -0.324463     -0.717773         0.664551
# 9      100012            3.082031     -0.717773         0.664551
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0     -0.577637          0.142090   -0.478027    -0.166016        -0.505859
# 1     -0.577637          0.426758    1.725586     0.592773         1.600586
# 2     -0.577637         -0.427246   -1.153320    -1.404297        -1.089844
# 3     -0.577637         -0.142578   -0.711426     0.177979        -0.651855
# 4     -0.577637         -0.199463   -0.213745    -0.361572        -0.067383
# 5     -0.577637         -0.294434   -0.269531     0.028290        -0.225708
# 6      0.807129          0.009285    2.388672     0.979004         2.318359
# 7     -0.577637          0.806152    2.312500     1.032227         2.683594
# 8     -0.577637         -0.237427    1.044922     0.463623         1.016602
# 9     -0.577637         -0.142578   -0.482178    -0.473145        -0.359619
#
#    REGION_POPULATION_RELATIVE  ...   LSTM_19   LSTM_20   LSTM_21   LSTM_23  \
# 0                   -0.149658  ...  0.088806  0.164062  0.484619  0.262939
# 1                   -1.252930  ...  0.000000  0.532715  1.517578  0.622070
# 2                   -0.783203  ...  0.000000  0.356934  1.283203  0.556152
# 3                   -0.929199  ...  0.000000  0.271973  0.982422  0.650391
# 4                    0.562988  ...  0.000000  0.200684  1.047852  0.322754
# 5                    1.079102  ...  0.000000  0.338135  1.052734  0.354248
# 6                    1.079102  ...  0.244629  0.418457  1.654297  0.724121
# 7                   -1.283203  ...  0.000000  0.393555  1.265625  0.714355
# 8                   -0.161865  ...  0.000000  0.312500  1.094727  0.205688
# 9                   -0.085693  ...  0.000000  0.305176  1.082031  0.746582
#
#     LSTM_25   LSTM_26   LSTM_27   LSTM_30   LSTM_31   LSTM_32
# 0  0.162842  0.139404  0.488281  0.624512  0.304199  0.323242
# 1  0.825195  0.000000  1.728516  2.693359  1.545898  1.300781
# 2  0.493408  0.729492  1.445312  2.021484  0.999512  0.889160
# 3  0.457764  0.000000  1.086914  1.581055  0.726074  0.801758
# 4  0.527832  0.000000  1.129883  1.547852  0.803223  0.759277
# 5  0.462158  0.621094  1.134766  1.626953  0.891602  0.897949
# 6  0.611816  0.491943  1.828125  1.815430  1.048828  1.099609
# 7  0.713867  0.540527  1.346680  2.126953  1.164062  1.132812
# 8  0.506836  0.751953  1.060547  1.671875  0.832520  0.958496
# 9  0.452881  0.000000  1.239258  1.718750  0.853027  0.817383
#
# [10 rows x 461 columns]

# %% [markdown]
# # 拆分数据集

# %%
def split_train(data,test_ratio):
   #  data = data.iloc[0:20000,:]
    np.random.seed(0)  # 设置随机种子确保实验可重复
    shuffled_indices=np.random.permutation(len(data))
    test_set_size=int(len(data)*test_ratio)
    test_indices =shuffled_indices[:test_set_size]
    train_indices=shuffled_indices[test_set_size:]
    return data.iloc[train_indices],data.iloc[test_indices]

# %%
all_data_train, all_data_valtest = split_train(all_data, 0.2)

# %%
all_data_train.shape
# Out:
# (246009, 461)

# %%
all_data_valtest.shape
# Out:
# (61502, 461)

# %%
all_data_val,all_data_test = split_train(all_data_valtest, 0.5)

# %%
all_data_val.shape
# Out:
# (30751, 461)

# %%
all_data_test.shape
# Out:
# (30751, 461)

# %% [markdown]
# # 特征选择方法

# %%
from sklearn.feature_selection import SelectKBest,chi2,RFE,SelectFromModel
from sklearn.preprocessing import MinMaxScaler

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# 采用6种特征选择方法，输入特征选择结果
def select_feature(data, num):
    X = data.drop(['TARGET'], axis=1)
    y = data.TARGET
    feature_name = X.columns.tolist()
    
    start = time.time()
    # 过滤法，皮尔逊相关系数
    cor_list = []
    # 计算与目标的相关系数
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # 空值使用0代替
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # 选中的名字
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-num:]].columns.tolist()
    # 选中为T
    cor_support = [True if i in cor_feature else False for i in feature_name]
    end1 =time.time()
    print("过滤法-皮尔逊相关系数特征选择所用时间：", end1 - start)
    print(str(len(cor_feature)), 'selected features')
    
    # 过滤法-卡方检验
    X_norm = MinMaxScaler().fit_transform(X)
    chi_selector = SelectKBest(chi2, k=num)
    chi_selector.fit(X_norm, y)
    chi_support = chi_selector.get_support()
    chi_feature = X.loc[:,chi_support].columns.tolist()
    end2 = time.time()
    print("过滤法-卡方检验特征选择所用时间：", end2 - end1)
    print(str(len(chi_feature)), 'selected features')
    
    # 包裹式-LR
    LR_selector = RFE(estimator=LogisticRegression(solver='liblinear',max_iter=500), n_features_to_select=num, step=50, verbose=5)
    LR_selector.fit(X, y)
    LR_support = LR_selector.get_support()
    LR_feature = X.loc[:,LR_support].columns.tolist()  # list
    end3 = time.time()
    print("包裹式-LR特征选择所用时间：", end3 - end2)
    print(str(len(LR_feature)), 'selected features')
    
    # 包裹式-RF
    RF_selector = RFE(estimator=RandomForestClassifier(n_estimators=100), n_features_to_select=num, step=50, verbose=5)
    RF_selector.fit(X, y)
    RF_support = RF_selector.get_support()
    RF_feature = X.loc[:,RF_support].columns.tolist()
    end4 = time.time()
    print("包裹式-LR特征选择所用时间：", end4 - end3)
    print(str(len(RF_feature)), 'selected features')
    
    # 嵌入式-LR
    embeded_lr_selector = SelectFromModel(estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
          intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
          penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
          verbose=0, warm_start=False),
        norm_order=1, prefit=False, threshold=-np.inf, max_features=num)
    embeded_lr_selector.fit(X_norm, y)
    embeded_lr_support = embeded_lr_selector.get_support()
    embeded_lr_feature = X.loc[:,embeded_lr_support].columns.tolist()
    end5 = time.time()
    print("嵌入式-LR特征选择所用时间：", end5 - end4)
    print(str(len(embeded_lr_feature)), 'selected features')
    
    # 嵌入式-RF
    embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), threshold=-np.inf, max_features=200)
    embeded_rf_selector.fit(X, y)
    embeded_rf_support = embeded_rf_selector.get_support()
    embeded_rf_feature = X.loc[:,embeded_rf_support].columns.tolist()
    end6 = time.time()
    print("嵌入式-LR特征选择所用时间：", end6 - end5)

    print(str(len(embeded_rf_feature)), 'selected features')
    
    
    # put all selection together
    feature_selection_df = pd.DataFrame({'Feature':feature_name, 'Pearson':cor_support, 'Chi-2':chi_support, 'RFE_LR':LR_support, 'RFE_RF':RF_support, 'Logistics':embeded_lr_support,
                                    'Random Forest':embeded_rf_support})
    # 统计结果 
    feature_selection_df['Total'] = np.sum(feature_selection_df, axis=1)
    # display the top 200
    feature_selection_df = feature_selection_df.sort_values(['Total','Feature'] , ascending=False)
    feature_selection_df.index = range(1, len(feature_selection_df)+1)
    feature_selection_df = feature_selection_df.iloc[:num,]
    
    selected_df = feature_selection_df[feature_selection_df['Total'] > 3]
    combination_feature = selected_df.Feature.tolist()
    combination_feature_dataframe = combination_feature + [" "] * (200 - len(combination_feature)) # 不够两百，空值填充
    
    dataframe_select = pd.DataFrame({'Pearson':cor_feature, 'Chi-2':chi_feature, 'RFE_LR':LR_feature, 'RFE_RF':RF_feature, 'embedding_LR':embeded_lr_feature,
                                    'embedding_RF':embeded_rf_feature, 'combination': combination_feature_dataframe})
    
    # 返回投票结果，以及返回选择后的特征列表
    return feature_selection_df,dataframe_select
    # 组合特征选择

# %%
all_feture_selction_df,all_dataframe_select = select_feature(all_data_train, 200)
# Out:
# 过滤法-皮尔逊相关系数特征选择所用时间： 1.83622145652771
# 200 selected features
# 过滤法-卡方检验特征选择所用时间： 1.8855607509613037
# 200 selected features
# Fitting estimator with 460 features.
# Fitting estimator with 410 features.
# Fitting estimator with 360 features.
# Fitting estimator with 310 features.
# Fitting estimator with 260 features.
# Fitting estimator with 210 features.
# 包裹式-LR特征选择所用时间： 1322.7132577896118
# 200 selected features
# Fitting estimator with 460 features.
# Fitting estimator with 410 features.
# Fitting estimator with 360 features.
# Fitting estimator with 310 features.
# Fitting estimator with 260 features.
# Fitting estimator with 210 features.
# 包裹式-LR特征选择所用时间： 2037.9275753498077
# 200 selected features
# 嵌入式-LR特征选择所用时间： 295.2207579612732
# 200 selected features
# 嵌入式-LR特征选择所用时间： 286.50982332229614
# 200 selected features

# %%
pd.set_option('display.max_rows', None) # 可以显示所有
all_feture_selction_df
# Out:
#                                             Feature  Pearson  Chi-2  RFE_LR  \
# 1                           PREV_DAYS_DECISION_MEAN     True   True    True
# 2                             PREV_CNT_PAYMENT_MEAN     True   True    True
# 3                                         POS_COUNT     True   True    True
# 4                                           LSTM_32     True   True    True
# 5                                           LSTM_31     True   True    True
# 6                                           LSTM_27     True   True    True
# 7                                           LSTM_21     True   True    True
# 8                    INSTAL_DAYS_ENTRY_PAYMENT_MEAN     True   True    True
# 9                            CLOSED_DAYS_CREDIT_MIN     True   True    True
# 10                           CLOSED_DAYS_CREDIT_MAX     True   True    True
# 11                             BURO_DAYS_CREDIT_VAR     True   True    True
# 12                             BURO_DAYS_CREDIT_MIN     True   True    True
# 13                            BURO_DAYS_CREDIT_MEAN     True   True    True
# 14                       APPROVED_DAYS_DECISION_MIN     True   True    True
# 15                     YEARS_BEGINEXPLUATATION_MODE     True   True   False
# 16                                   TOTALAREA_MODE     True   True   False
# 17                       REGION_POPULATION_RELATIVE     True   True   False
# 18                      PREV_RATE_DOWN_PAYMENT_MEAN     True   True   False
# 19           PREV_NAME_CONTRACT_STATUS_Refused_MEAN     True   True   False
# 20                           PREV_DAYS_DECISION_MIN     True   True    True
# 21                 PREV_CODE_REJECT_REASON_XAP_MEAN     True   True    True
# 22                  PREV_CODE_REJECT_REASON_HC_MEAN     True   True   False
# 23                             PREV_CNT_PAYMENT_SUM     True  False    True
# 24                            PREV_AMT_ANNUITY_MEAN     True  False    True
# 25                          POS_MONTHS_BALANCE_SIZE     True  False    True
# 26                          POS_MONTHS_BALANCE_MEAN     True  False    True
# 27                         NEW_PHONE_TO_BIRTH_RATIO     True   True   False
# 28                                   NEW_INC_BY_ORG     True   True   False
# 29                                           LSTM_8     True   True   False
# 30                                           LSTM_4     True   True    True
# 31                                          LSTM_30     True   True    True
# 32                                          LSTM_26     True   True   False
# 33                                          LSTM_25     True   True   False
# 34                                          LSTM_23     True   True   False
# 35                                          LSTM_20     True   True   False
# 36                                          LSTM_14     True   True   False
# 37                                          LSTM_12     True   True    True
# 38                                          LSTM_10     True   True   False
# 39                                  LIVINGAREA_MODE     True   True   False
# 40                          INSTAL_PAYMENT_DIFF_SUM     True  False    True
# 41                         INSTAL_PAYMENT_DIFF_MEAN     True  False    True
# 42                          INSTAL_PAYMENT_DIFF_MAX     True  False    True
# 43                                   INSTAL_DBD_SUM     True  False    True
# 44                    INSTAL_DAYS_ENTRY_PAYMENT_SUM     True  False    True
# 45                                     EXT_SOURCE_2     True   True   False
# 46                           DAYS_LAST_PHONE_CHANGE     True   True   False
# 47                                  DAYS_ID_PUBLISH     True   True   False
# 48                               DAYS_EMPLOYED_PERC     True   True   False
# 49                                       DAYS_BIRTH     True   True   False
# 50                           CLOSED_DAYS_CREDIT_VAR     True   True    True
# 51                          CLOSED_DAYS_CREDIT_MEAN     True   True    True
# 52                   CLOSED_DAYS_CREDIT_ENDDATE_MIN     True  False    True
# 53                      CC_CNT_DRAWINGS_CURRENT_VAR     True   True    True
# 54                     BURO_DAYS_CREDIT_UPDATE_MEAN     True  False    True
# 55                             BURO_DAYS_CREDIT_MAX     True   True    True
# 56                     BURO_DAYS_CREDIT_ENDDATE_MIN     True  False    True
# 57                    BURO_DAYS_CREDIT_ENDDATE_MEAN     True  False    True
# 58                   BURO_CREDIT_ACTIVE_Closed_MEAN     True   True   False
# 59                   APPROVED_RATE_DOWN_PAYMENT_MAX     True   True   False
# 60                      APPROVED_DAYS_DECISION_MEAN     True  False    True
# 61                    APPROVED_AMT_GOODS_PRICE_MEAN     True  False    True
# 62                        APPROVED_AMT_ANNUITY_MEAN     True  False    True
# 63                         APPROVED_AMT_ANNUITY_MAX     True  False    True
# 64                                       AMT_CREDIT     True   True   False
# 65                           ACTIVE_DAYS_CREDIT_MIN     True  False    True
# 66                          ACTIVE_DAYS_CREDIT_MEAN     True  False    True
# 67                           ACTIVE_DAYS_CREDIT_MAX     True  False    True
# 68                  ACTIVE_DAYS_CREDIT_ENDDATE_MEAN     True  False    True
# 69                   ACTIVE_DAYS_CREDIT_ENDDATE_MAX     True  False    True
# 70                       PREV_RATE_DOWN_PAYMENT_MAX     True   True   False
# 71                  PREV_NAME_YIELD_GROUP_high_MEAN     True   True   False
# 72                    PREV_NAME_TYPE_SUITE_nan_MEAN     True   True   False
# 73                  PREV_NAME_PAYMENT_TYPE_XNA_MEAN     True   True   False
# 74          PREV_NAME_CONTRACT_STATUS_Approved_MEAN     True   True   False
# 75                         PREV_APP_CREDIT_PERC_MIN    False  False    True
# 76                        PREV_AMT_GOODS_PRICE_MEAN    False  False    True
# 77                              PREV_AMT_CREDIT_MAX    False  False    True
# 78                         PREV_AMT_APPLICATION_MIN    False  False    True
# 79                         PREV_AMT_APPLICATION_MAX    False  False    True
# 80                             PREV_AMT_ANNUITY_MIN     True  False    True
# 81                           POS_MONTHS_BALANCE_MAX    False  False    True
# 82           NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MAX    False  False    True
# 83                        NEW_PHONE_TO_EMPLOY_RATIO     True  False   False
# 84                        NEW_CREDIT_TO_GOODS_RATIO     True  False   False
# 85                      NEW_CREDIT_TO_ANNUITY_RATIO     True  False   False
# 86                                          LSTM_19     True  False   False
# 87                                  LIVINGAREA_MEDI     True   True   False
# 88                                   LIVINGAREA_AVG     True   True   False
# 89                                   INSTAL_DPD_MAX    False  False    True
# 90                                  INSTAL_DBD_MEAN    False  False    True
# 91                                   INSTAL_DBD_MAX    False  False    True
# 92                    INSTAL_DAYS_ENTRY_PAYMENT_MAX    False  False    True
# 93                                     INSTAL_COUNT    False  False    True
# 94                           INSTAL_AMT_PAYMENT_SUM    False  False    True
# 95                           INSTAL_AMT_PAYMENT_MIN    False  False    True
# 96                          INSTAL_AMT_PAYMENT_MEAN    False  False    True
# 97                           INSTAL_AMT_PAYMENT_MAX    False  False    True
# 98                                DAYS_REGISTRATION     True  False   False
# 99                                    DAYS_EMPLOYED     True  False   False
# 100                  CLOSED_DAYS_CREDIT_UPDATE_MEAN     True  False    True
# 101                  CLOSED_DAYS_CREDIT_ENDDATE_MAX    False  False    True
# 102                     CC_AMT_TOTAL_RECEIVABLE_VAR     True   True    True
# 103                  CC_AMT_INST_MIN_REGULARITY_VAR     True   True    True
# 104                 CC_AMT_INST_MIN_REGULARITY_MEAN     True   True    True
# 105                     CC_AMT_DRAWINGS_CURRENT_MAX     True   True    True
# 106                             CC_AMT_BALANCE_MEAN     True   True    True
# 107                              CC_AMT_BALANCE_MAX     True   True    True
# 108                   BURO_MONTHS_BALANCE_SIZE_MEAN     True   True    True
# 109                    BURO_DAYS_CREDIT_ENDDATE_MAX     True  False    True
# 110                  BURO_CREDIT_ACTIVE_Active_MEAN     True   True   False
# 111                    BURO_AMT_CREDIT_SUM_DEBT_SUM    False  False    True
# 112                   BURO_AMT_CREDIT_SUM_DEBT_MEAN    False  False    True
# 113                 APPROVED_RATE_DOWN_PAYMENT_MEAN     True   True   False
# 114            APPROVED_HOUR_APPR_PROCESS_START_MIN    False  False    True
# 115            APPROVED_HOUR_APPR_PROCESS_START_MAX    False  False    True
# 116                      APPROVED_DAYS_DECISION_MAX    False  False    True
# 117                        APPROVED_CNT_PAYMENT_SUM    False  False    True
# 118                   APPROVED_APP_CREDIT_PERC_MEAN    False  False    True
# 119                    APPROVED_AMT_GOODS_PRICE_MAX     True  False    True
# 120                  APPROVED_AMT_DOWN_PAYMENT_MEAN     True  False    True
# 121                   APPROVED_AMT_DOWN_PAYMENT_MAX     True  False    True
# 122                         APPROVED_AMT_CREDIT_MAX    False  False    True
# 123                    APPROVED_AMT_APPLICATION_MIN    False  False    True
# 124                   APPROVED_AMT_APPLICATION_MEAN     True  False    True
# 125                    APPROVED_AMT_APPLICATION_MAX     True  False    True
# 126                                 APARTMENTS_MODE     True   True   False
# 127                                 AMT_GOODS_PRICE     True   True   False
# 128                          ACTIVE_DAYS_CREDIT_VAR    False  False    True
# 129                  ACTIVE_DAYS_CREDIT_UPDATE_MEAN     True  False    True
# 130                  ACTIVE_DAYS_CREDIT_ENDDATE_MIN    False  False    True
# 131                       ACTIVE_AMT_CREDIT_SUM_SUM    False  False    True
# 132              ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN    False  False    True
# 133                    YEARS_BEGINEXPLUATATION_MEDI     True   True   False
# 134                     YEARS_BEGINEXPLUATATION_AVG     True   True   False
# 135                            WALLSMATERIAL_MODE_0     True   True   False
# 136                                      SK_ID_CURR    False  False    True
# 137                     REGION_RATING_CLIENT_W_CITY     True   True   False
# 138                            REGION_RATING_CLIENT     True   True   False
# 139  PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN     True   True   False
# 140           PREV_NAME_YIELD_GROUP_low_action_MEAN     True   True   False
# 141                  PREV_NAME_YIELD_GROUP_XNA_MEAN     True   True   False
# 142        PREV_NAME_SELLER_INDUSTRY_Furniture_MEAN     True   True   False
# 143     PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN     True   True   False
# 144                    PREV_NAME_PORTFOLIO_XNA_MEAN     True   True   False
# 145         PREV_NAME_GOODS_CATEGORY_Furniture_MEAN     True   True   False
# 146     PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN     True   True   False
# 147                  PREV_NAME_CLIENT_TYPE_New_MEAN     True   True   False
# 148                PREV_HOUR_APPR_PROCESS_START_MIN    False  False    True
# 149               PREV_HOUR_APPR_PROCESS_START_MEAN    False  False    True
# 150                PREV_HOUR_APPR_PROCESS_START_MAX    False  False    True
# 151                          PREV_DAYS_DECISION_MAX    False  False    True
# 152          PREV_CHANNEL_TYPE_AP+ (Cash loan)_MEAN     True   True   False
# 153                       PREV_APP_CREDIT_PERC_MEAN    False  False    True
# 154                        PREV_APP_CREDIT_PERC_MAX    False  False    True
# 155                        PREV_AMT_GOODS_PRICE_MIN    False  False    True
# 156                        PREV_AMT_GOODS_PRICE_MAX    False  False    True
# 157                      PREV_AMT_DOWN_PAYMENT_MEAN    False  False    True
# 158                       PREV_AMT_DOWN_PAYMENT_MAX    False  False    True
# 159                             PREV_AMT_CREDIT_MIN    False  False    True
# 160                            PREV_AMT_CREDIT_MEAN    False  False    True
# 161                       PREV_AMT_APPLICATION_MEAN    False  False    True
# 162                            PREV_AMT_ANNUITY_MAX    False  False    True
# 163         POS_NAME_CONTRACT_STATUS_Completed_MEAN    False  False   False
# 164                                    PAYMENT_RATE    False  False   False
# 165                           ORGANIZATION_TYPE_XNA     True   True   False
# 166          NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MIN    False  False    True
# 167         NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MEAN    False  False    True
# 168               NEW_RATIO_BURO_AMT_CREDIT_SUM_SUM    False  False    True
# 169              NEW_RATIO_BURO_AMT_CREDIT_SUM_MEAN    False  False    True
# 170               NEW_RATIO_BURO_AMT_CREDIT_SUM_MAX    False  False    True
# 171                        NAME_INCOME_TYPE_Working     True   True   False
# 172                      NAME_INCOME_TYPE_Pensioner     True   True   False
# 173             NAME_HOUSING_TYPE_House / apartment     True   True   False
# 174         NAME_FAMILY_STATUS_Single / not married     True   True   False
# 175            NAME_EDUCATION_TYPE_Higher education     True   True   False
# 176                              NAME_CONTRACT_TYPE     True   True   False
# 177                                          LSTM_3     True  False   False
# 178                         INSTAL_PAYMENT_PERC_VAR    False  False    True
# 179                         INSTAL_PAYMENT_PERC_SUM    False  False    True
# 180                                  INSTAL_DPD_SUM    False  False    True
# 181                       INSTAL_AMT_INSTALMENT_SUM    False  False    True
# 182                      INSTAL_AMT_INSTALMENT_MEAN    False  False    True
# 183                       INSTAL_AMT_INSTALMENT_MAX    False  False    True
# 184                              INCOME_CREDIT_PERC    False  False   False
# 185                                HOUSETYPE_MODE_0     True   True   False
# 186                         HOUR_APPR_PROCESS_START    False  False   False
# 187                                   FLOORSMAX_AVG     True   True   False
# 188                                 FLAG_DOCUMENT_3     True   True   False
# 189                                  ENTRANCES_MODE     True   True   False
# 190                                  ELEVATORS_MODE     True   True   False
# 191                                   CODE_GENDER_F     True   True   False
# 192                 CLOSED_DAYS_CREDIT_ENDDATE_MEAN    False  False    True
# 193                       CLOSED_AMT_CREDIT_SUM_SUM    False  False    True
# 194                      CLOSED_AMT_CREDIT_SUM_MEAN    False  False    True
# 195                       CLOSED_AMT_CREDIT_SUM_MAX    False  False    True
# 196                CC_CNT_INSTALMENT_MATURE_CUM_SUM    False   True    True
# 197                    CC_CNT_DRAWINGS_CURRENT_MEAN     True   True   False
# 198                     CC_CNT_DRAWINGS_CURRENT_MAX     True   True   False
# 199                 CC_CNT_DRAWINGS_ATM_CURRENT_SUM     True   True   False
# 200                    CC_AMT_TOTAL_RECEIVABLE_MEAN     True   True    True
#
#      RFE_RF  Logistics  Random Forest  Total
# 1      True       True           True      6
# 2      True       True           True      6
# 3      True       True           True      6
# 4      True       True           True      6
# 5      True       True           True      6
# 6      True       True           True      6
# 7      True       True           True      6
# 8      True       True           True      6
# 9      True       True           True      6
# 10     True       True           True      6
# 11     True       True           True      6
# 12     True       True           True      6
# 13     True       True           True      6
# 14     True       True           True      6
# 15     True       True           True      5
# 16     True       True           True      5
# 17     True       True           True      5
# 18     True       True           True      5
# 19     True       True           True      5
# 20     True      False           True      5
# 21     True      False           True      5
# 22     True       True           True      5
# 23     True       True           True      5
# 24     True       True           True      5
# 25     True       True           True      5
# 26     True       True           True      5
# 27     True       True           True      5
# 28     True       True           True      5
# 29     True       True           True      5
# 30     True      False           True      5
# 31     True      False           True      5
# 32     True       True           True      5
# 33     True       True           True      5
# 34     True       True           True      5
# 35     True       True           True      5
# 36     True       True           True      5
# 37     True      False           True      5
# 38     True       True           True      5
# 39     True       True           True      5
# 40     True       True           True      5
# 41     True       True           True      5
# 42     True       True           True      5
# 43     True       True           True      5
# 44     True       True           True      5
# 45     True       True           True      5
# 46     True       True           True      5
# 47     True       True           True      5
# 48     True       True           True      5
# 49     True       True           True      5
# 50     True      False           True      5
# 51     True      False           True      5
# 52     True       True           True      5
# 53     True       True          False      5
# 54     True       True           True      5
# 55     True      False           True      5
# 56     True       True           True      5
# 57     True       True           True      5
# 58     True       True           True      5
# 59     True       True           True      5
# 60     True       True           True      5
# 61     True       True           True      5
# 62     True       True           True      5
# 63     True       True           True      5
# 64     True       True           True      5
# 65     True       True           True      5
# 66     True       True           True      5
# 67     True       True           True      5
# 68     True       True           True      5
# 69     True       True           True      5
# 70     True      False           True      4
# 71     True      False           True      4
# 72     True      False           True      4
# 73     True      False           True      4
# 74     True      False           True      4
# 75     True       True           True      4
# 76     True       True           True      4
# 77     True       True           True      4
# 78     True       True           True      4
# 79     True       True           True      4
# 80     True      False           True      4
# 81     True       True           True      4
# 82     True       True           True      4
# 83     True       True           True      4
# 84     True       True           True      4
# 85     True       True           True      4
# 86     True       True           True      4
# 87     True      False           True      4
# 88     True      False           True      4
# 89     True       True           True      4
# 90     True       True           True      4
# 91     True       True           True      4
# 92     True       True           True      4
# 93     True       True           True      4
# 94     True       True           True      4
# 95     True       True           True      4
# 96     True       True           True      4
# 97     True       True           True      4
# 98     True       True           True      4
# 99     True       True           True      4
# 100    True      False           True      4
# 101    True       True           True      4
# 102   False       True          False      4
# 103   False       True          False      4
# 104   False       True          False      4
# 105   False       True          False      4
# 106   False       True          False      4
# 107   False       True          False      4
# 108   False       True          False      4
# 109    True      False           True      4
# 110   False       True           True      4
# 111    True       True           True      4
# 112    True       True           True      4
# 113    True      False           True      4
# 114    True       True           True      4
# 115    True       True           True      4
# 116    True       True           True      4
# 117    True       True           True      4
# 118    True       True           True      4
# 119    True      False           True      4
# 120    True      False           True      4
# 121    True      False           True      4
# 122    True       True           True      4
# 123    True       True           True      4
# 124    True      False           True      4
# 125    True      False           True      4
# 126    True       True          False      4
# 127    True      False           True      4
# 128    True       True           True      4
# 129    True      False           True      4
# 130    True       True           True      4
# 131    True       True           True      4
# 132    True       True           True      4
# 133   False      False           True      3
# 134   False      False           True      3
# 135   False       True          False      3
# 136    True      False           True      3
# 137   False       True          False      3
# 138   False       True          False      3
# 139   False       True          False      3
# 140   False       True          False      3
# 141    True      False          False      3
# 142   False       True          False      3
# 143   False       True          False      3
# 144   False      False           True      3
# 145   False       True          False      3
# 146   False       True          False      3
# 147   False       True          False      3
# 148    True      False           True      3
# 149    True      False           True      3
# 150    True      False           True      3
# 151    True      False           True      3
# 152   False       True          False      3
# 153    True      False           True      3
# 154    True      False           True      3
# 155    True      False           True      3
# 156    True      False           True      3
# 157    True      False           True      3
# 158    True      False           True      3
# 159    True      False           True      3
# 160    True      False           True      3
# 161    True      False           True      3
# 162    True      False           True      3
# 163    True       True           True      3
# 164    True       True           True      3
# 165   False       True          False      3
# 166    True      False           True      3
# 167    True      False           True      3
# 168    True      False           True      3
# 169    True      False           True      3
# 170    True      False           True      3
# 171   False       True          False      3
# 172   False       True          False      3
# 173   False       True          False      3
# 174   False       True          False      3
# 175   False       True          False      3
# 176   False       True          False      3
# 177    True      False           True      3
# 178    True      False           True      3
# 179    True      False           True      3
# 180    True      False           True      3
# 181    True      False           True      3
# 182    True      False           True      3
# 183    True      False           True      3
# 184    True       True           True      3
# 185   False       True          False      3
# 186    True       True           True      3
# 187   False       True          False      3
# 188   False       True          False      3
# 189   False       True          False      3
# 190   False       True          False      3
# 191   False       True          False      3
# 192    True      False           True      3
# 193    True      False           True      3
# 194    True      False           True      3
# 195    True      False           True      3
# 196   False       True          False      3
# 197    True      False          False      3
# 198   False       True          False      3
# 199   False       True          False      3
# 200   False      False          False      3

# %%
all_feture_selction_df.to_csv("C:/data/processing_data/dataset/all_feture_selction.csv")

# %%
all_dataframe_select
# Out:
#                                                Pearson  \
# 0                       APPROVED_AMT_DOWN_PAYMENT_MEAN
# 1             ORGANIZATION_TYPE_Business Entity Type 3
# 2                       ACTIVE_DAYS_CREDIT_UPDATE_MEAN
# 3                              INSTAL_PAYMENT_DIFF_MAX
# 4                        APPROVED_AMT_GOODS_PRICE_MEAN
# 5          PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN
# 6                      CC_AMT_RECEIVABLE_PRINCIPAL_VAR
# 7                        APPROVED_AMT_APPLICATION_MEAN
# 8                        BURO_MONTHS_BALANCE_SIZE_MEAN
# 9                                 CC_AMT_RECIVABLE_VAR
# 10                         CC_AMT_TOTAL_RECEIVABLE_VAR
# 11                                  CC_AMT_BALANCE_VAR
# 12                        APPROVED_AMT_GOODS_PRICE_MAX
# 13                        APPROVED_AMT_APPLICATION_MAX
# 14                     CC_AMT_DRAWINGS_ATM_CURRENT_SUM
# 15                      PREV_NAME_CLIENT_TYPE_New_MEAN
# 16                PREV_NAME_CLIENT_TYPE_Refreshed_MEAN
# 17   PREV_PRODUCT_COMBINATION_POS mobile with inter...
# 18             NAME_FAMILY_STATUS_Single / not married
# 19                          NAME_FAMILY_STATUS_Married
# 20                               PREV_AMT_ANNUITY_MEAN
# 21                                PREV_AMT_ANNUITY_MIN
# 22                        PREV_NAME_PORTFOLIO_POS_MEAN
# 23                     ACTIVE_DAYS_CREDIT_ENDDATE_MEAN
# 24            PREV_NAME_SELLER_INDUSTRY_Furniture_MEAN
# 25                       APPROVED_AMT_DOWN_PAYMENT_MAX
# 26                              ACTIVE_DAYS_CREDIT_MIN
# 27                             POS_MONTHS_BALANCE_MEAN
# 28                                     NEW_DOC_IND_STD
# 29               PREV_NAME_YIELD_GROUP_low_action_MEAN
# 30                      CC_AMT_INST_MIN_REGULARITY_VAR
# 31                        BURO_DAYS_CREDIT_ENDDATE_MAX
# 32                                      INSTAL_DBD_SUM
# 33                             INSTAL_PAYMENT_DIFF_SUM
# 34                         APPROVED_DAYS_DECISION_MEAN
# 35                 NAME_HOUSING_TYPE_House / apartment
# 36                  PREV_NAME_SELLER_INDUSTRY_XNA_MEAN
# 37             PREV_NAME_GOODS_CATEGORY_Furniture_MEAN
# 38                                     FLAG_WORK_PHONE
# 39                             POS_MONTHS_BALANCE_SIZE
# 40                                           POS_COUNT
# 41                                             LSTM_19
# 42                     APPROVED_RATE_DOWN_PAYMENT_MEAN
# 43                                          AMT_CREDIT
# 44                             OCCUPATION_TYPE_Drivers
# 45                            INSTAL_PAYMENT_DIFF_MEAN
# 46                         CC_CNT_DRAWINGS_CURRENT_SUM
# 47                                     FLAG_DOCUMENT_6
# 48                            DEF_60_CNT_SOCIAL_CIRCLE
# 49                     CC_CNT_DRAWINGS_ATM_CURRENT_SUM
# 50                     ORGANIZATION_TYPE_Self-employed
# 51                            DEF_30_CNT_SOCIAL_CIRCLE
# 52   PREV_PRODUCT_COMBINATION_POS industry with int...
# 53                       INSTAL_DAYS_ENTRY_PAYMENT_SUM
# 54                         NEW_CREDIT_TO_ANNUITY_RATIO
# 55     PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN
# 56                                  NAME_CONTRACT_TYPE
# 57                                PREV_CNT_PAYMENT_SUM
# 58                         CC_AMT_DRAWINGS_CURRENT_MAX
# 59                                   BASEMENTAREA_MODE
# 60     PREV_PRODUCT_COMBINATION_Cash Street: high_MEAN
# 61         PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN
# 62                        PREV_NAME_PORTFOLIO_XNA_MEAN
# 63                         PREV_RATE_DOWN_PAYMENT_MEAN
# 64                             LIVE_CITY_NOT_WORK_CITY
# 65                               PREV_CNT_PAYMENT_MEAN
# 66                                   BASEMENTAREA_MEDI
# 67                      PREV_NAME_PORTFOLIO_Cards_MEAN
# 68                            WALLSMATERIAL_MODE_Panel
# 69                                    BASEMENTAREA_AVG
# 70                                      ELEVATORS_MODE
# 71      PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN
# 72                         CC_CNT_DRAWINGS_CURRENT_VAR
# 73                        CC_AMT_DRAWINGS_CURRENT_MEAN
# 74                      INSTAL_DAYS_ENTRY_PAYMENT_MEAN
# 75                             BURO_STATUS_1_MEAN_MEAN
# 76                                      NEW_INC_BY_ORG
# 77                           APPROVED_AMT_ANNUITY_MEAN
# 78                                      ELEVATORS_MEDI
# 79                            APPROVED_AMT_ANNUITY_MAX
# 80                   PREV_NAME_GOODS_CATEGORY_XNA_MEAN
# 81                                       ELEVATORS_AVG
# 82                        BURO_DAYS_CREDIT_ENDDATE_MIN
# 83               PREV_NAME_YIELD_GROUP_low_normal_MEAN
# 84                      CC_AMT_INST_MIN_REGULARITY_MAX
# 85                                  DAYS_EMPLOYED_PERC
# 86                            NEW_PHONE_TO_BIRTH_RATIO
# 87              PREV_CHANNEL_TYPE_AP+ (Cash loan)_MEAN
# 88                                    NEW_DOC_IND_KURT
# 89                          REGION_POPULATION_RELATIVE
# 90                             PREV_DAYS_DECISION_MEAN
# 91                                      ENTRANCES_MODE
# 92                       PREV_NAME_TYPE_SUITE_nan_MEAN
# 93                     CC_AMT_RECEIVABLE_PRINCIPAL_MAX
# 94                     CC_AMT_RECEIVABLE_PRINCIPAL_MIN
# 95                          PREV_RATE_DOWN_PAYMENT_MAX
# 96                         CC_AMT_TOTAL_RECEIVABLE_MIN
# 97                                CC_AMT_RECIVABLE_MIN
# 98                      ACTIVE_DAYS_CREDIT_ENDDATE_MAX
# 99                                CC_AMT_RECIVABLE_MAX
# 100                        CC_AMT_TOTAL_RECEIVABLE_MAX
# 101                    PREV_NAME_PAYMENT_TYPE_XNA_MEAN
# 102                   PREV_CODE_REJECT_REASON_XAP_MEAN
# 103                                 CC_AMT_BALANCE_MIN
# 104              BURO_CREDIT_TYPE_Consumer credit_MEAN
# 105                                     ENTRANCES_MEDI
# 106                                 CC_AMT_BALANCE_MAX
# 107                                      ENTRANCES_AVG
# 108                                    LIVINGAREA_MODE
# 109                                    APARTMENTS_MODE
# 110                     CLOSED_DAYS_CREDIT_ENDDATE_MIN
# 111                                    AMT_GOODS_PRICE
# 112                                  OCCUPATION_TYPE_0
# 113                     APPROVED_RATE_DOWN_PAYMENT_MAX
# 114       PREV_NAME_CONTRACT_TYPE_Revolving loans_MEAN
# 115                                    APARTMENTS_MEDI
# 116                 PREV_CODE_REJECT_REASON_LIMIT_MEAN
# 117                                    LIVINGAREA_MEDI
# 118                                     APARTMENTS_AVG
# 119                                   HOUSETYPE_MODE_0
# 120                               WALLSMATERIAL_MODE_0
# 121                                     LIVINGAREA_AVG
# 122                    PREV_NAME_YIELD_GROUP_high_MEAN
# 123                                     TOTALAREA_MODE
# 124                            ACTIVE_DAYS_CREDIT_MEAN
# 125                         APPROVED_DAYS_DECISION_MIN
# 126                             PREV_DAYS_DECISION_MIN
# 127          PREV_PRODUCT_COMBINATION_Card Street_MEAN
# 128                    CC_AMT_INST_MIN_REGULARITY_MEAN
# 129                      HOUSETYPE_MODE_block of flats
# 130                      BURO_DAYS_CREDIT_ENDDATE_MEAN
# 131                       YEARS_BEGINEXPLUATATION_MODE
# 132                        YEARS_BEGINEXPLUATATION_AVG
# 133                       YEARS_BEGINEXPLUATATION_MEDI
# 134                              EMERGENCYSTATE_MODE_0
# 135                             CLOSED_DAYS_CREDIT_VAR
# 136                               BURO_DAYS_CREDIT_VAR
# 137                             EMERGENCYSTATE_MODE_No
# 138                          NEW_PHONE_TO_EMPLOY_RATIO
# 139            PREV_NAME_CONTRACT_STATUS_Approved_MEAN
# 140                                  DAYS_REGISTRATION
# 141                             ACTIVE_DAYS_CREDIT_MAX
# 142                           OCCUPATION_TYPE_Laborers
# 143                             REG_CITY_NOT_LIVE_CITY
# 144                       CC_CNT_DRAWINGS_CURRENT_MEAN
# 145                     PREV_NAME_YIELD_GROUP_XNA_MEAN
# 146                                    FLAG_DOCUMENT_3
# 147                                      DAYS_EMPLOYED
# 148                              ORGANIZATION_TYPE_XNA
# 149                                     FLAG_EMP_PHONE
# 150                         NAME_INCOME_TYPE_Pensioner
# 151                   CC_AMT_RECEIVABLE_PRINCIPAL_MEAN
# 152                              CC_AMT_RECIVABLE_MEAN
# 153                       CC_AMT_TOTAL_RECEIVABLE_MEAN
# 154                                CC_AMT_BALANCE_MEAN
# 155                             CLOSED_DAYS_CREDIT_MAX
# 156                     BURO_CREDIT_ACTIVE_Active_MEAN
# 157                                     FLOORSMAX_MODE
# 158                                     FLOORSMAX_MEDI
# 159                                      FLOORSMAX_AVG
# 160  NAME_EDUCATION_TYPE_Secondary / secondary special
# 161                             REG_CITY_NOT_WORK_CITY
# 162                                    DAYS_ID_PUBLISH
# 163                               BURO_DAYS_CREDIT_MAX
# 164                        CC_CNT_DRAWINGS_CURRENT_MAX
# 165                                      CODE_GENDER_F
# 166                                      CODE_GENDER_M
# 167                    PREV_CODE_REJECT_REASON_HC_MEAN
# 168                           NAME_INCOME_TYPE_Working
# 169                             DAYS_LAST_PHONE_CHANGE
# 170               NAME_EDUCATION_TYPE_Higher education
# 171                               REGION_RATING_CLIENT
# 172                     CLOSED_DAYS_CREDIT_UPDATE_MEAN
# 173                        REGION_RATING_CLIENT_W_CITY
# 174                PREV_NAME_PRODUCT_TYPE_walk-in_MEAN
# 175                                            LSTM_10
# 176                          NEW_CREDIT_TO_GOODS_RATIO
# 177                       BURO_DAYS_CREDIT_UPDATE_MEAN
# 178                            CLOSED_DAYS_CREDIT_MEAN
# 179                             CLOSED_DAYS_CREDIT_MIN
# 180                               BURO_DAYS_CREDIT_MIN
# 181                     BURO_CREDIT_ACTIVE_Closed_MEAN
# 182                                         DAYS_BIRTH
# 183             PREV_NAME_CONTRACT_STATUS_Refused_MEAN
# 184                              BURO_DAYS_CREDIT_MEAN
# 185                                             LSTM_3
# 186                                            LSTM_26
# 187                                            LSTM_20
# 188                                            LSTM_14
# 189                                            LSTM_23
# 190                                       EXT_SOURCE_2
# 191                                            LSTM_25
# 192                                            LSTM_27
# 193                                             LSTM_4
# 194                                             LSTM_8
# 195                                            LSTM_21
# 196                                            LSTM_31
# 197                                            LSTM_32
# 198                                            LSTM_30
# 199                                            LSTM_12
#
#                                                  Chi-2  \
# 0                                   NAME_CONTRACT_TYPE
# 1                                         FLAG_OWN_CAR
# 2                                           AMT_CREDIT
# 3                                      AMT_GOODS_PRICE
# 4                           REGION_POPULATION_RELATIVE
# 5                                           DAYS_BIRTH
# 6                                      DAYS_ID_PUBLISH
# 7                                       FLAG_EMP_PHONE
# 8                                      FLAG_WORK_PHONE
# 9                                           FLAG_PHONE
# 10                                REGION_RATING_CLIENT
# 11                         REGION_RATING_CLIENT_W_CITY
# 12                              REG_CITY_NOT_LIVE_CITY
# 13                              REG_CITY_NOT_WORK_CITY
# 14                             LIVE_CITY_NOT_WORK_CITY
# 15                                        EXT_SOURCE_2
# 16                                      APARTMENTS_AVG
# 17                                    BASEMENTAREA_AVG
# 18                         YEARS_BEGINEXPLUATATION_AVG
# 19                                       ELEVATORS_AVG
# 20                                       ENTRANCES_AVG
# 21                                       FLOORSMAX_AVG
# 22                                        LANDAREA_AVG
# 23                                      LIVINGAREA_AVG
# 24                                   NONLIVINGAREA_AVG
# 25                                     APARTMENTS_MODE
# 26                                   BASEMENTAREA_MODE
# 27                        YEARS_BEGINEXPLUATATION_MODE
# 28                                      ELEVATORS_MODE
# 29                                      ENTRANCES_MODE
# 30                                      FLOORSMAX_MODE
# 31                                       LANDAREA_MODE
# 32                                     LIVINGAREA_MODE
# 33                                  NONLIVINGAREA_MODE
# 34                                     APARTMENTS_MEDI
# 35                                   BASEMENTAREA_MEDI
# 36                        YEARS_BEGINEXPLUATATION_MEDI
# 37                                      ELEVATORS_MEDI
# 38                                      ENTRANCES_MEDI
# 39                                      FLOORSMAX_MEDI
# 40                                       LANDAREA_MEDI
# 41                                     LIVINGAREA_MEDI
# 42                                  NONLIVINGAREA_MEDI
# 43                                      TOTALAREA_MODE
# 44                              DAYS_LAST_PHONE_CHANGE
# 45                                     FLAG_DOCUMENT_3
# 46                                     FLAG_DOCUMENT_6
# 47                                     FLAG_DOCUMENT_8
# 48                                  DAYS_EMPLOYED_PERC
# 49                                    NEW_DOC_IND_KURT
# 50                                      NEW_INC_BY_ORG
# 51                            NEW_PHONE_TO_BIRTH_RATIO
# 52                                       CODE_GENDER_F
# 53                                       CODE_GENDER_M
# 54               NAME_INCOME_TYPE_Commercial associate
# 55                          NAME_INCOME_TYPE_Pensioner
# 56                      NAME_INCOME_TYPE_State servant
# 57                            NAME_INCOME_TYPE_Working
# 58                NAME_EDUCATION_TYPE_Higher education
# 59   NAME_EDUCATION_TYPE_Secondary / secondary special
# 60                   NAME_FAMILY_STATUS_Civil marriage
# 61                          NAME_FAMILY_STATUS_Married
# 62             NAME_FAMILY_STATUS_Single / not married
# 63                 NAME_HOUSING_TYPE_House / apartment
# 64                                   OCCUPATION_TYPE_0
# 65                          OCCUPATION_TYPE_Core staff
# 66                             OCCUPATION_TYPE_Drivers
# 67                            OCCUPATION_TYPE_Laborers
# 68                            OCCUPATION_TYPE_Managers
# 69                         OCCUPATION_TYPE_Sales staff
# 70            ORGANIZATION_TYPE_Business Entity Type 3
# 71                     ORGANIZATION_TYPE_Self-employed
# 72                               ORGANIZATION_TYPE_XNA
# 73                                    HOUSETYPE_MODE_0
# 74                       HOUSETYPE_MODE_block of flats
# 75                                WALLSMATERIAL_MODE_0
# 76                            WALLSMATERIAL_MODE_Panel
# 77                     WALLSMATERIAL_MODE_Stone, brick
# 78                               EMERGENCYSTATE_MODE_0
# 79                              EMERGENCYSTATE_MODE_No
# 80                                BURO_DAYS_CREDIT_MIN
# 81                                BURO_DAYS_CREDIT_MAX
# 82                               BURO_DAYS_CREDIT_MEAN
# 83                                BURO_DAYS_CREDIT_VAR
# 84                       BURO_MONTHS_BALANCE_SIZE_MEAN
# 85                      BURO_CREDIT_ACTIVE_Active_MEAN
# 86                      BURO_CREDIT_ACTIVE_Closed_MEAN
# 87                      BURO_CREDIT_TYPE_Car loan_MEAN
# 88               BURO_CREDIT_TYPE_Consumer credit_MEAN
# 89                   BURO_CREDIT_TYPE_Credit card_MEAN
# 90                      BURO_CREDIT_TYPE_Mortgage_MEAN
# 91                             BURO_STATUS_0_MEAN_MEAN
# 92                             BURO_STATUS_1_MEAN_MEAN
# 93                             BURO_STATUS_C_MEAN_MEAN
# 94                              CLOSED_DAYS_CREDIT_MIN
# 95                              CLOSED_DAYS_CREDIT_MAX
# 96                             CLOSED_DAYS_CREDIT_MEAN
# 97                              CLOSED_DAYS_CREDIT_VAR
# 98                               CC_MONTHS_BALANCE_VAR
# 99                                  CC_AMT_BALANCE_MAX
# 100                                CC_AMT_BALANCE_MEAN
# 101                                 CC_AMT_BALANCE_VAR
# 102                        CC_AMT_DRAWINGS_CURRENT_MAX
# 103                       CC_AMT_DRAWINGS_CURRENT_MEAN
# 104                     CC_AMT_INST_MIN_REGULARITY_MAX
# 105                    CC_AMT_INST_MIN_REGULARITY_MEAN
# 106                     CC_AMT_INST_MIN_REGULARITY_VAR
# 107                    CC_AMT_RECEIVABLE_PRINCIPAL_MAX
# 108                   CC_AMT_RECEIVABLE_PRINCIPAL_MEAN
# 109                    CC_AMT_RECEIVABLE_PRINCIPAL_VAR
# 110                               CC_AMT_RECIVABLE_MAX
# 111                              CC_AMT_RECIVABLE_MEAN
# 112                               CC_AMT_RECIVABLE_VAR
# 113                        CC_AMT_TOTAL_RECEIVABLE_MAX
# 114                       CC_AMT_TOTAL_RECEIVABLE_MEAN
# 115                        CC_AMT_TOTAL_RECEIVABLE_VAR
# 116                    CC_CNT_DRAWINGS_ATM_CURRENT_SUM
# 117                        CC_CNT_DRAWINGS_CURRENT_MAX
# 118                       CC_CNT_DRAWINGS_CURRENT_MEAN
# 119                        CC_CNT_DRAWINGS_CURRENT_VAR
# 120                   CC_CNT_INSTALMENT_MATURE_CUM_SUM
# 121                 CC_NAME_CONTRACT_STATUS_Active_MIN
# 122                CC_NAME_CONTRACT_STATUS_Active_MEAN
# 123                 CC_NAME_CONTRACT_STATUS_Active_SUM
# 124                                           CC_COUNT
# 125                     INSTAL_DAYS_ENTRY_PAYMENT_MEAN
# 126                                          POS_COUNT
# 127                         PREV_RATE_DOWN_PAYMENT_MAX
# 128                        PREV_RATE_DOWN_PAYMENT_MEAN
# 129                             PREV_DAYS_DECISION_MIN
# 130                            PREV_DAYS_DECISION_MEAN
# 131                              PREV_CNT_PAYMENT_MEAN
# 132            PREV_NAME_CONTRACT_TYPE_Cash loans_MEAN
# 133        PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN
# 134       PREV_NAME_CONTRACT_TYPE_Revolving loans_MEAN
# 135            PREV_NAME_CONTRACT_STATUS_Approved_MEAN
# 136            PREV_NAME_CONTRACT_STATUS_Canceled_MEAN
# 137             PREV_NAME_CONTRACT_STATUS_Refused_MEAN
# 138  PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN
# 139                    PREV_NAME_PAYMENT_TYPE_XNA_MEAN
# 140                    PREV_CODE_REJECT_REASON_HC_MEAN
# 141                 PREV_CODE_REJECT_REASON_LIMIT_MEAN
# 142                   PREV_CODE_REJECT_REASON_SCO_MEAN
# 143                   PREV_CODE_REJECT_REASON_XAP_MEAN
# 144                 PREV_NAME_TYPE_SUITE_Children_MEAN
# 145                   PREV_NAME_TYPE_SUITE_Family_MEAN
# 146                      PREV_NAME_TYPE_SUITE_nan_MEAN
# 147                     PREV_NAME_CLIENT_TYPE_New_MEAN
# 148               PREV_NAME_CLIENT_TYPE_Refreshed_MEAN
# 149  PREV_NAME_GOODS_CATEGORY_Clothing and Accessor...
# 150  PREV_NAME_GOODS_CATEGORY_Consumer Electronics_...
# 151            PREV_NAME_GOODS_CATEGORY_Furniture_MEAN
# 152               PREV_NAME_GOODS_CATEGORY_Mobile_MEAN
# 153                  PREV_NAME_GOODS_CATEGORY_XNA_MEAN
# 154                     PREV_NAME_PORTFOLIO_Cards_MEAN
# 155                       PREV_NAME_PORTFOLIO_POS_MEAN
# 156                       PREV_NAME_PORTFOLIO_XNA_MEAN
# 157                PREV_NAME_PRODUCT_TYPE_walk-in_MEAN
# 158                 PREV_NAME_PRODUCT_TYPE_x-sell_MEAN
# 159             PREV_CHANNEL_TYPE_AP+ (Cash loan)_MEAN
# 160     PREV_CHANNEL_TYPE_Credit and cash offices_MEAN
# 161                       PREV_CHANNEL_TYPE_Stone_MEAN
# 162            PREV_NAME_SELLER_INDUSTRY_Clothing_MEAN
# 163        PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN
# 164        PREV_NAME_SELLER_INDUSTRY_Construction_MEAN
# 165  PREV_NAME_SELLER_INDUSTRY_Consumer electronics...
# 166           PREV_NAME_SELLER_INDUSTRY_Furniture_MEAN
# 167                 PREV_NAME_SELLER_INDUSTRY_XNA_MEAN
# 168                     PREV_NAME_YIELD_GROUP_XNA_MEAN
# 169                    PREV_NAME_YIELD_GROUP_high_MEAN
# 170              PREV_NAME_YIELD_GROUP_low_action_MEAN
# 171              PREV_NAME_YIELD_GROUP_low_normal_MEAN
# 172                  PREV_NAME_YIELD_GROUP_middle_MEAN
# 173          PREV_PRODUCT_COMBINATION_Card Street_MEAN
# 174                 PREV_PRODUCT_COMBINATION_Cash_MEAN
# 175    PREV_PRODUCT_COMBINATION_Cash Street: high_MEAN
# 176  PREV_PRODUCT_COMBINATION_Cash Street: middle_MEAN
# 177    PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN
# 178     PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN
# 179  PREV_PRODUCT_COMBINATION_Cash X-Sell: middle_MEAN
# 180  PREV_PRODUCT_COMBINATION_POS household without...
# 181  PREV_PRODUCT_COMBINATION_POS industry with int...
# 182  PREV_PRODUCT_COMBINATION_POS mobile with inter...
# 183                     APPROVED_RATE_DOWN_PAYMENT_MAX
# 184                    APPROVED_RATE_DOWN_PAYMENT_MEAN
# 185                         APPROVED_DAYS_DECISION_MIN
# 186                                             LSTM_4
# 187                                             LSTM_8
# 188                                            LSTM_10
# 189                                            LSTM_12
# 190                                            LSTM_14
# 191                                            LSTM_20
# 192                                            LSTM_21
# 193                                            LSTM_23
# 194                                            LSTM_25
# 195                                            LSTM_26
# 196                                            LSTM_27
# 197                                            LSTM_30
# 198                                            LSTM_31
# 199                                            LSTM_32
#
#                                       RFE_LR  \
# 0                                 SK_ID_CURR
# 1                       BURO_DAYS_CREDIT_MIN
# 2                       BURO_DAYS_CREDIT_MAX
# 3                      BURO_DAYS_CREDIT_MEAN
# 4                       BURO_DAYS_CREDIT_VAR
# 5               BURO_DAYS_CREDIT_ENDDATE_MIN
# 6               BURO_DAYS_CREDIT_ENDDATE_MAX
# 7              BURO_DAYS_CREDIT_ENDDATE_MEAN
# 8               BURO_DAYS_CREDIT_UPDATE_MEAN
# 9           BURO_AMT_CREDIT_MAX_OVERDUE_MEAN
# 10                   BURO_AMT_CREDIT_SUM_MAX
# 11                  BURO_AMT_CREDIT_SUM_MEAN
# 12                   BURO_AMT_CREDIT_SUM_SUM
# 13              BURO_AMT_CREDIT_SUM_DEBT_MAX
# 14             BURO_AMT_CREDIT_SUM_DEBT_MEAN
# 15              BURO_AMT_CREDIT_SUM_DEBT_SUM
# 16            BURO_AMT_CREDIT_SUM_LIMIT_MEAN
# 17             BURO_AMT_CREDIT_SUM_LIMIT_SUM
# 18               BURO_MONTHS_BALANCE_MIN_MIN
# 19             BURO_MONTHS_BALANCE_SIZE_MEAN
# 20              BURO_MONTHS_BALANCE_SIZE_SUM
# 21                    ACTIVE_DAYS_CREDIT_MIN
# 22                    ACTIVE_DAYS_CREDIT_MAX
# 23                   ACTIVE_DAYS_CREDIT_MEAN
# 24                    ACTIVE_DAYS_CREDIT_VAR
# 25            ACTIVE_DAYS_CREDIT_ENDDATE_MIN
# 26            ACTIVE_DAYS_CREDIT_ENDDATE_MAX
# 27           ACTIVE_DAYS_CREDIT_ENDDATE_MEAN
# 28            ACTIVE_DAYS_CREDIT_UPDATE_MEAN
# 29        ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN
# 30                 ACTIVE_AMT_CREDIT_SUM_MAX
# 31                ACTIVE_AMT_CREDIT_SUM_MEAN
# 32                 ACTIVE_AMT_CREDIT_SUM_SUM
# 33            ACTIVE_AMT_CREDIT_SUM_DEBT_MAX
# 34           ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN
# 35            ACTIVE_AMT_CREDIT_SUM_DEBT_SUM
# 36          ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN
# 37           ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM
# 38            ACTIVE_MONTHS_BALANCE_SIZE_SUM
# 39                    CLOSED_DAYS_CREDIT_MIN
# 40                    CLOSED_DAYS_CREDIT_MAX
# 41                   CLOSED_DAYS_CREDIT_MEAN
# 42                    CLOSED_DAYS_CREDIT_VAR
# 43            CLOSED_DAYS_CREDIT_ENDDATE_MIN
# 44            CLOSED_DAYS_CREDIT_ENDDATE_MAX
# 45           CLOSED_DAYS_CREDIT_ENDDATE_MEAN
# 46            CLOSED_DAYS_CREDIT_UPDATE_MEAN
# 47        CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN
# 48                 CLOSED_AMT_CREDIT_SUM_MAX
# 49                CLOSED_AMT_CREDIT_SUM_MEAN
# 50                 CLOSED_AMT_CREDIT_SUM_SUM
# 51            CLOSED_MONTHS_BALANCE_SIZE_SUM
# 52            NEW_RATIO_BURO_DAYS_CREDIT_VAR
# 53    NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MIN
# 54    NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MAX
# 55   NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MEAN
# 56         NEW_RATIO_BURO_AMT_CREDIT_SUM_MAX
# 57        NEW_RATIO_BURO_AMT_CREDIT_SUM_MEAN
# 58         NEW_RATIO_BURO_AMT_CREDIT_SUM_SUM
# 59                     CC_MONTHS_BALANCE_MIN
# 60                    CC_MONTHS_BALANCE_MEAN
# 61                     CC_MONTHS_BALANCE_SUM
# 62                     CC_MONTHS_BALANCE_VAR
# 63                        CC_AMT_BALANCE_MIN
# 64                        CC_AMT_BALANCE_MAX
# 65                       CC_AMT_BALANCE_MEAN
# 66                        CC_AMT_BALANCE_SUM
# 67            CC_AMT_CREDIT_LIMIT_ACTUAL_MIN
# 68            CC_AMT_CREDIT_LIMIT_ACTUAL_MAX
# 69           CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN
# 70            CC_AMT_CREDIT_LIMIT_ACTUAL_SUM
# 71           CC_AMT_DRAWINGS_ATM_CURRENT_SUM
# 72               CC_AMT_DRAWINGS_CURRENT_MAX
# 73              CC_AMT_DRAWINGS_CURRENT_MEAN
# 74               CC_AMT_DRAWINGS_CURRENT_SUM
# 75         CC_AMT_DRAWINGS_OTHER_CURRENT_SUM
# 76           CC_AMT_DRAWINGS_POS_CURRENT_SUM
# 77            CC_AMT_INST_MIN_REGULARITY_MIN
# 78            CC_AMT_INST_MIN_REGULARITY_MAX
# 79           CC_AMT_INST_MIN_REGULARITY_MEAN
# 80            CC_AMT_INST_MIN_REGULARITY_SUM
# 81            CC_AMT_INST_MIN_REGULARITY_VAR
# 82                CC_AMT_PAYMENT_CURRENT_SUM
# 83          CC_AMT_PAYMENT_TOTAL_CURRENT_MAX
# 84         CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN
# 85          CC_AMT_PAYMENT_TOTAL_CURRENT_SUM
# 86           CC_AMT_RECEIVABLE_PRINCIPAL_MIN
# 87           CC_AMT_RECEIVABLE_PRINCIPAL_MAX
# 88          CC_AMT_RECEIVABLE_PRINCIPAL_MEAN
# 89           CC_AMT_RECEIVABLE_PRINCIPAL_SUM
# 90           CC_AMT_RECEIVABLE_PRINCIPAL_VAR
# 91                      CC_AMT_RECIVABLE_MIN
# 92                      CC_AMT_RECIVABLE_MAX
# 93                     CC_AMT_RECIVABLE_MEAN
# 94                      CC_AMT_RECIVABLE_SUM
# 95                      CC_AMT_RECIVABLE_VAR
# 96               CC_AMT_TOTAL_RECEIVABLE_MIN
# 97               CC_AMT_TOTAL_RECEIVABLE_MAX
# 98              CC_AMT_TOTAL_RECEIVABLE_MEAN
# 99               CC_AMT_TOTAL_RECEIVABLE_SUM
# 100              CC_AMT_TOTAL_RECEIVABLE_VAR
# 101              CC_CNT_DRAWINGS_CURRENT_VAR
# 102         CC_CNT_INSTALMENT_MATURE_CUM_SUM
# 103         CC_CNT_INSTALMENT_MATURE_CUM_VAR
# 104                            CC_SK_DPD_MAX
# 105                            CC_SK_DPD_SUM
# 106                            CC_SK_DPD_VAR
# 107                        CC_SK_DPD_DEF_SUM
# 108                        CC_SK_DPD_DEF_VAR
# 109       CC_NAME_CONTRACT_STATUS_Active_SUM
# 110                                 CC_COUNT
# 111    INSTAL_NUM_INSTALMENT_VERSION_NUNIQUE
# 112                           INSTAL_DPD_MAX
# 113                           INSTAL_DPD_SUM
# 114                           INSTAL_DBD_MAX
# 115                          INSTAL_DBD_MEAN
# 116                           INSTAL_DBD_SUM
# 117                  INSTAL_PAYMENT_PERC_MAX
# 118                  INSTAL_PAYMENT_PERC_SUM
# 119                  INSTAL_PAYMENT_PERC_VAR
# 120                  INSTAL_PAYMENT_DIFF_MAX
# 121                 INSTAL_PAYMENT_DIFF_MEAN
# 122                  INSTAL_PAYMENT_DIFF_SUM
# 123                INSTAL_AMT_INSTALMENT_MAX
# 124               INSTAL_AMT_INSTALMENT_MEAN
# 125                INSTAL_AMT_INSTALMENT_SUM
# 126                   INSTAL_AMT_PAYMENT_MIN
# 127                   INSTAL_AMT_PAYMENT_MAX
# 128                  INSTAL_AMT_PAYMENT_MEAN
# 129                   INSTAL_AMT_PAYMENT_SUM
# 130            INSTAL_DAYS_ENTRY_PAYMENT_MAX
# 131           INSTAL_DAYS_ENTRY_PAYMENT_MEAN
# 132            INSTAL_DAYS_ENTRY_PAYMENT_SUM
# 133                             INSTAL_COUNT
# 134                   POS_MONTHS_BALANCE_MAX
# 135                  POS_MONTHS_BALANCE_MEAN
# 136                  POS_MONTHS_BALANCE_SIZE
# 137                           POS_SK_DPD_MAX
# 138                          POS_SK_DPD_MEAN
# 139                                POS_COUNT
# 140                     PREV_AMT_ANNUITY_MIN
# 141                     PREV_AMT_ANNUITY_MAX
# 142                    PREV_AMT_ANNUITY_MEAN
# 143                 PREV_AMT_APPLICATION_MIN
# 144                 PREV_AMT_APPLICATION_MAX
# 145                PREV_AMT_APPLICATION_MEAN
# 146                      PREV_AMT_CREDIT_MIN
# 147                      PREV_AMT_CREDIT_MAX
# 148                     PREV_AMT_CREDIT_MEAN
# 149                 PREV_APP_CREDIT_PERC_MIN
# 150                 PREV_APP_CREDIT_PERC_MAX
# 151                PREV_APP_CREDIT_PERC_MEAN
# 152                PREV_AMT_DOWN_PAYMENT_MIN
# 153                PREV_AMT_DOWN_PAYMENT_MAX
# 154               PREV_AMT_DOWN_PAYMENT_MEAN
# 155                 PREV_AMT_GOODS_PRICE_MIN
# 156                 PREV_AMT_GOODS_PRICE_MAX
# 157                PREV_AMT_GOODS_PRICE_MEAN
# 158         PREV_HOUR_APPR_PROCESS_START_MIN
# 159         PREV_HOUR_APPR_PROCESS_START_MAX
# 160        PREV_HOUR_APPR_PROCESS_START_MEAN
# 161                   PREV_DAYS_DECISION_MIN
# 162                   PREV_DAYS_DECISION_MAX
# 163                  PREV_DAYS_DECISION_MEAN
# 164                    PREV_CNT_PAYMENT_MEAN
# 165                     PREV_CNT_PAYMENT_SUM
# 166         PREV_CODE_REJECT_REASON_XAP_MEAN
# 167                 APPROVED_AMT_ANNUITY_MIN
# 168                 APPROVED_AMT_ANNUITY_MAX
# 169                APPROVED_AMT_ANNUITY_MEAN
# 170             APPROVED_AMT_APPLICATION_MIN
# 171             APPROVED_AMT_APPLICATION_MAX
# 172            APPROVED_AMT_APPLICATION_MEAN
# 173                  APPROVED_AMT_CREDIT_MIN
# 174                  APPROVED_AMT_CREDIT_MAX
# 175                 APPROVED_AMT_CREDIT_MEAN
# 176             APPROVED_APP_CREDIT_PERC_MIN
# 177             APPROVED_APP_CREDIT_PERC_MAX
# 178            APPROVED_APP_CREDIT_PERC_MEAN
# 179            APPROVED_AMT_DOWN_PAYMENT_MIN
# 180            APPROVED_AMT_DOWN_PAYMENT_MAX
# 181           APPROVED_AMT_DOWN_PAYMENT_MEAN
# 182             APPROVED_AMT_GOODS_PRICE_MIN
# 183             APPROVED_AMT_GOODS_PRICE_MAX
# 184            APPROVED_AMT_GOODS_PRICE_MEAN
# 185     APPROVED_HOUR_APPR_PROCESS_START_MIN
# 186     APPROVED_HOUR_APPR_PROCESS_START_MAX
# 187    APPROVED_HOUR_APPR_PROCESS_START_MEAN
# 188               APPROVED_DAYS_DECISION_MIN
# 189               APPROVED_DAYS_DECISION_MAX
# 190              APPROVED_DAYS_DECISION_MEAN
# 191                APPROVED_CNT_PAYMENT_MEAN
# 192                 APPROVED_CNT_PAYMENT_SUM
# 193                                   LSTM_4
# 194                                  LSTM_12
# 195                                  LSTM_21
# 196                                  LSTM_27
# 197                                  LSTM_30
# 198                                  LSTM_31
# 199                                  LSTM_32
#
#                                       RFE_RF  \
# 0                                 SK_ID_CURR
# 1                           AMT_INCOME_TOTAL
# 2                                 AMT_CREDIT
# 3                                AMT_ANNUITY
# 4                            AMT_GOODS_PRICE
# 5                 REGION_POPULATION_RELATIVE
# 6                                 DAYS_BIRTH
# 7                              DAYS_EMPLOYED
# 8                          DAYS_REGISTRATION
# 9                            DAYS_ID_PUBLISH
# 10                   HOUR_APPR_PROCESS_START
# 11                              EXT_SOURCE_2
# 12                            APARTMENTS_AVG
# 13                            LIVINGAREA_AVG
# 14                           APARTMENTS_MODE
# 15              YEARS_BEGINEXPLUATATION_MODE
# 16                           LIVINGAREA_MODE
# 17                           APARTMENTS_MEDI
# 18                           LIVINGAREA_MEDI
# 19                            TOTALAREA_MODE
# 20                  OBS_30_CNT_SOCIAL_CIRCLE
# 21                  OBS_60_CNT_SOCIAL_CIRCLE
# 22                    DAYS_LAST_PHONE_CHANGE
# 23                        DAYS_EMPLOYED_PERC
# 24                        INCOME_CREDIT_PERC
# 25                         INCOME_PER_PERSON
# 26                       ANNUITY_INCOME_PERC
# 27                              PAYMENT_RATE
# 28               NEW_CREDIT_TO_ANNUITY_RATIO
# 29                 NEW_CREDIT_TO_GOODS_RATIO
# 30                          NEW_INC_PER_CHLD
# 31                            NEW_INC_BY_ORG
# 32                  NEW_PHONE_TO_BIRTH_RATIO
# 33                 NEW_PHONE_TO_EMPLOY_RATIO
# 34                      BURO_DAYS_CREDIT_MIN
# 35                      BURO_DAYS_CREDIT_MAX
# 36                     BURO_DAYS_CREDIT_MEAN
# 37                      BURO_DAYS_CREDIT_VAR
# 38              BURO_DAYS_CREDIT_ENDDATE_MIN
# 39              BURO_DAYS_CREDIT_ENDDATE_MAX
# 40             BURO_DAYS_CREDIT_ENDDATE_MEAN
# 41              BURO_DAYS_CREDIT_UPDATE_MEAN
# 42          BURO_AMT_CREDIT_MAX_OVERDUE_MEAN
# 43                   BURO_AMT_CREDIT_SUM_MAX
# 44                  BURO_AMT_CREDIT_SUM_MEAN
# 45                   BURO_AMT_CREDIT_SUM_SUM
# 46              BURO_AMT_CREDIT_SUM_DEBT_MAX
# 47             BURO_AMT_CREDIT_SUM_DEBT_MEAN
# 48              BURO_AMT_CREDIT_SUM_DEBT_SUM
# 49            BURO_CREDIT_ACTIVE_Closed_MEAN
# 50                    ACTIVE_DAYS_CREDIT_MIN
# 51                    ACTIVE_DAYS_CREDIT_MAX
# 52                   ACTIVE_DAYS_CREDIT_MEAN
# 53                    ACTIVE_DAYS_CREDIT_VAR
# 54            ACTIVE_DAYS_CREDIT_ENDDATE_MIN
# 55            ACTIVE_DAYS_CREDIT_ENDDATE_MAX
# 56           ACTIVE_DAYS_CREDIT_ENDDATE_MEAN
# 57            ACTIVE_DAYS_CREDIT_UPDATE_MEAN
# 58        ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN
# 59                 ACTIVE_AMT_CREDIT_SUM_MAX
# 60                ACTIVE_AMT_CREDIT_SUM_MEAN
# 61                 ACTIVE_AMT_CREDIT_SUM_SUM
# 62            ACTIVE_AMT_CREDIT_SUM_DEBT_MAX
# 63           ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN
# 64            ACTIVE_AMT_CREDIT_SUM_DEBT_SUM
# 65                    CLOSED_DAYS_CREDIT_MIN
# 66                    CLOSED_DAYS_CREDIT_MAX
# 67                   CLOSED_DAYS_CREDIT_MEAN
# 68                    CLOSED_DAYS_CREDIT_VAR
# 69            CLOSED_DAYS_CREDIT_ENDDATE_MIN
# 70            CLOSED_DAYS_CREDIT_ENDDATE_MAX
# 71           CLOSED_DAYS_CREDIT_ENDDATE_MEAN
# 72            CLOSED_DAYS_CREDIT_UPDATE_MEAN
# 73                 CLOSED_AMT_CREDIT_SUM_MAX
# 74                CLOSED_AMT_CREDIT_SUM_MEAN
# 75                 CLOSED_AMT_CREDIT_SUM_SUM
# 76            NEW_RATIO_BURO_DAYS_CREDIT_MIN
# 77            NEW_RATIO_BURO_DAYS_CREDIT_MAX
# 78           NEW_RATIO_BURO_DAYS_CREDIT_MEAN
# 79    NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MIN
# 80    NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MAX
# 81   NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MEAN
# 82    NEW_RATIO_BURO_DAYS_CREDIT_UPDATE_MEAN
# 83         NEW_RATIO_BURO_AMT_CREDIT_SUM_MAX
# 84        NEW_RATIO_BURO_AMT_CREDIT_SUM_MEAN
# 85         NEW_RATIO_BURO_AMT_CREDIT_SUM_SUM
# 86              CC_CNT_DRAWINGS_CURRENT_MEAN
# 87               CC_CNT_DRAWINGS_CURRENT_VAR
# 88                            INSTAL_DPD_MAX
# 89                           INSTAL_DPD_MEAN
# 90                            INSTAL_DPD_SUM
# 91                            INSTAL_DBD_MAX
# 92                           INSTAL_DBD_MEAN
# 93                            INSTAL_DBD_SUM
# 94                  INSTAL_PAYMENT_PERC_MEAN
# 95                   INSTAL_PAYMENT_PERC_SUM
# 96                   INSTAL_PAYMENT_PERC_VAR
# 97                   INSTAL_PAYMENT_DIFF_MAX
# 98                  INSTAL_PAYMENT_DIFF_MEAN
# 99                   INSTAL_PAYMENT_DIFF_SUM
# 100                  INSTAL_PAYMENT_DIFF_VAR
# 101                INSTAL_AMT_INSTALMENT_MAX
# 102               INSTAL_AMT_INSTALMENT_MEAN
# 103                INSTAL_AMT_INSTALMENT_SUM
# 104                   INSTAL_AMT_PAYMENT_MIN
# 105                   INSTAL_AMT_PAYMENT_MAX
# 106                  INSTAL_AMT_PAYMENT_MEAN
# 107                   INSTAL_AMT_PAYMENT_SUM
# 108            INSTAL_DAYS_ENTRY_PAYMENT_MAX
# 109           INSTAL_DAYS_ENTRY_PAYMENT_MEAN
# 110            INSTAL_DAYS_ENTRY_PAYMENT_SUM
# 111                             INSTAL_COUNT
# 112                   POS_MONTHS_BALANCE_MAX
# 113                  POS_MONTHS_BALANCE_MEAN
# 114                  POS_MONTHS_BALANCE_SIZE
# 115                      POS_SK_DPD_DEF_MEAN
# 116     POS_NAME_CONTRACT_STATUS_Active_MEAN
# 117  POS_NAME_CONTRACT_STATUS_Completed_MEAN
# 118                                POS_COUNT
# 119                     PREV_AMT_ANNUITY_MIN
# 120                     PREV_AMT_ANNUITY_MAX
# 121                    PREV_AMT_ANNUITY_MEAN
# 122                 PREV_AMT_APPLICATION_MIN
# 123                 PREV_AMT_APPLICATION_MAX
# 124                PREV_AMT_APPLICATION_MEAN
# 125                      PREV_AMT_CREDIT_MIN
# 126                      PREV_AMT_CREDIT_MAX
# 127                     PREV_AMT_CREDIT_MEAN
# 128                 PREV_APP_CREDIT_PERC_MIN
# 129                 PREV_APP_CREDIT_PERC_MAX
# 130                PREV_APP_CREDIT_PERC_MEAN
# 131                 PREV_APP_CREDIT_PERC_VAR
# 132                PREV_AMT_DOWN_PAYMENT_MAX
# 133               PREV_AMT_DOWN_PAYMENT_MEAN
# 134                 PREV_AMT_GOODS_PRICE_MIN
# 135                 PREV_AMT_GOODS_PRICE_MAX
# 136                PREV_AMT_GOODS_PRICE_MEAN
# 137         PREV_HOUR_APPR_PROCESS_START_MIN
# 138         PREV_HOUR_APPR_PROCESS_START_MAX
# 139        PREV_HOUR_APPR_PROCESS_START_MEAN
# 140               PREV_RATE_DOWN_PAYMENT_MAX
# 141              PREV_RATE_DOWN_PAYMENT_MEAN
# 142                   PREV_DAYS_DECISION_MIN
# 143                   PREV_DAYS_DECISION_MAX
# 144                  PREV_DAYS_DECISION_MEAN
# 145                    PREV_CNT_PAYMENT_MEAN
# 146                     PREV_CNT_PAYMENT_SUM
# 147  PREV_NAME_CONTRACT_STATUS_Approved_MEAN
# 148   PREV_NAME_CONTRACT_STATUS_Refused_MEAN
# 149          PREV_NAME_PAYMENT_TYPE_XNA_MEAN
# 150          PREV_CODE_REJECT_REASON_HC_MEAN
# 151         PREV_CODE_REJECT_REASON_XAP_MEAN
# 152  PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN
# 153            PREV_NAME_TYPE_SUITE_nan_MEAN
# 154           PREV_NAME_YIELD_GROUP_XNA_MEAN
# 155          PREV_NAME_YIELD_GROUP_high_MEAN
# 156                 APPROVED_AMT_ANNUITY_MIN
# 157                 APPROVED_AMT_ANNUITY_MAX
# 158                APPROVED_AMT_ANNUITY_MEAN
# 159             APPROVED_AMT_APPLICATION_MIN
# 160             APPROVED_AMT_APPLICATION_MAX
# 161            APPROVED_AMT_APPLICATION_MEAN
# 162                  APPROVED_AMT_CREDIT_MIN
# 163                  APPROVED_AMT_CREDIT_MAX
# 164                 APPROVED_AMT_CREDIT_MEAN
# 165             APPROVED_APP_CREDIT_PERC_MIN
# 166             APPROVED_APP_CREDIT_PERC_MAX
# 167            APPROVED_APP_CREDIT_PERC_MEAN
# 168             APPROVED_APP_CREDIT_PERC_VAR
# 169            APPROVED_AMT_DOWN_PAYMENT_MAX
# 170           APPROVED_AMT_DOWN_PAYMENT_MEAN
# 171             APPROVED_AMT_GOODS_PRICE_MIN
# 172             APPROVED_AMT_GOODS_PRICE_MAX
# 173            APPROVED_AMT_GOODS_PRICE_MEAN
# 174     APPROVED_HOUR_APPR_PROCESS_START_MIN
# 175     APPROVED_HOUR_APPR_PROCESS_START_MAX
# 176    APPROVED_HOUR_APPR_PROCESS_START_MEAN
# 177           APPROVED_RATE_DOWN_PAYMENT_MAX
# 178          APPROVED_RATE_DOWN_PAYMENT_MEAN
# 179               APPROVED_DAYS_DECISION_MIN
# 180               APPROVED_DAYS_DECISION_MAX
# 181              APPROVED_DAYS_DECISION_MEAN
# 182                APPROVED_CNT_PAYMENT_MEAN
# 183                 APPROVED_CNT_PAYMENT_SUM
# 184                                   LSTM_3
# 185                                   LSTM_4
# 186                                   LSTM_8
# 187                                  LSTM_10
# 188                                  LSTM_12
# 189                                  LSTM_14
# 190                                  LSTM_19
# 191                                  LSTM_20
# 192                                  LSTM_21
# 193                                  LSTM_23
# 194                                  LSTM_25
# 195                                  LSTM_26
# 196                                  LSTM_27
# 197                                  LSTM_30
# 198                                  LSTM_31
# 199                                  LSTM_32
#
#                                           embedding_LR  \
# 0                                   NAME_CONTRACT_TYPE
# 1                                         FLAG_OWN_CAR
# 2                                           AMT_CREDIT
# 3                                          AMT_ANNUITY
# 4                           REGION_POPULATION_RELATIVE
# 5                                           DAYS_BIRTH
# 6                                        DAYS_EMPLOYED
# 7                                    DAYS_REGISTRATION
# 8                                      DAYS_ID_PUBLISH
# 9                                      CNT_FAM_MEMBERS
# 10                                REGION_RATING_CLIENT
# 11                         REGION_RATING_CLIENT_W_CITY
# 12                             HOUR_APPR_PROCESS_START
# 13                                        EXT_SOURCE_2
# 14                                       FLOORSMAX_AVG
# 15                                     APARTMENTS_MODE
# 16                        YEARS_BEGINEXPLUATATION_MODE
# 17                                      ELEVATORS_MODE
# 18                                      ENTRANCES_MODE
# 19                                     LIVINGAREA_MODE
# 20                                       LANDAREA_MEDI
# 21                                      TOTALAREA_MODE
# 22                            DEF_30_CNT_SOCIAL_CIRCLE
# 23                            DEF_60_CNT_SOCIAL_CIRCLE
# 24                              DAYS_LAST_PHONE_CHANGE
# 25                                     FLAG_DOCUMENT_3
# 26                                     FLAG_DOCUMENT_8
# 27                           AMT_REQ_CREDIT_BUREAU_MON
# 28                          AMT_REQ_CREDIT_BUREAU_YEAR
# 29                                  DAYS_EMPLOYED_PERC
# 30                                  INCOME_CREDIT_PERC
# 31                                 ANNUITY_INCOME_PERC
# 32                                        PAYMENT_RATE
# 33                         NEW_CREDIT_TO_ANNUITY_RATIO
# 34                           NEW_CREDIT_TO_GOODS_RATIO
# 35                                     NEW_DOC_IND_STD
# 36                                      NEW_INC_BY_ORG
# 37                            NEW_PHONE_TO_BIRTH_RATIO
# 38                           NEW_PHONE_TO_EMPLOY_RATIO
# 39                                       CODE_GENDER_F
# 40                          NAME_INCOME_TYPE_Pensioner
# 41                            NAME_INCOME_TYPE_Working
# 42                NAME_EDUCATION_TYPE_Higher education
# 43             NAME_FAMILY_STATUS_Single / not married
# 44                 NAME_HOUSING_TYPE_House / apartment
# 45                          OCCUPATION_TYPE_Core staff
# 46                               ORGANIZATION_TYPE_XNA
# 47                                    HOUSETYPE_MODE_0
# 48                                WALLSMATERIAL_MODE_0
# 49                                BURO_DAYS_CREDIT_MIN
# 50                               BURO_DAYS_CREDIT_MEAN
# 51                                BURO_DAYS_CREDIT_VAR
# 52                        BURO_DAYS_CREDIT_ENDDATE_MIN
# 53                       BURO_DAYS_CREDIT_ENDDATE_MEAN
# 54                        BURO_DAYS_CREDIT_UPDATE_MEAN
# 55                       BURO_AMT_CREDIT_SUM_DEBT_MEAN
# 56                        BURO_AMT_CREDIT_SUM_DEBT_SUM
# 57                       BURO_MONTHS_BALANCE_SIZE_MEAN
# 58                      BURO_CREDIT_ACTIVE_Active_MEAN
# 59                      BURO_CREDIT_ACTIVE_Closed_MEAN
# 60                      BURO_CREDIT_TYPE_Car loan_MEAN
# 61                   BURO_CREDIT_TYPE_Credit card_MEAN
# 62                      BURO_CREDIT_TYPE_Mortgage_MEAN
# 63                             BURO_STATUS_1_MEAN_MEAN
# 64                              ACTIVE_DAYS_CREDIT_MIN
# 65                              ACTIVE_DAYS_CREDIT_MAX
# 66                             ACTIVE_DAYS_CREDIT_MEAN
# 67                              ACTIVE_DAYS_CREDIT_VAR
# 68                      ACTIVE_DAYS_CREDIT_ENDDATE_MIN
# 69                      ACTIVE_DAYS_CREDIT_ENDDATE_MAX
# 70                     ACTIVE_DAYS_CREDIT_ENDDATE_MEAN
# 71                  ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN
# 72                           ACTIVE_AMT_CREDIT_SUM_SUM
# 73                    ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN
# 74                              CLOSED_DAYS_CREDIT_MIN
# 75                              CLOSED_DAYS_CREDIT_MAX
# 76                      CLOSED_DAYS_CREDIT_ENDDATE_MIN
# 77                      CLOSED_DAYS_CREDIT_ENDDATE_MAX
# 78                      CLOSED_MONTHS_BALANCE_SIZE_SUM
# 79              NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MAX
# 80                                  CC_AMT_BALANCE_MAX
# 81                                 CC_AMT_BALANCE_MEAN
# 82                                  CC_AMT_BALANCE_VAR
# 83                      CC_AMT_CREDIT_LIMIT_ACTUAL_MIN
# 84                      CC_AMT_CREDIT_LIMIT_ACTUAL_MAX
# 85                     CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN
# 86                      CC_AMT_CREDIT_LIMIT_ACTUAL_SUM
# 87                      CC_AMT_CREDIT_LIMIT_ACTUAL_VAR
# 88                     CC_AMT_DRAWINGS_ATM_CURRENT_SUM
# 89                         CC_AMT_DRAWINGS_CURRENT_MAX
# 90                   CC_AMT_DRAWINGS_OTHER_CURRENT_SUM
# ...
# 63           ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN
# 64            ACTIVE_AMT_CREDIT_SUM_DEBT_SUM
# 65                    CLOSED_DAYS_CREDIT_MIN
# 66                    CLOSED_DAYS_CREDIT_MAX
# 67                   CLOSED_DAYS_CREDIT_MEAN
# 68                    CLOSED_DAYS_CREDIT_VAR
# 69            CLOSED_DAYS_CREDIT_ENDDATE_MIN
# 70            CLOSED_DAYS_CREDIT_ENDDATE_MAX
# 71           CLOSED_DAYS_CREDIT_ENDDATE_MEAN
# 72            CLOSED_DAYS_CREDIT_UPDATE_MEAN
# 73                 CLOSED_AMT_CREDIT_SUM_MAX
# 74                CLOSED_AMT_CREDIT_SUM_MEAN
# 75                 CLOSED_AMT_CREDIT_SUM_SUM
# 76            NEW_RATIO_BURO_DAYS_CREDIT_MIN
# 77            NEW_RATIO_BURO_DAYS_CREDIT_MAX
# 78           NEW_RATIO_BURO_DAYS_CREDIT_MEAN
# 79            NEW_RATIO_BURO_DAYS_CREDIT_VAR
# 80    NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MIN
# 81    NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MAX
# 82   NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MEAN
# 83    NEW_RATIO_BURO_DAYS_CREDIT_UPDATE_MEAN
# 84         NEW_RATIO_BURO_AMT_CREDIT_SUM_MAX
# 85        NEW_RATIO_BURO_AMT_CREDIT_SUM_MEAN
# 86         NEW_RATIO_BURO_AMT_CREDIT_SUM_SUM
# 87                            INSTAL_DPD_MAX
# 88                           INSTAL_DPD_MEAN
# 89                            INSTAL_DPD_SUM
# 90                            INSTAL_DBD_MAX
# 91                           INSTAL_DBD_MEAN
# 92                            INSTAL_DBD_SUM
# 93                  INSTAL_PAYMENT_PERC_MEAN
# 94                   INSTAL_PAYMENT_PERC_SUM
# 95                   INSTAL_PAYMENT_PERC_VAR
# 96                   INSTAL_PAYMENT_DIFF_MAX
# 97                  INSTAL_PAYMENT_DIFF_MEAN
# 98                   INSTAL_PAYMENT_DIFF_SUM
# 99                   INSTAL_PAYMENT_DIFF_VAR
# 100                INSTAL_AMT_INSTALMENT_MAX
# 101               INSTAL_AMT_INSTALMENT_MEAN
# 102                INSTAL_AMT_INSTALMENT_SUM
# 103                   INSTAL_AMT_PAYMENT_MIN
# 104                   INSTAL_AMT_PAYMENT_MAX
# 105                  INSTAL_AMT_PAYMENT_MEAN
# 106                   INSTAL_AMT_PAYMENT_SUM
# 107            INSTAL_DAYS_ENTRY_PAYMENT_MAX
# 108           INSTAL_DAYS_ENTRY_PAYMENT_MEAN
# 109            INSTAL_DAYS_ENTRY_PAYMENT_SUM
# 110                             INSTAL_COUNT
# 111                   POS_MONTHS_BALANCE_MAX
# 112                  POS_MONTHS_BALANCE_MEAN
# 113                  POS_MONTHS_BALANCE_SIZE
# 114                      POS_SK_DPD_DEF_MEAN
# 115     POS_NAME_CONTRACT_STATUS_Active_MEAN
# 116  POS_NAME_CONTRACT_STATUS_Completed_MEAN
# 117     POS_NAME_CONTRACT_STATUS_Signed_MEAN
# 118                                POS_COUNT
# 119                     PREV_AMT_ANNUITY_MIN
# 120                     PREV_AMT_ANNUITY_MAX
# 121                    PREV_AMT_ANNUITY_MEAN
# 122                 PREV_AMT_APPLICATION_MIN
# 123                 PREV_AMT_APPLICATION_MAX
# 124                PREV_AMT_APPLICATION_MEAN
# 125                      PREV_AMT_CREDIT_MIN
# 126                      PREV_AMT_CREDIT_MAX
# 127                     PREV_AMT_CREDIT_MEAN
# 128                 PREV_APP_CREDIT_PERC_MIN
# 129                 PREV_APP_CREDIT_PERC_MAX
# 130                PREV_APP_CREDIT_PERC_MEAN
# 131                 PREV_APP_CREDIT_PERC_VAR
# 132                PREV_AMT_DOWN_PAYMENT_MAX
# 133               PREV_AMT_DOWN_PAYMENT_MEAN
# 134                 PREV_AMT_GOODS_PRICE_MIN
# 135                 PREV_AMT_GOODS_PRICE_MAX
# 136                PREV_AMT_GOODS_PRICE_MEAN
# 137         PREV_HOUR_APPR_PROCESS_START_MIN
# 138         PREV_HOUR_APPR_PROCESS_START_MAX
# 139        PREV_HOUR_APPR_PROCESS_START_MEAN
# 140               PREV_RATE_DOWN_PAYMENT_MAX
# 141              PREV_RATE_DOWN_PAYMENT_MEAN
# 142                   PREV_DAYS_DECISION_MIN
# 143                   PREV_DAYS_DECISION_MAX
# 144                  PREV_DAYS_DECISION_MEAN
# 145                    PREV_CNT_PAYMENT_MEAN
# 146                     PREV_CNT_PAYMENT_SUM
# 147  PREV_NAME_CONTRACT_STATUS_Approved_MEAN
# 148   PREV_NAME_CONTRACT_STATUS_Refused_MEAN
# 149          PREV_NAME_PAYMENT_TYPE_XNA_MEAN
# 150          PREV_CODE_REJECT_REASON_HC_MEAN
# 151         PREV_CODE_REJECT_REASON_XAP_MEAN
# 152  PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN
# 153            PREV_NAME_TYPE_SUITE_nan_MEAN
# 154             PREV_NAME_PORTFOLIO_XNA_MEAN
# 155          PREV_NAME_YIELD_GROUP_high_MEAN
# 156                 APPROVED_AMT_ANNUITY_MIN
# 157                 APPROVED_AMT_ANNUITY_MAX
# 158                APPROVED_AMT_ANNUITY_MEAN
# 159             APPROVED_AMT_APPLICATION_MIN
# 160             APPROVED_AMT_APPLICATION_MAX
# 161            APPROVED_AMT_APPLICATION_MEAN
# 162                  APPROVED_AMT_CREDIT_MIN
# 163                  APPROVED_AMT_CREDIT_MAX
# 164                 APPROVED_AMT_CREDIT_MEAN
# 165             APPROVED_APP_CREDIT_PERC_MIN
# 166             APPROVED_APP_CREDIT_PERC_MAX
# 167            APPROVED_APP_CREDIT_PERC_MEAN
# 168             APPROVED_APP_CREDIT_PERC_VAR
# 169            APPROVED_AMT_DOWN_PAYMENT_MAX
# 170           APPROVED_AMT_DOWN_PAYMENT_MEAN
# 171             APPROVED_AMT_GOODS_PRICE_MIN
# 172             APPROVED_AMT_GOODS_PRICE_MAX
# 173            APPROVED_AMT_GOODS_PRICE_MEAN
# 174     APPROVED_HOUR_APPR_PROCESS_START_MIN
# 175     APPROVED_HOUR_APPR_PROCESS_START_MAX
# 176    APPROVED_HOUR_APPR_PROCESS_START_MEAN
# 177           APPROVED_RATE_DOWN_PAYMENT_MAX
# 178          APPROVED_RATE_DOWN_PAYMENT_MEAN
# 179               APPROVED_DAYS_DECISION_MIN
# 180               APPROVED_DAYS_DECISION_MAX
# 181              APPROVED_DAYS_DECISION_MEAN
# 182                APPROVED_CNT_PAYMENT_MEAN
# 183                 APPROVED_CNT_PAYMENT_SUM
# 184                                   LSTM_3
# 185                                   LSTM_4
# 186                                   LSTM_8
# 187                                  LSTM_10
# 188                                  LSTM_12
# 189                                  LSTM_14
# 190                                  LSTM_19
# 191                                  LSTM_20
# 192                                  LSTM_21
# 193                                  LSTM_23
# 194                                  LSTM_25
# 195                                  LSTM_26
# 196                                  LSTM_27
# 197                                  LSTM_30
# 198                                  LSTM_31
# 199                                  LSTM_32
#
#                                  combination
# 0                    PREV_DAYS_DECISION_MEAN
# 1                      PREV_CNT_PAYMENT_MEAN
# 2                                  POS_COUNT
# 3                                    LSTM_32
# 4                                    LSTM_31
# 5                                    LSTM_27
# 6                                    LSTM_21
# 7             INSTAL_DAYS_ENTRY_PAYMENT_MEAN
# 8                     CLOSED_DAYS_CREDIT_MIN
# 9                     CLOSED_DAYS_CREDIT_MAX
# 10                      BURO_DAYS_CREDIT_VAR
# 11                      BURO_DAYS_CREDIT_MIN
# 12                     BURO_DAYS_CREDIT_MEAN
# 13                APPROVED_DAYS_DECISION_MIN
# 14              YEARS_BEGINEXPLUATATION_MODE
# 15                            TOTALAREA_MODE
# 16                REGION_POPULATION_RELATIVE
# 17               PREV_RATE_DOWN_PAYMENT_MEAN
# 18    PREV_NAME_CONTRACT_STATUS_Refused_MEAN
# 19                    PREV_DAYS_DECISION_MIN
# 20          PREV_CODE_REJECT_REASON_XAP_MEAN
# 21           PREV_CODE_REJECT_REASON_HC_MEAN
# 22                      PREV_CNT_PAYMENT_SUM
# 23                     PREV_AMT_ANNUITY_MEAN
# 24                   POS_MONTHS_BALANCE_SIZE
# 25                   POS_MONTHS_BALANCE_MEAN
# 26                  NEW_PHONE_TO_BIRTH_RATIO
# 27                            NEW_INC_BY_ORG
# 28                                    LSTM_8
# 29                                    LSTM_4
# 30                                   LSTM_30
# 31                                   LSTM_26
# 32                                   LSTM_25
# 33                                   LSTM_23
# 34                                   LSTM_20
# 35                                   LSTM_14
# 36                                   LSTM_12
# 37                                   LSTM_10
# 38                           LIVINGAREA_MODE
# 39                   INSTAL_PAYMENT_DIFF_SUM
# 40                  INSTAL_PAYMENT_DIFF_MEAN
# 41                   INSTAL_PAYMENT_DIFF_MAX
# 42                            INSTAL_DBD_SUM
# 43             INSTAL_DAYS_ENTRY_PAYMENT_SUM
# 44                              EXT_SOURCE_2
# 45                    DAYS_LAST_PHONE_CHANGE
# 46                           DAYS_ID_PUBLISH
# 47                        DAYS_EMPLOYED_PERC
# 48                                DAYS_BIRTH
# 49                    CLOSED_DAYS_CREDIT_VAR
# 50                   CLOSED_DAYS_CREDIT_MEAN
# 51            CLOSED_DAYS_CREDIT_ENDDATE_MIN
# 52               CC_CNT_DRAWINGS_CURRENT_VAR
# 53              BURO_DAYS_CREDIT_UPDATE_MEAN
# 54                      BURO_DAYS_CREDIT_MAX
# 55              BURO_DAYS_CREDIT_ENDDATE_MIN
# 56             BURO_DAYS_CREDIT_ENDDATE_MEAN
# 57            BURO_CREDIT_ACTIVE_Closed_MEAN
# 58            APPROVED_RATE_DOWN_PAYMENT_MAX
# 59               APPROVED_DAYS_DECISION_MEAN
# 60             APPROVED_AMT_GOODS_PRICE_MEAN
# 61                 APPROVED_AMT_ANNUITY_MEAN
# 62                  APPROVED_AMT_ANNUITY_MAX
# 63                                AMT_CREDIT
# 64                    ACTIVE_DAYS_CREDIT_MIN
# 65                   ACTIVE_DAYS_CREDIT_MEAN
# 66                    ACTIVE_DAYS_CREDIT_MAX
# 67           ACTIVE_DAYS_CREDIT_ENDDATE_MEAN
# 68            ACTIVE_DAYS_CREDIT_ENDDATE_MAX
# 69                PREV_RATE_DOWN_PAYMENT_MAX
# 70           PREV_NAME_YIELD_GROUP_high_MEAN
# 71             PREV_NAME_TYPE_SUITE_nan_MEAN
# 72           PREV_NAME_PAYMENT_TYPE_XNA_MEAN
# 73   PREV_NAME_CONTRACT_STATUS_Approved_MEAN
# 74                  PREV_APP_CREDIT_PERC_MIN
# 75                 PREV_AMT_GOODS_PRICE_MEAN
# 76                       PREV_AMT_CREDIT_MAX
# 77                  PREV_AMT_APPLICATION_MIN
# 78                  PREV_AMT_APPLICATION_MAX
# 79                      PREV_AMT_ANNUITY_MIN
# 80                    POS_MONTHS_BALANCE_MAX
# 81    NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MAX
# 82                 NEW_PHONE_TO_EMPLOY_RATIO
# 83                 NEW_CREDIT_TO_GOODS_RATIO
# 84               NEW_CREDIT_TO_ANNUITY_RATIO
# 85                                   LSTM_19
# 86                           LIVINGAREA_MEDI
# 87                            LIVINGAREA_AVG
# 88                            INSTAL_DPD_MAX
# 89                           INSTAL_DBD_MEAN
# 90                            INSTAL_DBD_MAX
# 91             INSTAL_DAYS_ENTRY_PAYMENT_MAX
# 92                              INSTAL_COUNT
# 93                    INSTAL_AMT_PAYMENT_SUM
# 94                    INSTAL_AMT_PAYMENT_MIN
# 95                   INSTAL_AMT_PAYMENT_MEAN
# 96                    INSTAL_AMT_PAYMENT_MAX
# 97                         DAYS_REGISTRATION
# 98                             DAYS_EMPLOYED
# 99            CLOSED_DAYS_CREDIT_UPDATE_MEAN
# 100           CLOSED_DAYS_CREDIT_ENDDATE_MAX
# 101              CC_AMT_TOTAL_RECEIVABLE_VAR
# 102           CC_AMT_INST_MIN_REGULARITY_VAR
# 103          CC_AMT_INST_MIN_REGULARITY_MEAN
# 104              CC_AMT_DRAWINGS_CURRENT_MAX
# 105                      CC_AMT_BALANCE_MEAN
# 106                       CC_AMT_BALANCE_MAX
# 107            BURO_MONTHS_BALANCE_SIZE_MEAN
# 108             BURO_DAYS_CREDIT_ENDDATE_MAX
# 109           BURO_CREDIT_ACTIVE_Active_MEAN
# 110             BURO_AMT_CREDIT_SUM_DEBT_SUM
# 111            BURO_AMT_CREDIT_SUM_DEBT_MEAN
# 112          APPROVED_RATE_DOWN_PAYMENT_MEAN
# 113     APPROVED_HOUR_APPR_PROCESS_START_MIN
# 114     APPROVED_HOUR_APPR_PROCESS_START_MAX
# 115               APPROVED_DAYS_DECISION_MAX
# 116                 APPROVED_CNT_PAYMENT_SUM
# 117            APPROVED_APP_CREDIT_PERC_MEAN
# 118             APPROVED_AMT_GOODS_PRICE_MAX
# 119           APPROVED_AMT_DOWN_PAYMENT_MEAN
# 120            APPROVED_AMT_DOWN_PAYMENT_MAX
# 121                  APPROVED_AMT_CREDIT_MAX
# 122             APPROVED_AMT_APPLICATION_MIN
# 123            APPROVED_AMT_APPLICATION_MEAN
# 124             APPROVED_AMT_APPLICATION_MAX
# 125                          APARTMENTS_MODE
# 126                          AMT_GOODS_PRICE
# 127                   ACTIVE_DAYS_CREDIT_VAR
# 128           ACTIVE_DAYS_CREDIT_UPDATE_MEAN
# 129           ACTIVE_DAYS_CREDIT_ENDDATE_MIN
# 130                ACTIVE_AMT_CREDIT_SUM_SUM
# 131       ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 150
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199

# %%
all_dataframe_select.to_csv("C:/data/processing_data/dataset/all_dataframe_select.csv")

# %%
# all_data_train.to_csv("C:/data/processing_data/dataset/all_data_train.csv")
# all_data_val.to_csv("C:/data/processing_data/dataset/all_data_val.csv")
# all_data_test.to_csv("C:/data/processing_data/dataset/all_data_test.csv")

# %% [markdown]
# # 读取特征选择结果

# %%
all_dataframe_select = pd.read_csv("C:/data/processing_data/dataset/all_dataframe_select.csv")

# %%
# 去特征选择后的数据
combination_feature = [name for name in all_dataframe_select['combination'].tolist() if len(name) > 2] # >2 过滤掉空字符
combination_feature.append("TARGET")

# %%
select_combination_train = all_data_train.loc[:, combination_feature]
select_combination_train
# Out:
#         PREV_DAYS_DECISION_MEAN  PREV_CNT_PAYMENT_MEAN  POS_COUNT   LSTM_32  \
# 87690                  -789.500              29.000000       17.0  0.996582
# 161396                 -655.000               6.000000        7.0  0.780762
# 156427                 -235.875              11.335938       12.0  0.786621
# 240569                -1065.000              21.000000       25.0  0.812012
# 89697                  -190.000               8.000000       11.0  0.538574
# ...                         ...                    ...        ...       ...
# 221162                 -895.000              36.000000       32.0  1.241211
# 110976                -1421.000              13.664062       62.0  0.754395
# 79405                  -618.000              24.000000       20.0  0.927246
# 290387                -1263.000              19.000000       75.0  0.899414
# 4645                  -1450.000              14.000000       51.0  0.931641
#
#          LSTM_31   LSTM_27   LSTM_21  INSTAL_DAYS_ENTRY_PAYMENT_MEAN  \
# 87690   1.125977  1.572266  1.404297                       -1880.000
# 161396  0.662109  0.963867  0.953125                        -560.000
# 156427  0.630859  0.898926  0.912109                        -221.750
# 240569  0.833008  1.385742  1.238281                       -1365.000
# 89697   0.262695  0.626465  0.589355                        -199.125
# ...          ...       ...       ...                             ...
# 221162  1.194336  1.482422  1.340820                        -739.500
# 110976  0.833008  1.148438  1.016602                       -1350.000
# 79405   0.735352  0.960449  1.041992                        -309.250
# 290387  0.966797  1.309570  1.247070                        -968.500
# 4645    0.851562  1.328125  1.224609                       -1178.000
#
#         CLOSED_DAYS_CREDIT_MIN  CLOSED_DAYS_CREDIT_MAX  ...  \
# 87690                  -2276.0                  -319.0  ...
# 161396                     0.0                     0.0  ...
# 156427                     0.0                     0.0  ...
# 240569                 -1684.0                  -896.0  ...
# 89697                      0.0                     0.0  ...
# ...                        ...                     ...  ...
# 221162                 -1785.0                  -692.0  ...
# 110976                 -1093.0                  -119.0  ...
# 79405                  -1851.0                  -188.0  ...
# 290387                     0.0                     0.0  ...
# 4645                   -2804.0                  -363.0  ...
#
#         APPROVED_AMT_APPLICATION_MEAN  APPROVED_AMT_APPLICATION_MAX  \
# 87690                   329150.250000                      450000.0
# 161396                  170955.000000                      170955.0
# 156427                  106645.500000                      130050.0
# 240569                   88106.625000                      180000.0
# 89697                    66813.750000                       70906.5
# ...                               ...                           ...
# 221162                  998741.250000                     1800000.0
# 110976                  221710.203125                      976500.0
# 79405                   531000.000000                      531000.0
# 290387                  376023.375000                     1192500.0
# 4645                    226666.125000                      900000.0
#
#         APARTMENTS_MODE  AMT_GOODS_PRICE  ACTIVE_DAYS_CREDIT_VAR  \
# 87690          0.126953        -0.225708            1.153778e+06
# 161396        -0.593262         1.587891            0.000000e+00
# 156427         2.609375         0.103027            0.000000e+00
# 240569         0.026871        -1.174805            8.094434e+04
# 89697         -0.593262        -0.201294            0.000000e+00
# ...                 ...              ...                     ...
# 221162         0.204102         1.600586            2.959947e+05
# 110976        -0.039703         0.370850            4.018944e+05
# 79405         -0.593262        -0.664062            9.417800e+04
# 290387        -0.593262         0.492676            0.000000e+00
# 4645          -0.593262         0.370850            6.331442e+05
#
#         ACTIVE_DAYS_CREDIT_UPDATE_MEAN  ACTIVE_DAYS_CREDIT_ENDDATE_MIN  \
# 87690                      -167.500000                         -2320.0
# 161396                        0.000000                             0.0
# 156427                        0.000000                             0.0
# 240569                      -24.671875                            94.0
# 89697                         0.000000                             0.0
# ...                                ...                             ...
# 221162                     -351.000000                           559.0
# 110976                      -19.328125                          -188.0
# 79405                      -543.500000                             0.0
# 290387                       -5.000000                          6644.0
# 4645                       -198.000000                         -1363.0
#
#         ACTIVE_AMT_CREDIT_SUM_SUM  ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN  TARGET
# 87690                    787788.0                            0.000000       0
# 161396                        0.0                            0.000000       0
# 156427                        0.0                            0.000000       0
# 240569                  1237500.0                            0.000000       0
# 89697                         0.0                            0.000000       0
# ...                           ...                                 ...     ...
# 221162                  5265000.0                         5880.720215       0
# 110976                  1268550.0                            0.000000       0
# 79405                    137254.5                         1350.000000       0
# 290387                   360000.0                         7429.500000       0
# 4645                     383319.0                         5565.600098       0
#
# [246009 rows x 133 columns]

# %%
select_combination_train.shape
# Out:
# (246009, 133)

# %%
# all_data_val = pd.read_csv("C:/data/processing_data/dataset/all_data_val.csv")
select_combination_val = all_data_val.loc[:, combination_feature]

# %%
select_combination_val.shape
# Out:
# (30751, 133)

# %%
# all_data_test = pd.read_csv("C:/data/processing_data/dataset/all_data_test.csv")
select_combination_test = all_data_test.loc[:, combination_feature]

# %%
select_combination_test.shape
# Out:
# (30751, 133)

# %%
select_combination_train_X = select_combination_train.drop(["TARGET"], axis = 1)
select_combination_train_y = select_combination_train["TARGET"]
select_combination_train_X.shape
# Out:
# (246009, 132)

# %%
import imblearn
from imblearn.combine import SMOTETomek
start = time.time()
smt.fit(select_combination_train_X, select_combination_train_y)
X_train_resample, y_train_resample = smt.fit_resample(select_combination_train_X, select_combination_train_y)
end = time.time()
print("综合采样时间：", end-start)
# Out:
# 综合采样时间：8420.995375156402588

# %% [markdown]
# SMOTETomek：先使用过采样，扩大样本后再对处在胶着状态的点用 Tomek Link 法进行删除，有时候甚至连 Tomek Link 都不用，直接把离得近的对全部删除，因为在进行过采样后，0 和 1 的样本量已经达到了 1：1。

# %%
X_train_resample.shape
# Out:
# (452270, 132)

# %%
data = pd.concat([X_train_resample,y_train_resample], axis = 1)

# %%
# 保留训练集SMOTETomek后的结果
data.to_csv("C:/data/processing_data/dataset/all_train_resample.csv")

# %%
data.head(10)
# Out:
#    PREV_DAYS_DECISION_MEAN  PREV_CNT_PAYMENT_MEAN  POS_COUNT   LSTM_32  \
# 0                 -789.500              29.000000       17.0  0.996582
# 1                 -655.000               6.000000        7.0  0.780762
# 2                 -235.875              11.335938       12.0  0.786621
# 3                -1065.000              21.000000       25.0  0.812012
# 4                 -190.000               8.000000       11.0  0.538574
# 5                 -208.000               6.000000        7.0  1.203125
# 6                -2070.000               9.664062       30.0  1.090820
# 7                 -765.500              15.000000       17.0  0.859863
# 8                 -939.500               7.332031       26.0  0.768555
# 9                -1551.000              24.000000       13.0  0.674316
#
#     LSTM_31   LSTM_27   LSTM_21  INSTAL_DAYS_ENTRY_PAYMENT_MEAN  \
# 0  1.125977  1.572266  1.404297                      -1880.0000
# 1  0.662109  0.963867  0.953125                       -560.0000
# 2  0.630859  0.898926  0.912109                       -221.7500
# 3  0.833008  1.385742  1.238281                      -1365.0000
# 4  0.262695  0.626465  0.589355                       -199.1250
# 5  1.353516  1.355469  1.292969                       -112.8125
# 6  1.101562  1.563477  1.451172                      -1551.0000
# 7  0.748535  0.966797  1.017578                       -602.0000
# 8  0.809570  1.185547  1.091797                       -853.5000
# 9  0.700684  1.009766  1.008789                      -1367.0000
#
#    CLOSED_DAYS_CREDIT_MIN  CLOSED_DAYS_CREDIT_MAX  ...  \
# 0                 -2276.0                  -319.0  ...
# 1                     0.0                     0.0  ...
# 2                     0.0                     0.0  ...
# 3                 -1684.0                  -896.0  ...
# 4                     0.0                     0.0  ...
# 5                     0.0                     0.0  ...
# 6                 -2630.0                  -317.0  ...
# 7                 -1524.0                 -1014.0  ...
# 8                  -961.0                  -882.0  ...
# 9                 -2592.0                  -567.0  ...
#
#    APPROVED_AMT_APPLICATION_MEAN  APPROVED_AMT_APPLICATION_MAX  \
# 0                  329150.250000                 450000.000000
# 1                  170955.000000                 170955.000000
# 2                  106645.500000                 130050.000000
# 3                   88106.625000                 180000.000000
# 4                   66813.750000                  70906.500000
# 5                  129600.000000                 129600.000000
# 6                  151127.093750                 495000.000000
# 7                   94050.000000                 157500.000000
# 8                   68280.000000                  90000.000000
# 9                  171343.796875                 171343.796875
#
#    APARTMENTS_MODE  AMT_GOODS_PRICE  ACTIVE_DAYS_CREDIT_VAR  \
# 0         0.126953        -0.225708            1.153778e+06
# 1        -0.593262         1.587891            0.000000e+00
# 2         2.609375         0.103027            0.000000e+00
# 3         0.026871        -1.174805            8.094434e+04
# 4        -0.593262        -0.201294            0.000000e+00
# 5        -0.150391         3.414062            0.000000e+00
# 6         0.292236         0.370850            2.690333e+03
# 7        -0.593262        -0.603027            4.500000e+00
# 8        -0.593262        -1.174805            0.000000e+00
# 9        -0.593262        -0.237793            3.960500e+05
#
#    ACTIVE_DAYS_CREDIT_UPDATE_MEAN  ACTIVE_DAYS_CREDIT_ENDDATE_MIN  \
# 0                     -167.500000                         -2320.0
# 1                        0.000000                             0.0
# 2                        0.000000                             0.0
# 3                      -24.671875                            94.0
# 4                        0.000000                             0.0
# 5                        0.000000                             0.0
# 6                      -20.671875                          1533.0
# 7                      -19.500000                           692.0
# 8                      -30.000000                           362.0
# 9                      -22.000000                          1708.0
#
#    ACTIVE_AMT_CREDIT_SUM_SUM  ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN  TARGET
# 0               7.877880e+05                                 0.0       0
# 1               0.000000e+00                                 0.0       0
# 2               0.000000e+00                                 0.0       0
# 3               1.237500e+06                                 0.0       0
# 4               0.000000e+00                                 0.0       0
# 5               0.000000e+00                                 0.0       0
# 6               4.020300e+06                                93.0       0
# 7               5.207850e+05                                 0.0       0
# 8               1.655959e+05                                 0.0       0
# 9               3.429000e+06                                 0.0       0
#
# [10 rows x 133 columns]

# %%
select_combination_val.shape
# Out:
# (30751, 133)

# %%
import gc
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
import lightgbm as lgb
from sklearn.metrics import f1_score,precision_score,recall_score,roc_auc_score,accuracy_score,roc_curve, plot_roc_curve
from sklearn import metrics
def val_lightgbm(train, val):
    
    print("Starting LightGBM. Train shape: {}, val shape: {}".format(train.shape, val.shape))
    feats = [f for f in train.columns if f not in ['TARGET','SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV','index']]
    
    
    gbm = lgb.LGBMClassifier(
            boosting_type='gbdt',
            num_leaves=106,
            max_depth=-1,
            learning_rate=0.012,
            n_estimators= 10000,
            objective='binary',
            class_weight=None,
            min_split_gain=0.0,
            min_child_weight=0.001,
            min_child_samples=390,
            subsample=0.717756,
            subsample_freq=1,
            colsample_bytree=0.614937,
            reg_alpha=0.512999,
            reg_lambda=0.382687,
            subsample_for_bin=80000,
            random_state=42,
            n_jobs=-1
        )
    X_train = train[feats].to_numpy()
    y_train = train['TARGET'].values  
    X_val = val[feats].to_numpy()                   
    y_val = val['TARGET'].values 
        
    gbm.fit(X_train,y_train)
    gbm_y_pre_train = gbm.predict(X_train)
    gbm_y_pre= gbm.predict(X_val)
    gbm_y_proba_train = gbm.predict_proba(X_train)
    gbm_y_proba= gbm.predict_proba(X_val)
    fpr,tpr,thresholds = roc_curve(y_val,gbm_y_proba[:,1])
    ks = max(tpr-fpr)
    
    print("==============================train==================================")
    gbm_accuracy_score_train = accuracy_score(y_train,gbm_y_pre_train)
    
    gbm_auc_train = roc_auc_score(y_train,gbm_y_proba_train[:,1])
    
    print('gbm_accuracy_score: %f,\ngbm_auc: %f'
          %(gbm_accuracy_score_train,
            gbm_auc_train))
    
    print("---------------------------------val---------------------------------")
    gbm_accuracy_score= accuracy_score(y_val,gbm_y_pre)
  
    gbm_auc = roc_auc_score(y_val,gbm_y_proba[:,1])
    print('gbm_accuracy_score: %f,\ngbm_auc: %f,\ngbm_ks:%f'
          %(gbm_accuracy_score,
        
    
            gbm_auc,
            ks))
    print("======================================================================")
    importance_df = pd.DataFrame()              
    importance_df["feature"] = feats
    importance_df["importance"] = gbm.feature_importances_
    
    
    return gbm,importance_df

def display_importances(feature_importance_df_):
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False)[:40].index
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    plt.figure(figsize=(8, 10))
    sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout
#     plt.savefig('lgbm_importances01.png')

# %%
start = time.time()
gbm, feature_imp = val_lightgbm(data, select_ combination_val)
end = time.time()
print("训练时间：", end -start)
# Out:
# Starting LightGBM. Train shape: (452270, 133), val shape: (30751, 133)
# ==============================train==================================
# gbm_accuracy_score: 0.999655,
# gbm_auc: 1.000000
# ---------------------------------val---------------------------------
# gbm_accuracy_score: 0.931677,
# gbm_auc: 0.827763,
# gbm_ks:0.496807
# ======================================================================
# 训练时间： 914.4859137535095

# %%
def lightgbm_test(gbm, test):
    feats = [f for f in test.columns if f not in ['TARGET','SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV','index']] # 固定列了

    gbm_y_pre = gbm.predict(test[feats].to_numpy())
    gbm_y_proba= gbm.predict_proba(test[feats])  # 验证训练模型没有这个'Booster' object has no attribute 'predict_proba'属性
    fpr,tpr,thresholds = roc_curve(test["TARGET"],gbm_y_proba[:,1])
    ks = max(tpr-fpr)


    gbm_accuracy_score=accuracy_score(test["TARGET"],gbm_y_pre)

    gbm_auc=roc_auc_score(test["TARGET"],gbm_y_proba[:,1])
    print('gbm_accuracy_score: %f,\ngbm_auc: %f,\ngbm_ks:%f'
          %(gbm_accuracy_score,
            gbm_auc,
            ks))

# %%
lightgbm_test(gbm, select_combination_test)
# Out:
# gbm_accuracy_score: 0.926311,
# gbm_auc: 0.802134,
# gbm_ks:0.450672

# %%
lightgbm_test(gbm, select_combination_test)
# Out:
# gbm_accuracy_score: 0.926311,
# gbm_auc: 0.802134,
# gbm_ks:0.450672

# %%
lightgbm_test(gbm, select_combination_test)
# Out:
# gbm_accuracy_score: 0.926311,
# gbm_auc: 0.802134,
# gbm_ks:0.450672

# %%
# import joblib
# joblib.dump(gbm, 'C:/data/processing_data/dataset/all_data_modle.pkl')
# joblib.load('modle.pkl') 加载模型

# %%
# !pip install joblib

# %% [markdown]
# # 去掉特征提取结果

# %%
import time
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

def reduce_mem_usage(data, verbose = True):
    start_mem = data.memory_usage().sum() / 1024**2
    if verbose:
        print('Memory usage of dataframe: {:.2f} MB'.format(start_mem))
    
    for col in data.columns:
        col_type = data[col].dtype
        
        if col_type != object:
            c_min = data[col].min()
            c_max = data[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    data[col] = data[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    data[col] = data[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    data[col] = data[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    data[col] = data[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    data[col] = data[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    data[col] = data[col].astype(np.float32)
                else:
                    data[col] = data[col].astype(np.float64)

    end_mem = data.memory_usage().sum() / 1024**2
    if verbose:
        print('Memory usage after optimization: {:.2f} MB'.format(end_mem))
        print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return data

# %%
all_data = pd.read_csv("C:/data/processing_data/all_data.csv")
all_data = reduce_mem_usage(all_data)
# Out:
# Memory usage of dataframe: 1081.56 MB
# Memory usage after optimization: 340.48 MB
# Decreased by 68.5%

# %%
all_data.shape
# Out:
# (307511, 461)

# %%
columns = all_data.columns.tolist()

# %%
all_data.head(10)
# Out:
#    SK_ID_CURR  NAME_CONTRACT_TYPE  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 0      100002           -0.324463     -0.717773         0.664551
# 1      100003           -0.324463     -0.717773        -1.504883
# 2      100004            3.082031      1.392578         0.664551
# 3      100006           -0.324463     -0.717773         0.664551
# 4      100007           -0.324463     -0.717773         0.664551
# 5      100008           -0.324463     -0.717773         0.664551
# 6      100009           -0.324463      1.392578         0.664551
# 7      100010           -0.324463      1.392578         0.664551
# 8      100011           -0.324463     -0.717773         0.664551
# 9      100012            3.082031     -0.717773         0.664551
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0     -0.577637          0.142090   -0.478027    -0.166016        -0.505859
# 1     -0.577637          0.426758    1.725586     0.592773         1.600586
# 2     -0.577637         -0.427246   -1.153320    -1.404297        -1.089844
# 3     -0.577637         -0.142578   -0.711426     0.177979        -0.651855
# 4     -0.577637         -0.199463   -0.213745    -0.361572        -0.067383
# 5     -0.577637         -0.294434   -0.269531     0.028290        -0.225708
# 6      0.807129          0.009285    2.388672     0.979004         2.318359
# 7     -0.577637          0.806152    2.312500     1.032227         2.683594
# 8     -0.577637         -0.237427    1.044922     0.463623         1.016602
# 9     -0.577637         -0.142578   -0.482178    -0.473145        -0.359619
#
#    REGION_POPULATION_RELATIVE  ...   LSTM_19   LSTM_20   LSTM_21   LSTM_23  \
# 0                   -0.149658  ...  0.088806  0.164062  0.484619  0.262939
# 1                   -1.252930  ...  0.000000  0.532715  1.517578  0.622070
# 2                   -0.783203  ...  0.000000  0.356934  1.283203  0.556152
# 3                   -0.929199  ...  0.000000  0.271973  0.982422  0.650391
# 4                    0.562988  ...  0.000000  0.200684  1.047852  0.322754
# 5                    1.079102  ...  0.000000  0.338135  1.052734  0.354248
# 6                    1.079102  ...  0.244629  0.418457  1.654297  0.724121
# 7                   -1.283203  ...  0.000000  0.393555  1.265625  0.714355
# 8                   -0.161865  ...  0.000000  0.312500  1.094727  0.205688
# 9                   -0.085693  ...  0.000000  0.305176  1.082031  0.746582
#
#     LSTM_25   LSTM_26   LSTM_27   LSTM_30   LSTM_31   LSTM_32
# 0  0.162842  0.139404  0.488281  0.624512  0.304199  0.323242
# 1  0.825195  0.000000  1.728516  2.693359  1.545898  1.300781
# 2  0.493408  0.729492  1.445312  2.021484  0.999512  0.889160
# 3  0.457764  0.000000  1.086914  1.581055  0.726074  0.801758
# 4  0.527832  0.000000  1.129883  1.547852  0.803223  0.759277
# 5  0.462158  0.621094  1.134766  1.626953  0.891602  0.897949
# 6  0.611816  0.491943  1.828125  1.815430  1.048828  1.099609
# 7  0.713867  0.540527  1.346680  2.126953  1.164062  1.132812
# 8  0.506836  0.751953  1.060547  1.671875  0.832520  0.958496
# 9  0.452881  0.000000  1.239258  1.718750  0.853027  0.817383
#
# [10 rows x 461 columns]

# %%
columns
# Out:
# ['SK_ID_CURR',
#  'NAME_CONTRACT_TYPE',
#  'FLAG_OWN_CAR',
#  'FLAG_OWN_REALTY',
#  'CNT_CHILDREN',
#  'AMT_INCOME_TOTAL',
#  'AMT_CREDIT',
#  'AMT_ANNUITY',
#  'AMT_GOODS_PRICE',
#  'REGION_POPULATION_RELATIVE',
#  'DAYS_BIRTH',
#  'DAYS_EMPLOYED',
#  'DAYS_REGISTRATION',
#  'DAYS_ID_PUBLISH',
#  'FLAG_EMP_PHONE',
#  'FLAG_WORK_PHONE',
#  'FLAG_PHONE',
#  'FLAG_EMAIL',
#  'CNT_FAM_MEMBERS',
#  'REGION_RATING_CLIENT',
#  'REGION_RATING_CLIENT_W_CITY',
#  'HOUR_APPR_PROCESS_START',
#  'REG_CITY_NOT_LIVE_CITY',
#  'REG_CITY_NOT_WORK_CITY',
#  'LIVE_CITY_NOT_WORK_CITY',
#  'EXT_SOURCE_2',
#  'APARTMENTS_AVG',
#  'BASEMENTAREA_AVG',
#  'YEARS_BEGINEXPLUATATION_AVG',
#  'ELEVATORS_AVG',
#  'ENTRANCES_AVG',
#  'FLOORSMAX_AVG',
#  'LANDAREA_AVG',
#  'LIVINGAREA_AVG',
#  'NONLIVINGAREA_AVG',
#  'APARTMENTS_MODE',
#  'BASEMENTAREA_MODE',
#  'YEARS_BEGINEXPLUATATION_MODE',
#  'ELEVATORS_MODE',
#  'ENTRANCES_MODE',
#  'FLOORSMAX_MODE',
#  'LANDAREA_MODE',
#  'LIVINGAREA_MODE',
#  'NONLIVINGAREA_MODE',
#  'APARTMENTS_MEDI',
#  'BASEMENTAREA_MEDI',
#  'YEARS_BEGINEXPLUATATION_MEDI',
#  'ELEVATORS_MEDI',
#  'ENTRANCES_MEDI',
#  'FLOORSMAX_MEDI',
#  'LANDAREA_MEDI',
#  'LIVINGAREA_MEDI',
#  'NONLIVINGAREA_MEDI',
#  'TOTALAREA_MODE',
#  'OBS_30_CNT_SOCIAL_CIRCLE',
#  'DEF_30_CNT_SOCIAL_CIRCLE',
#  'OBS_60_CNT_SOCIAL_CIRCLE',
#  'DEF_60_CNT_SOCIAL_CIRCLE',
#  'DAYS_LAST_PHONE_CHANGE',
#  'FLAG_DOCUMENT_3',
#  'FLAG_DOCUMENT_6',
#  'FLAG_DOCUMENT_8',
#  'AMT_REQ_CREDIT_BUREAU_MON',
#  'AMT_REQ_CREDIT_BUREAU_QRT',
#  'AMT_REQ_CREDIT_BUREAU_YEAR',
#  'DAYS_EMPLOYED_PERC',
#  'INCOME_CREDIT_PERC',
#  'INCOME_PER_PERSON',
#  'ANNUITY_INCOME_PERC',
#  'PAYMENT_RATE',
#  'NEW_CREDIT_TO_ANNUITY_RATIO',
#  'NEW_CREDIT_TO_GOODS_RATIO',
#  'NEW_DOC_IND_AVG',
#  'NEW_DOC_IND_STD',
#  'NEW_DOC_IND_KURT',
#  'NEW_LIVE_IND_SUM',
#  'NEW_LIVE_IND_STD',
#  'NEW_LIVE_IND_KURT',
#  'NEW_INC_PER_CHLD',
#  'NEW_INC_BY_ORG',
#  'NEW_PHONE_TO_BIRTH_RATIO',
#  'NEW_PHONE_TO_EMPLOY_RATIO',
#  'CODE_GENDER_F',
#  'CODE_GENDER_M',
#  'NAME_TYPE_SUITE_Family',
#  'NAME_TYPE_SUITE_Unaccompanied',
#  'NAME_INCOME_TYPE_Commercial associate',
#  'NAME_INCOME_TYPE_Pensioner',
#  'NAME_INCOME_TYPE_State servant',
#  'NAME_INCOME_TYPE_Working',
#  'NAME_EDUCATION_TYPE_Higher education',
#  'NAME_EDUCATION_TYPE_Secondary / secondary special',
#  'NAME_FAMILY_STATUS_Civil marriage',
#  'NAME_FAMILY_STATUS_Married',
#  'NAME_FAMILY_STATUS_Separated',
#  'NAME_FAMILY_STATUS_Single / not married',
#  'NAME_HOUSING_TYPE_House / apartment',
#  'OCCUPATION_TYPE_0',
#  'OCCUPATION_TYPE_Core staff',
#  'OCCUPATION_TYPE_Drivers',
#  'OCCUPATION_TYPE_Laborers',
#  'OCCUPATION_TYPE_Managers',
#  'OCCUPATION_TYPE_Sales staff',
#  'WEEKDAY_APPR_PROCESS_START_FRIDAY',
#  'WEEKDAY_APPR_PROCESS_START_MONDAY',
#  'WEEKDAY_APPR_PROCESS_START_SATURDAY',
#  'WEEKDAY_APPR_PROCESS_START_THURSDAY',
#  'WEEKDAY_APPR_PROCESS_START_TUESDAY',
#  'WEEKDAY_APPR_PROCESS_START_WEDNESDAY',
#  'ORGANIZATION_TYPE_Business Entity Type 3',
#  'ORGANIZATION_TYPE_Self-employed',
#  'ORGANIZATION_TYPE_XNA',
#  'HOUSETYPE_MODE_0',
#  'HOUSETYPE_MODE_block of flats',
#  'WALLSMATERIAL_MODE_0',
#  'WALLSMATERIAL_MODE_Panel',
#  'WALLSMATERIAL_MODE_Stone, brick',
#  'EMERGENCYSTATE_MODE_0',
#  'EMERGENCYSTATE_MODE_No',
#  'TARGET',
#  'BURO_DAYS_CREDIT_MIN',
#  'BURO_DAYS_CREDIT_MAX',
#  'BURO_DAYS_CREDIT_MEAN',
#  'BURO_DAYS_CREDIT_VAR',
#  'BURO_DAYS_CREDIT_ENDDATE_MIN',
#  'BURO_DAYS_CREDIT_ENDDATE_MAX',
#  'BURO_DAYS_CREDIT_ENDDATE_MEAN',
#  'BURO_DAYS_CREDIT_UPDATE_MEAN',
#  'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN',
#  'BURO_AMT_CREDIT_SUM_MAX',
#  'BURO_AMT_CREDIT_SUM_MEAN',
#  'BURO_AMT_CREDIT_SUM_SUM',
#  'BURO_AMT_CREDIT_SUM_DEBT_MAX',
#  'BURO_AMT_CREDIT_SUM_DEBT_MEAN',
#  'BURO_AMT_CREDIT_SUM_DEBT_SUM',
#  'BURO_AMT_CREDIT_SUM_LIMIT_MEAN',
#  'BURO_AMT_CREDIT_SUM_LIMIT_SUM',
#  'BURO_MONTHS_BALANCE_MIN_MIN',
#  'BURO_MONTHS_BALANCE_SIZE_MEAN',
#  'BURO_MONTHS_BALANCE_SIZE_SUM',
#  'BURO_CREDIT_ACTIVE_Active_MEAN',
#  'BURO_CREDIT_ACTIVE_Closed_MEAN',
#  'BURO_CREDIT_TYPE_Car loan_MEAN',
#  'BURO_CREDIT_TYPE_Consumer credit_MEAN',
#  'BURO_CREDIT_TYPE_Credit card_MEAN',
#  'BURO_CREDIT_TYPE_Mortgage_MEAN',
#  'BURO_STATUS_0_MEAN_MEAN',
#  'BURO_STATUS_1_MEAN_MEAN',
#  'BURO_STATUS_C_MEAN_MEAN',
#  'BURO_STATUS_X_MEAN_MEAN',
#  'ACTIVE_DAYS_CREDIT_MIN',
#  'ACTIVE_DAYS_CREDIT_MAX',
#  'ACTIVE_DAYS_CREDIT_MEAN',
#  'ACTIVE_DAYS_CREDIT_VAR',
#  'ACTIVE_DAYS_CREDIT_ENDDATE_MIN',
#  'ACTIVE_DAYS_CREDIT_ENDDATE_MAX',
#  'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN',
#  'ACTIVE_DAYS_CREDIT_UPDATE_MEAN',
#  'ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN',
#  'ACTIVE_AMT_CREDIT_SUM_MAX',
#  'ACTIVE_AMT_CREDIT_SUM_MEAN',
#  'ACTIVE_AMT_CREDIT_SUM_SUM',
#  'ACTIVE_AMT_CREDIT_SUM_DEBT_MAX',
#  'ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN',
#  'ACTIVE_AMT_CREDIT_SUM_DEBT_SUM',
#  'ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN',
#  'ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM',
#  'ACTIVE_MONTHS_BALANCE_SIZE_SUM',
#  'CLOSED_DAYS_CREDIT_MIN',
#  'CLOSED_DAYS_CREDIT_MAX',
#  'CLOSED_DAYS_CREDIT_MEAN',
#  'CLOSED_DAYS_CREDIT_VAR',
#  'CLOSED_DAYS_CREDIT_ENDDATE_MIN',
#  'CLOSED_DAYS_CREDIT_ENDDATE_MAX',
#  'CLOSED_DAYS_CREDIT_ENDDATE_MEAN',
#  'CLOSED_DAYS_CREDIT_UPDATE_MEAN',
#  'CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN',
#  'CLOSED_AMT_CREDIT_SUM_MAX',
#  'CLOSED_AMT_CREDIT_SUM_MEAN',
#  'CLOSED_AMT_CREDIT_SUM_SUM',
#  'CLOSED_MONTHS_BALANCE_SIZE_SUM',
#  'NEW_RATIO_BURO_DAYS_CREDIT_MIN',
#  'NEW_RATIO_BURO_DAYS_CREDIT_MAX',
#  'NEW_RATIO_BURO_DAYS_CREDIT_MEAN',
#  'NEW_RATIO_BURO_DAYS_CREDIT_VAR',
#  'NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MIN',
#  'NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MAX',
#  'NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MEAN',
#  'NEW_RATIO_BURO_DAYS_CREDIT_UPDATE_MEAN',
#  'NEW_RATIO_BURO_AMT_CREDIT_SUM_MAX',
#  'NEW_RATIO_BURO_AMT_CREDIT_SUM_MEAN',
#  'NEW_RATIO_BURO_AMT_CREDIT_SUM_SUM',
#  'CC_MONTHS_BALANCE_MIN',
#  'CC_MONTHS_BALANCE_MAX',
#  'CC_MONTHS_BALANCE_MEAN',
#  'CC_MONTHS_BALANCE_SUM',
#  'CC_MONTHS_BALANCE_VAR',
#  'CC_AMT_BALANCE_MIN',
#  'CC_AMT_BALANCE_MAX',
#  'CC_AMT_BALANCE_MEAN',
#  'CC_AMT_BALANCE_SUM',
#  'CC_AMT_BALANCE_VAR',
#  'CC_AMT_CREDIT_LIMIT_ACTUAL_MIN',
#  'CC_AMT_CREDIT_LIMIT_ACTUAL_MAX',
#  'CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN',
#  'CC_AMT_CREDIT_LIMIT_ACTUAL_SUM',
#  'CC_AMT_CREDIT_LIMIT_ACTUAL_VAR',
#  'CC_AMT_DRAWINGS_ATM_CURRENT_SUM',
#  'CC_AMT_DRAWINGS_CURRENT_MAX',
#  'CC_AMT_DRAWINGS_CURRENT_MEAN',
#  'CC_AMT_DRAWINGS_CURRENT_SUM',
#  'CC_AMT_DRAWINGS_CURRENT_VAR',
#  'CC_AMT_DRAWINGS_OTHER_CURRENT_SUM',
#  'CC_AMT_DRAWINGS_POS_CURRENT_SUM',
#  'CC_AMT_INST_MIN_REGULARITY_MIN',
#  'CC_AMT_INST_MIN_REGULARITY_MAX',
#  'CC_AMT_INST_MIN_REGULARITY_MEAN',
#  'CC_AMT_INST_MIN_REGULARITY_SUM',
#  'CC_AMT_INST_MIN_REGULARITY_VAR',
#  'CC_AMT_PAYMENT_CURRENT_SUM',
#  'CC_AMT_PAYMENT_TOTAL_CURRENT_MAX',
#  'CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN',
#  'CC_AMT_PAYMENT_TOTAL_CURRENT_SUM',
#  'CC_AMT_PAYMENT_TOTAL_CURRENT_VAR',
#  'CC_AMT_RECEIVABLE_PRINCIPAL_MIN',
#  'CC_AMT_RECEIVABLE_PRINCIPAL_MAX',
#  'CC_AMT_RECEIVABLE_PRINCIPAL_MEAN',
#  'CC_AMT_RECEIVABLE_PRINCIPAL_SUM',
#  'CC_AMT_RECEIVABLE_PRINCIPAL_VAR',
#  'CC_AMT_RECIVABLE_MIN',
#  'CC_AMT_RECIVABLE_MAX',
#  'CC_AMT_RECIVABLE_MEAN',
#  'CC_AMT_RECIVABLE_SUM',
#  'CC_AMT_RECIVABLE_VAR',
#  'CC_AMT_TOTAL_RECEIVABLE_MIN',
#  'CC_AMT_TOTAL_RECEIVABLE_MAX',
#  'CC_AMT_TOTAL_RECEIVABLE_MEAN',
#  'CC_AMT_TOTAL_RECEIVABLE_SUM',
#  'CC_AMT_TOTAL_RECEIVABLE_VAR',
#  'CC_CNT_DRAWINGS_ATM_CURRENT_SUM',
#  'CC_CNT_DRAWINGS_CURRENT_MAX',
#  'CC_CNT_DRAWINGS_CURRENT_MEAN',
#  'CC_CNT_DRAWINGS_CURRENT_SUM',
#  'CC_CNT_DRAWINGS_CURRENT_VAR',
#  'CC_CNT_DRAWINGS_OTHER_CURRENT_SUM',
#  'CC_CNT_DRAWINGS_POS_CURRENT_SUM',
#  'CC_CNT_INSTALMENT_MATURE_CUM_MIN',
#  'CC_CNT_INSTALMENT_MATURE_CUM_MAX',
#  'CC_CNT_INSTALMENT_MATURE_CUM_MEAN',
#  'CC_CNT_INSTALMENT_MATURE_CUM_SUM',
#  'CC_CNT_INSTALMENT_MATURE_CUM_VAR',
#  'CC_SK_DPD_MAX',
#  'CC_SK_DPD_MEAN',
#  'CC_SK_DPD_SUM',
#  'CC_SK_DPD_VAR',
#  'CC_SK_DPD_DEF_MAX',
#  'CC_SK_DPD_DEF_MEAN',
#  'CC_SK_DPD_DEF_SUM',
#  'CC_SK_DPD_DEF_VAR',
#  'CC_NAME_CONTRACT_STATUS_Active_MIN',
#  'CC_NAME_CONTRACT_STATUS_Active_MEAN',
#  'CC_NAME_CONTRACT_STATUS_Active_SUM',
#  'CC_NAME_CONTRACT_STATUS_Active_VAR',
#  'CC_NAME_CONTRACT_STATUS_Completed_MAX',
#  'CC_NAME_CONTRACT_STATUS_Completed_MEAN',
#  'CC_NAME_CONTRACT_STATUS_Completed_SUM',
#  'CC_NAME_CONTRACT_STATUS_Completed_VAR',
#  'CC_NAME_CONTRACT_STATUS_Signed_VAR',
#  'CC_COUNT',
#  'INSTAL_NUM_INSTALMENT_VERSION_NUNIQUE',
#  'INSTAL_DPD_MAX',
#  'INSTAL_DPD_MEAN',
#  'INSTAL_DPD_SUM',
#  'INSTAL_DBD_MAX',
#  'INSTAL_DBD_MEAN',
#  'INSTAL_DBD_SUM',
#  'INSTAL_PAYMENT_PERC_MAX',
#  'INSTAL_PAYMENT_PERC_MEAN',
#  'INSTAL_PAYMENT_PERC_SUM',
#  'INSTAL_PAYMENT_PERC_VAR',
#  'INSTAL_PAYMENT_DIFF_MAX',
#  'INSTAL_PAYMENT_DIFF_MEAN',
#  'INSTAL_PAYMENT_DIFF_SUM',
#  'INSTAL_PAYMENT_DIFF_VAR',
#  'INSTAL_AMT_INSTALMENT_MAX',
#  'INSTAL_AMT_INSTALMENT_MEAN',
#  'INSTAL_AMT_INSTALMENT_SUM',
#  'INSTAL_AMT_PAYMENT_MIN',
#  'INSTAL_AMT_PAYMENT_MAX',
#  'INSTAL_AMT_PAYMENT_MEAN',
#  'INSTAL_AMT_PAYMENT_SUM',
#  'INSTAL_DAYS_ENTRY_PAYMENT_MAX',
#  'INSTAL_DAYS_ENTRY_PAYMENT_MEAN',
#  'INSTAL_DAYS_ENTRY_PAYMENT_SUM',
#  'INSTAL_COUNT',
#  'POS_MONTHS_BALANCE_MAX',
#  'POS_MONTHS_BALANCE_MEAN',
#  'POS_MONTHS_BALANCE_SIZE',
#  'POS_SK_DPD_MAX',
#  'POS_SK_DPD_MEAN',
#  'POS_SK_DPD_DEF_MAX',
#  'POS_SK_DPD_DEF_MEAN',
#  'POS_NAME_CONTRACT_STATUS_Active_MEAN',
#  'POS_NAME_CONTRACT_STATUS_Completed_MEAN',
#  'POS_NAME_CONTRACT_STATUS_Signed_MEAN',
#  'POS_COUNT',
#  'PREV_AMT_ANNUITY_MIN',
#  'PREV_AMT_ANNUITY_MAX',
#  'PREV_AMT_ANNUITY_MEAN',
#  'PREV_AMT_APPLICATION_MIN',
#  'PREV_AMT_APPLICATION_MAX',
#  'PREV_AMT_APPLICATION_MEAN',
#  'PREV_AMT_CREDIT_MIN',
#  'PREV_AMT_CREDIT_MAX',
#  'PREV_AMT_CREDIT_MEAN',
#  'PREV_APP_CREDIT_PERC_MIN',
#  'PREV_APP_CREDIT_PERC_MAX',
#  'PREV_APP_CREDIT_PERC_MEAN',
#  'PREV_APP_CREDIT_PERC_VAR',
#  'PREV_AMT_DOWN_PAYMENT_MIN',
#  'PREV_AMT_DOWN_PAYMENT_MAX',
#  'PREV_AMT_DOWN_PAYMENT_MEAN',
#  'PREV_AMT_GOODS_PRICE_MIN',
#  'PREV_AMT_GOODS_PRICE_MAX',
#  'PREV_AMT_GOODS_PRICE_MEAN',
#  'PREV_HOUR_APPR_PROCESS_START_MIN',
#  'PREV_HOUR_APPR_PROCESS_START_MAX',
#  'PREV_HOUR_APPR_PROCESS_START_MEAN',
#  'PREV_RATE_DOWN_PAYMENT_MIN',
#  'PREV_RATE_DOWN_PAYMENT_MAX',
#  'PREV_RATE_DOWN_PAYMENT_MEAN',
#  'PREV_DAYS_DECISION_MIN',
#  'PREV_DAYS_DECISION_MAX',
#  'PREV_DAYS_DECISION_MEAN',
#  'PREV_CNT_PAYMENT_MEAN',
#  'PREV_CNT_PAYMENT_SUM',
#  'PREV_NAME_CONTRACT_TYPE_Cash loans_MEAN',
#  'PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN',
#  'PREV_NAME_CONTRACT_TYPE_Revolving loans_MEAN',
#  'PREV_WEEKDAY_APPR_PROCESS_START_FRIDAY_MEAN',
#  'PREV_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN',
#  'PREV_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN',
#  'PREV_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN',
#  'PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN',
#  'PREV_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN',
#  'PREV_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN',
#  'PREV_NAME_CASH_LOAN_PURPOSE_XAP_MEAN',
#  'PREV_NAME_CASH_LOAN_PURPOSE_XNA_MEAN',
#  'PREV_NAME_CONTRACT_STATUS_Approved_MEAN',
#  'PREV_NAME_CONTRACT_STATUS_Canceled_MEAN',
#  'PREV_NAME_CONTRACT_STATUS_Refused_MEAN',
#  'PREV_NAME_CONTRACT_STATUS_Unused offer_MEAN',
#  'PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN',
#  'PREV_NAME_PAYMENT_TYPE_XNA_MEAN',
#  'PREV_CODE_REJECT_REASON_CLIENT_MEAN',
#  'PREV_CODE_REJECT_REASON_HC_MEAN',
#  'PREV_CODE_REJECT_REASON_LIMIT_MEAN',
#  'PREV_CODE_REJECT_REASON_SCO_MEAN',
#  'PREV_CODE_REJECT_REASON_XAP_MEAN',
#  'PREV_NAME_TYPE_SUITE_Children_MEAN',
#  'PREV_NAME_TYPE_SUITE_Family_MEAN',
#  'PREV_NAME_TYPE_SUITE_Spouse, partner_MEAN',
#  'PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN',
#  'PREV_NAME_TYPE_SUITE_nan_MEAN',
#  'PREV_NAME_CLIENT_TYPE_New_MEAN',
#  'PREV_NAME_CLIENT_TYPE_Refreshed_MEAN',
#  'PREV_NAME_CLIENT_TYPE_Repeater_MEAN',
#  'PREV_NAME_GOODS_CATEGORY_Audio/Video_MEAN',
#  'PREV_NAME_GOODS_CATEGORY_Clothing and Accessories_MEAN',
#  'PREV_NAME_GOODS_CATEGORY_Computers_MEAN',
#  'PREV_NAME_GOODS_CATEGORY_Construction Materials_MEAN',
#  'PREV_NAME_GOODS_CATEGORY_Consumer Electronics_MEAN',
#  'PREV_NAME_GOODS_CATEGORY_Furniture_MEAN',
#  'PREV_NAME_GOODS_CATEGORY_Mobile_MEAN',
#  'PREV_NAME_GOODS_CATEGORY_Photo / Cinema Equipment_MEAN',
#  'PREV_NAME_GOODS_CATEGORY_XNA_MEAN',
#  'PREV_NAME_PORTFOLIO_Cards_MEAN',
#  'PREV_NAME_PORTFOLIO_Cash_MEAN',
#  'PREV_NAME_PORTFOLIO_POS_MEAN',
#  'PREV_NAME_PORTFOLIO_XNA_MEAN',
#  'PREV_NAME_PRODUCT_TYPE_XNA_MEAN',
#  'PREV_NAME_PRODUCT_TYPE_walk-in_MEAN',
#  'PREV_NAME_PRODUCT_TYPE_x-sell_MEAN',
#  'PREV_CHANNEL_TYPE_AP+ (Cash loan)_MEAN',
#  'PREV_CHANNEL_TYPE_Contact center_MEAN',
#  'PREV_CHANNEL_TYPE_Country-wide_MEAN',
#  'PREV_CHANNEL_TYPE_Credit and cash offices_MEAN',
#  'PREV_CHANNEL_TYPE_Regional / Local_MEAN',
#  'PREV_CHANNEL_TYPE_Stone_MEAN',
#  'PREV_NAME_SELLER_INDUSTRY_Clothing_MEAN',
#  'PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN',
#  'PREV_NAME_SELLER_INDUSTRY_Construction_MEAN',
#  'PREV_NAME_SELLER_INDUSTRY_Consumer electronics_MEAN',
#  'PREV_NAME_SELLER_INDUSTRY_Furniture_MEAN',
#  'PREV_NAME_SELLER_INDUSTRY_XNA_MEAN',
#  'PREV_NAME_YIELD_GROUP_XNA_MEAN',
#  'PREV_NAME_YIELD_GROUP_high_MEAN',
#  'PREV_NAME_YIELD_GROUP_low_action_MEAN',
#  'PREV_NAME_YIELD_GROUP_low_normal_MEAN',
#  'PREV_NAME_YIELD_GROUP_middle_MEAN',
#  'PREV_PRODUCT_COMBINATION_Card Street_MEAN',
#  'PREV_PRODUCT_COMBINATION_Card X-Sell_MEAN',
#  'PREV_PRODUCT_COMBINATION_Cash_MEAN',
#  'PREV_PRODUCT_COMBINATION_Cash Street: high_MEAN',
#  'PREV_PRODUCT_COMBINATION_Cash Street: low_MEAN',
#  'PREV_PRODUCT_COMBINATION_Cash Street: middle_MEAN',
#  'PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN',
#  'PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN',
#  'PREV_PRODUCT_COMBINATION_Cash X-Sell: middle_MEAN',
#  'PREV_PRODUCT_COMBINATION_POS household with interest_MEAN',
#  'PREV_PRODUCT_COMBINATION_POS household without interest_MEAN',
#  'PREV_PRODUCT_COMBINATION_POS industry with interest_MEAN',
#  'PREV_PRODUCT_COMBINATION_POS mobile with interest_MEAN',
#  'PREV_PRODUCT_COMBINATION_POS mobile without interest_MEAN',
#  'PREV_PRODUCT_COMBINATION_POS other with interest_MEAN',
#  'APPROVED_AMT_ANNUITY_MIN',
#  'APPROVED_AMT_ANNUITY_MAX',
#  'APPROVED_AMT_ANNUITY_MEAN',
#  'APPROVED_AMT_APPLICATION_MIN',
#  'APPROVED_AMT_APPLICATION_MAX',
#  'APPROVED_AMT_APPLICATION_MEAN',
#  'APPROVED_AMT_CREDIT_MIN',
#  'APPROVED_AMT_CREDIT_MAX',
#  'APPROVED_AMT_CREDIT_MEAN',
#  'APPROVED_APP_CREDIT_PERC_MIN',
#  'APPROVED_APP_CREDIT_PERC_MAX',
#  'APPROVED_APP_CREDIT_PERC_MEAN',
#  'APPROVED_APP_CREDIT_PERC_VAR',
#  'APPROVED_AMT_DOWN_PAYMENT_MIN',
#  'APPROVED_AMT_DOWN_PAYMENT_MAX',
#  'APPROVED_AMT_DOWN_PAYMENT_MEAN',
#  'APPROVED_AMT_GOODS_PRICE_MIN',
#  'APPROVED_AMT_GOODS_PRICE_MAX',
#  'APPROVED_AMT_GOODS_PRICE_MEAN',
#  'APPROVED_HOUR_APPR_PROCESS_START_MIN',
#  'APPROVED_HOUR_APPR_PROCESS_START_MAX',
#  'APPROVED_HOUR_APPR_PROCESS_START_MEAN',
#  'APPROVED_RATE_DOWN_PAYMENT_MIN',
#  'APPROVED_RATE_DOWN_PAYMENT_MAX',
#  'APPROVED_RATE_DOWN_PAYMENT_MEAN',
#  'APPROVED_DAYS_DECISION_MIN',
#  'APPROVED_DAYS_DECISION_MAX',
#  'APPROVED_DAYS_DECISION_MEAN',
#  'APPROVED_CNT_PAYMENT_MEAN',
#  'APPROVED_CNT_PAYMENT_SUM',
#  'LSTM_3',
#  'LSTM_4',
#  'LSTM_8',
#  'LSTM_10',
#  'LSTM_12',
#  'LSTM_14',
#  'LSTM_19',
#  'LSTM_20',
#  'LSTM_21',
#  'LSTM_23',
#  'LSTM_25',
#  'LSTM_26',
#  'LSTM_27',
#  'LSTM_30',
#  'LSTM_31',
#  'LSTM_32']

# %%
droplist = [i for i in columns if "LSTM_" in i]

# %%
droplist
# Out:
# ['LSTM_3',
#  'LSTM_4',
#  'LSTM_8',
#  'LSTM_10',
#  'LSTM_12',
#  'LSTM_14',
#  'LSTM_19',
#  'LSTM_20',
#  'LSTM_21',
#  'LSTM_23',
#  'LSTM_25',
#  'LSTM_26',
#  'LSTM_27',
#  'LSTM_30',
#  'LSTM_31',
#  'LSTM_32']

# %%
all_data.to_csv("C:/data/data/lstm_data.csv")

# %%
drop_lstm_data = all_data.drop(columns = droplist, axis = 1)

# %%
drop_lstm_data.shape
# Out:
# (307511, 445)

# %%
drop_lstm_data.to_csv("C:/data/data/data.csv")

# %%
def split_train(data,test_ratio):
   #  data = data.iloc[0:20000,:]
    np.random.seed(0)  # 设置随机种子确保实验可重复
    shuffled_indices=np.random.permutation(len(data)) # 随机片
    test_set_size=int(len(data)*test_ratio)
    test_indices =shuffled_indices[:test_set_size]
    train_indices=shuffled_indices[test_set_size:]
    return data.iloc[train_indices],data.iloc[test_indices]

# %%
drop_lstm_data_train, drop_lstm_data_valtest = split_train(drop_lstm_data, 0.2)
drop_lstm_data_val,drop_lstm_data_test = split_train(drop_lstm_data_valtest, 0.5)
drop_lstm_data_train.to_csv("C:/data/processing_data/dataset/drop_lstm_data_train.csv")
drop_lstm_data_val.to_csv("C:/data/processing_data/dataset/drop_lstm_data_val.csv")
drop_lstm_data_test.to_csv("C:/data/processing_data/dataset/drop_lstm_data_test.csv")

# %%
from sklearn.feature_selection import SelectKBest,chi2,RFE,SelectFromModel
from sklearn.preprocessing import MinMaxScaler

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# 采用6种特征选择方法，输入特征选择结果
def select_feature(data, num):
    X = data.drop(['TARGET'], axis=1)
    y = data.TARGET
    feature_name = X.columns.tolist()
    
    start = time.time()
    # 过滤法，皮尔逊相关系数
    cor_list = []
    # 计算与目标的相关系数
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # 空值使用0代替
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # 选中的名字
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-num:]].columns.tolist()
    # 选中为T
    cor_support = [True if i in cor_feature else False for i in feature_name]
    end1 =time.time()
    print("过滤法-皮尔逊相关系数特征选择所用时间：", end1 - start)
    print(str(len(cor_feature)), 'selected features')
    
    # 过滤法-卡方检验
    X_norm = MinMaxScaler().fit_transform(X)
    chi_selector = SelectKBest(chi2, k=num)
    chi_selector.fit(X_norm, y)
    chi_support = chi_selector.get_support()
    chi_feature = X.loc[:,chi_support].columns.tolist()
    end2 = time.time()
    print("过滤法-卡方检验特征选择所用时间：", end2 - end1)
    print(str(len(chi_feature)), 'selected features')
    
    # 包裹式-LR
    LR_selector = RFE(estimator=LogisticRegression(solver='liblinear',max_iter=500), n_features_to_select=num, step=50, verbose=5)
    LR_selector.fit(X, y)
    LR_support = LR_selector.get_support()
    LR_feature = X.loc[:,LR_support].columns.tolist()  # list
    end3 = time.time()
    print("包裹式-LR特征选择所用时间：", end3 - end2)
    print(str(len(LR_feature)), 'selected features')
    
    # 包裹式-RF
    RF_selector = RFE(estimator=RandomForestClassifier(n_estimators=100), n_features_to_select=num, step=50, verbose=5)
    RF_selector.fit(X, y)
    RF_support = RF_selector.get_support()
    RF_feature = X.loc[:,RF_support].columns.tolist()
    end4 = time.time()
    print("包裹式-LR特征选择所用时间：", end4 - end3)
    print(str(len(RF_feature)), 'selected features')
    
    # 嵌入式-LR
    embeded_lr_selector = SelectFromModel(estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
          intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
          penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
          verbose=0, warm_start=False),
        norm_order=1, prefit=False, threshold=-np.inf, max_features=num)
    embeded_lr_selector.fit(X_norm, y)
    embeded_lr_support = embeded_lr_selector.get_support()
    embeded_lr_feature = X.loc[:,embeded_lr_support].columns.tolist()
    end5 = time.time()
    print("嵌入式-LR特征选择所用时间：", end5 - end4)
    print(str(len(embeded_lr_feature)), 'selected features')
    
    # 嵌入式-RF
    embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), threshold=-np.inf, max_features=200)
    embeded_rf_selector.fit(X, y)
    embeded_rf_support = embeded_rf_selector.get_support()
    embeded_rf_feature = X.loc[:,embeded_rf_support].columns.tolist()
    end6 = time.time()
    print("嵌入式-LR特征选择所用时间：", end6 - end5)

    print(str(len(embeded_rf_feature)), 'selected features')
    
    
    # put all selection together
    feature_selection_df = pd.DataFrame({'Feature':feature_name, 'Pearson':cor_support, 'Chi-2':chi_support, 'RFE_LR':LR_support, 'RFE_RF':RF_support, 'Logistics':embeded_lr_support,
                                    'Random Forest':embeded_rf_support})
    # 统计结果 
    feature_selection_df['Total'] = np.sum(feature_selection_df, axis=1)
    # display the top 200
    feature_selection_df = feature_selection_df.sort_values(['Total','Feature'] , ascending=False)
    feature_selection_df.index = range(1, len(feature_selection_df)+1)
    feature_selection_df = feature_selection_df.iloc[:num,]
    
    selected_df = feature_selection_df[feature_selection_df['Total'] > 3]
    combination_feature = selected_df.Feature.tolist()
    combination_feature_dataframe = combination_feature + [" "] * (200 - len(combination_feature)) # 不够两百，空值填充
    
    dataframe_select = pd.DataFrame({'Pearson':cor_feature, 'Chi-2':chi_feature, 'RFE_LR':LR_feature, 'RFE_RF':RF_feature, 'embedding_LR':embeded_lr_feature,
                                    'embedding_RF':embeded_rf_feature, 'combination': combination_feature_dataframe})
    
    # 返回投票结果，以及返回选择后的特征列表
    return feature_selection_df,dataframe_select
    # 组合特征选择

# %%
drop_lstm_feture_selction_df,drop_lstm_dataframe_select = select_feature(drop_lstm_data_train, 200)
# Out:
# 过滤法-皮尔逊相关系数特征选择所用时间： 1.7650914192199707
# 200 selected features
# 过滤法-卡方检验特征选择所用时间： 2.0914084911346436
# 200 selected features
# Fitting estimator with 444 features.
# Fitting estimator with 394 features.
# Fitting estimator with 344 features.
# Fitting estimator with 294 features.
# Fitting estimator with 244 features.
# 包裹式-LR特征选择所用时间： 1360.8490874767303
# 200 selected features
# Fitting estimator with 444 features.
# Fitting estimator with 394 features.
# Fitting estimator with 344 features.
# Fitting estimator with 294 features.
# Fitting estimator with 244 features.
# 包裹式-LR特征选择所用时间： 1647.4414615631104
# 200 selected features
# 嵌入式-LR特征选择所用时间： 323.3498065471649
# 200 selected features
# 嵌入式-LR特征选择所用时间： 282.8331153392792
# 200 selected features

# %%
pd.set_option('display.max_rows', None) # 可以显示所有
drop_lstm_feture_selction_df
# Out:
#                                                Feature  Pearson  Chi-2  \
# 1                              PREV_DAYS_DECISION_MEAN     True   True
# 2                     PREV_CODE_REJECT_REASON_XAP_MEAN     True   True
# 3                                 PREV_CNT_PAYMENT_SUM     True   True
# 4                                PREV_CNT_PAYMENT_MEAN     True   True
# 5                              POS_MONTHS_BALANCE_SIZE     True   True
# 6                              POS_MONTHS_BALANCE_MEAN     True   True
# 7                                            POS_COUNT     True   True
# 8                       INSTAL_DAYS_ENTRY_PAYMENT_MEAN     True   True
# 9                               CLOSED_DAYS_CREDIT_VAR     True   True
# 10                             CLOSED_DAYS_CREDIT_MEAN     True   True
# 11                         CC_CNT_DRAWINGS_CURRENT_VAR     True   True
# 12                                BURO_DAYS_CREDIT_VAR     True   True
# 13                                BURO_DAYS_CREDIT_MIN     True   True
# 14                               BURO_DAYS_CREDIT_MEAN     True   True
# 15                                BURO_DAYS_CREDIT_MAX     True   True
# 16                          APPROVED_DAYS_DECISION_MIN     True   True
# 17                         APPROVED_DAYS_DECISION_MEAN     True   True
# 18                            APPROVED_AMT_ANNUITY_MAX     True   True
# 19                              ACTIVE_DAYS_CREDIT_MIN     True   True
# 20                             ACTIVE_DAYS_CREDIT_MEAN     True   True
# 21                          REGION_POPULATION_RELATIVE     True   True
# 22                         PREV_RATE_DOWN_PAYMENT_MEAN     True   True
# 23                          PREV_RATE_DOWN_PAYMENT_MAX     True   True
# 24                     PREV_NAME_PAYMENT_TYPE_XNA_MEAN     True   True
# 25              PREV_NAME_CONTRACT_STATUS_Refused_MEAN     True   True
# 26             PREV_NAME_CONTRACT_STATUS_Approved_MEAN     True   True
# 27                              PREV_DAYS_DECISION_MIN     True   True
# 28                               PREV_AMT_ANNUITY_MEAN     True  False
# 29                                PREV_AMT_ANNUITY_MAX     True  False
# 30                         NEW_CREDIT_TO_ANNUITY_RATIO     True   True
# 31                             INSTAL_PAYMENT_DIFF_SUM     True  False
# 32                            INSTAL_PAYMENT_DIFF_MEAN     True  False
# 33                                      INSTAL_DBD_SUM     True  False
# 34                       INSTAL_DAYS_ENTRY_PAYMENT_SUM     True  False
# 35                              INSTAL_AMT_PAYMENT_MIN     True  False
# 36                                        EXT_SOURCE_2     True   True
# 37                              DAYS_LAST_PHONE_CHANGE     True   True
# 38                                     DAYS_ID_PUBLISH     True   True
# 39                                  DAYS_EMPLOYED_PERC     True   True
# 40                                          DAYS_BIRTH     True   True
# 41                      CLOSED_DAYS_CREDIT_UPDATE_MEAN     True  False
# 42                              CLOSED_DAYS_CREDIT_MIN     True   True
# 43                              CLOSED_DAYS_CREDIT_MAX     True   True
# 44                      CLOSED_DAYS_CREDIT_ENDDATE_MIN     True  False
# 45                             BURO_STATUS_1_MEAN_MEAN     True   True
# 46                        BURO_DAYS_CREDIT_UPDATE_MEAN     True  False
# 47                        BURO_DAYS_CREDIT_ENDDATE_MIN     True  False
# 48                      BURO_CREDIT_ACTIVE_Closed_MEAN     True   True
# 49                      BURO_CREDIT_ACTIVE_Active_MEAN     True   True
# 50                     APPROVED_RATE_DOWN_PAYMENT_MEAN     True   True
# 51                      APPROVED_RATE_DOWN_PAYMENT_MAX     True   True
# 52                       APPROVED_AMT_GOODS_PRICE_MEAN     True  False
# 53                           APPROVED_AMT_ANNUITY_MEAN     True  False
# 54                                     AMT_GOODS_PRICE     True   True
# 55                                          AMT_CREDIT     True   True
# 56                              ACTIVE_DAYS_CREDIT_VAR    False   True
# 57                              ACTIVE_DAYS_CREDIT_MAX     True  False
# 58                     ACTIVE_DAYS_CREDIT_ENDDATE_MEAN     True  False
# 59                      ACTIVE_DAYS_CREDIT_ENDDATE_MAX     True  False
# 60                          ACTIVE_AMT_CREDIT_SUM_MEAN     True  False
# 61                        YEARS_BEGINEXPLUATATION_MODE     True   True
# 62                        YEARS_BEGINEXPLUATATION_MEDI     True   True
# 63                         YEARS_BEGINEXPLUATATION_AVG     True   True
# 64                                      TOTALAREA_MODE     True   True
# 65                   PREV_NAME_YIELD_GROUP_middle_MEAN    False   True
# 66                     PREV_NAME_YIELD_GROUP_high_MEAN     True   True
# 67                      PREV_NAME_YIELD_GROUP_XNA_MEAN     True   True
# 68                       PREV_NAME_TYPE_SUITE_nan_MEAN     True   True
# 69         PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN     True   True
# 70                 PREV_NAME_PRODUCT_TYPE_walk-in_MEAN     True   True
# 71                        PREV_NAME_PORTFOLIO_XNA_MEAN     True   True
# 72   PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN     True   True
# 73         PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN     True   True
# 74                    PREV_HOUR_APPR_PROCESS_START_MIN    False  False
# 75                     PREV_CODE_REJECT_REASON_HC_MEAN     True   True
# 76                            PREV_APP_CREDIT_PERC_MIN    False  False
# 77                           PREV_AMT_GOODS_PRICE_MEAN    False  False
# 78                          PREV_AMT_DOWN_PAYMENT_MEAN     True  False
# 79                           PREV_AMT_DOWN_PAYMENT_MAX     True  False
# 80                                 PREV_AMT_CREDIT_MAX    False  False
# 81                                PREV_AMT_ANNUITY_MIN     True  False
# 82              NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MIN    False  False
# 83              NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MAX    False  False
# 84                            NEW_PHONE_TO_BIRTH_RATIO     True   True
# 85                                      NEW_INC_BY_ORG     True   True
# 86                           NEW_CREDIT_TO_GOODS_RATIO     True  False
# 87                                     LIVINGAREA_MODE     True   True
# 88                                     LIVINGAREA_MEDI     True   True
# 89                                      LIVINGAREA_AVG     True   True
# 90                                        LANDAREA_AVG     True   True
# 91                             INSTAL_PAYMENT_DIFF_MAX    False  False
# 92                                      INSTAL_DPD_MAX    False  False
# 93                                     INSTAL_DBD_MEAN    False  False
# 94                                      INSTAL_DBD_MAX    False  False
# 95                       INSTAL_DAYS_ENTRY_PAYMENT_MAX    False  False
# 96                                        INSTAL_COUNT    False  False
# 97                              INSTAL_AMT_PAYMENT_SUM    False  False
# 98                             INSTAL_AMT_PAYMENT_MEAN    False  False
# 99                              INSTAL_AMT_PAYMENT_MAX    False  False
# 100                          INSTAL_AMT_INSTALMENT_SUM    False  False
# 101                                  DAYS_REGISTRATION     True  False
# 102                                      DAYS_EMPLOYED     True  False
# 103                     CLOSED_DAYS_CREDIT_ENDDATE_MAX    False  False
# 104                         CLOSED_AMT_CREDIT_SUM_MEAN     True  False
# 105                          CLOSED_AMT_CREDIT_SUM_MAX     True  False
# 106                       CC_CNT_DRAWINGS_CURRENT_MEAN     True   True
# 107                     CC_AMT_INST_MIN_REGULARITY_VAR     True   True
# 108                    CC_AMT_INST_MIN_REGULARITY_MEAN     True   True
# 109                        CC_AMT_DRAWINGS_CURRENT_MAX     True   True
# 110                                 CC_AMT_BALANCE_VAR     True   True
# 111                                CC_AMT_BALANCE_MEAN     True   True
# 112                                 CC_AMT_BALANCE_MAX     True   True
# 113                      BURO_MONTHS_BALANCE_SIZE_MEAN     True   True
# 114                      BURO_DAYS_CREDIT_ENDDATE_MEAN     True  False
# 115                       BURO_DAYS_CREDIT_ENDDATE_MAX     True  False
# 116                  BURO_CREDIT_TYPE_Credit card_MEAN    False   True
# 117              BURO_CREDIT_TYPE_Consumer credit_MEAN     True   True
# 118                           BURO_AMT_CREDIT_SUM_MEAN     True  False
# 119                            BURO_AMT_CREDIT_SUM_MAX     True  False
# 120                       BURO_AMT_CREDIT_SUM_DEBT_SUM    False  False
# 121                      BURO_AMT_CREDIT_SUM_DEBT_MEAN    False  False
# 122               APPROVED_HOUR_APPR_PROCESS_START_MIN    False  False
# 123              APPROVED_HOUR_APPR_PROCESS_START_MEAN    False  False
# 124                         APPROVED_DAYS_DECISION_MAX    False  False
# 125                           APPROVED_CNT_PAYMENT_SUM    False  False
# 126                       APPROVED_APP_CREDIT_PERC_MIN    False  False
# 127                       APPROVED_APP_CREDIT_PERC_MAX    False  False
# 128                       APPROVED_AMT_GOODS_PRICE_MAX     True  False
# 129                     APPROVED_AMT_DOWN_PAYMENT_MEAN     True  False
# 130                      APPROVED_AMT_DOWN_PAYMENT_MAX     True  False
# 131                            APPROVED_AMT_CREDIT_MAX    False  False
# 132                       APPROVED_AMT_APPLICATION_MIN    False  False
# 133                      APPROVED_AMT_APPLICATION_MEAN     True  False
# 134                       APPROVED_AMT_APPLICATION_MAX     True  False
# 135                                    APARTMENTS_MEDI     True   True
# 136                                     APARTMENTS_AVG     True   True
# 137                     ACTIVE_DAYS_CREDIT_UPDATE_MEAN    False  False
# 138                     ACTIVE_DAYS_CREDIT_ENDDATE_MIN    False  False
# 139                          ACTIVE_AMT_CREDIT_SUM_SUM    False  False
# 140                 ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN    False  False
# 141                                         SK_ID_CURR    False  False
# 142                             REG_CITY_NOT_LIVE_CITY     True   True
# 143                        REGION_RATING_CLIENT_W_CITY     True   True
# 144     PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN     True   True
# 145              PREV_NAME_YIELD_GROUP_low_normal_MEAN     True   True
# 146              PREV_NAME_YIELD_GROUP_low_action_MEAN     True   True
# 147                     PREV_NAME_PORTFOLIO_Cards_MEAN     True   True
# 148            PREV_NAME_GOODS_CATEGORY_Furniture_MEAN     True   True
# 149                     PREV_NAME_CLIENT_TYPE_New_MEAN     True   True
# 150                  PREV_HOUR_APPR_PROCESS_START_MEAN    False  False
# 151                   PREV_HOUR_APPR_PROCESS_START_MAX    False  False
# 152                             PREV_DAYS_DECISION_MAX    False  False
# 153             PREV_CHANNEL_TYPE_AP+ (Cash loan)_MEAN     True   True
# 154                          PREV_APP_CREDIT_PERC_MEAN    False  False
# 155                           PREV_APP_CREDIT_PERC_MAX    False  False
# 156                           PREV_AMT_GOODS_PRICE_MIN    False  False
# 157                           PREV_AMT_GOODS_PRICE_MAX    False  False
# 158                                PREV_AMT_CREDIT_MIN    False  False
# 159                               PREV_AMT_CREDIT_MEAN    False  False
# 160                           PREV_AMT_APPLICATION_MIN    False  False
# 161                          PREV_AMT_APPLICATION_MEAN    False  False
# 162                           PREV_AMT_APPLICATION_MAX    False  False
# 163                                    POS_SK_DPD_MEAN    False  False
# 164               POS_NAME_CONTRACT_STATUS_Signed_MEAN    False  False
# 165            POS_NAME_CONTRACT_STATUS_Completed_MEAN    False  False
# 166               POS_NAME_CONTRACT_STATUS_Active_MEAN    False  False
# 167                             POS_MONTHS_BALANCE_MAX    False  False
# 168                                       PAYMENT_RATE    False  False
# 169                              ORGANIZATION_TYPE_XNA     True   True
# 170                            OCCUPATION_TYPE_Drivers     True   True
# 171                           OBS_60_CNT_SOCIAL_CIRCLE    False  False
# 172                     NEW_RATIO_BURO_DAYS_CREDIT_VAR    False  False
# 173            NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MEAN    False  False
# 174                  NEW_RATIO_BURO_AMT_CREDIT_SUM_SUM    False  False
# 175                 NEW_RATIO_BURO_AMT_CREDIT_SUM_MEAN    False  False
# 176                  NEW_RATIO_BURO_AMT_CREDIT_SUM_MAX    False  False
# 177                          NEW_PHONE_TO_EMPLOY_RATIO     True  False
# 178                                   NEW_INC_PER_CHLD    False  False
# 179                                   NEW_DOC_IND_KURT     True   True
# 180                     NAME_INCOME_TYPE_State servant     True   True
# 181                         NAME_INCOME_TYPE_Pensioner     True   True
# 182               NAME_EDUCATION_TYPE_Higher education     True   True
# 183                            INSTAL_PAYMENT_PERC_VAR    False  False
# 184                            INSTAL_PAYMENT_PERC_SUM    False  False
# 185                                     INSTAL_DPD_SUM    False  False
# 186                         INSTAL_AMT_INSTALMENT_MEAN    False  False
# 187                          INSTAL_AMT_INSTALMENT_MAX    False  False
# 188                                   HOUSETYPE_MODE_0     True   True
# 189                            HOUR_APPR_PROCESS_START     True  False
# 190                                     FLOORSMAX_MEDI     True   True
# 191                                    FLAG_WORK_PHONE     True   True
# 192                                     FLAG_EMP_PHONE     True   True
# 193                                    FLAG_DOCUMENT_6     True   True
# 194                                    FLAG_DOCUMENT_3     True   True
# 195                                     ENTRANCES_MEDI     True   True
# 196                                      CODE_GENDER_F     True   True
# 197                     CLOSED_MONTHS_BALANCE_SIZE_SUM    False   True
# 198                    CLOSED_DAYS_CREDIT_ENDDATE_MEAN    False  False
# 199                          CLOSED_AMT_CREDIT_SUM_SUM    False  False
# 200                              CC_MONTHS_BALANCE_VAR    False   True
#
#      RFE_LR  RFE_RF  Logistics  Random Forest  Total
# 1      True    True       True           True      6
# 2      True    True       True           True      6
# 3      True    True       True           True      6
# 4      True    True       True           True      6
# 5      True    True       True           True      6
# 6      True    True       True           True      6
# 7      True    True       True           True      6
# 8      True    True       True           True      6
# 9      True    True       True           True      6
# 10     True    True       True           True      6
# 11     True    True       True           True      6
# 12     True    True       True           True      6
# 13     True    True       True           True      6
# 14     True    True       True           True      6
# 15     True    True       True           True      6
# 16     True    True       True           True      6
# 17     True    True       True           True      6
# 18     True    True       True           True      6
# 19     True    True       True           True      6
# 20     True    True       True           True      6
# 21    False    True       True           True      5
# 22    False    True       True           True      5
# 23    False    True       True           True      5
# 24    False    True       True           True      5
# 25    False    True       True           True      5
# 26     True    True      False           True      5
# 27     True    True      False           True      5
# 28     True    True       True           True      5
# 29     True    True       True           True      5
# 30    False    True       True           True      5
# 31     True    True       True           True      5
# 32     True    True       True           True      5
# 33     True    True       True           True      5
# 34     True    True       True           True      5
# 35     True    True       True           True      5
# 36    False    True       True           True      5
# 37    False    True       True           True      5
# 38    False    True       True           True      5
# 39    False    True       True           True      5
# 40    False    True       True           True      5
# 41     True    True       True           True      5
# 42     True    True      False           True      5
# 43     True    True      False           True      5
# 44     True    True       True           True      5
# 45    False    True       True           True      5
# 46     True    True       True           True      5
# 47     True    True       True           True      5
# 48    False    True       True           True      5
# 49    False    True       True           True      5
# 50    False    True       True           True      5
# 51    False    True       True           True      5
# 52     True    True       True           True      5
# 53     True    True       True           True      5
# 54    False    True       True           True      5
# 55    False    True       True           True      5
# 56     True    True       True           True      5
# 57     True    True       True           True      5
# 58     True    True       True           True      5
# 59     True    True       True           True      5
# 60     True    True       True           True      5
# 61    False    True      False           True      4
# 62    False    True      False           True      4
# 63    False    True      False           True      4
# 64    False    True      False           True      4
# 65    False    True       True           True      4
# 66    False    True      False           True      4
# 67    False    True      False           True      4
# 68    False    True      False           True      4
# 69    False   False       True           True      4
# 70    False    True       True          False      4
# 71    False    True      False           True      4
# 72    False    True      False           True      4
# 73     True   False       True          False      4
# 74     True    True       True           True      4
# 75    False    True      False           True      4
# 76     True    True       True           True      4
# 77     True    True       True           True      4
# 78     True    True      False           True      4
# 79     True    True      False           True      4
# 80     True    True       True           True      4
# 81     True    True      False           True      4
# 82     True    True       True           True      4
# 83     True    True       True           True      4
# 84    False    True      False           True      4
# 85    False    True      False           True      4
# 86    False    True       True           True      4
# 87    False    True      False           True      4
# 88    False    True      False           True      4
# 89    False    True      False           True      4
# 90    False    True       True          False      4
# 91     True    True       True           True      4
# 92     True    True       True           True      4
# 93     True    True       True           True      4
# 94     True    True       True           True      4
# 95     True    True       True           True      4
# 96     True    True       True           True      4
# 97     True    True       True           True      4
# 98     True    True       True           True      4
# 99     True    True       True           True      4
# 100    True    True       True           True      4
# 101   False    True       True           True      4
# 102   False    True       True           True      4
# 103    True    True       True           True      4
# 104    True    True      False           True      4
# 105    True    True      False           True      4
# 106   False    True      False           True      4
# 107    True   False       True          False      4
# 108    True   False       True          False      4
# 109    True   False       True          False      4
# 110    True   False       True          False      4
# 111    True   False       True          False      4
# 112    True   False       True          False      4
# 113    True   False       True          False      4
# 114    True    True      False           True      4
# 115    True    True      False           True      4
# 116   False    True       True           True      4
# 117   False   False       True           True      4
# 118    True    True      False           True      4
# 119    True    True      False           True      4
# 120    True    True       True           True      4
# 121    True    True       True           True      4
# 122    True    True       True           True      4
# 123    True    True       True           True      4
# 124    True    True       True           True      4
# 125    True    True       True           True      4
# 126    True    True       True           True      4
# 127    True    True       True           True      4
# 128    True    True      False           True      4
# 129    True    True      False           True      4
# 130    True    True      False           True      4
# 131    True    True       True           True      4
# 132    True    True       True           True      4
# 133    True    True      False           True      4
# 134    True    True      False           True      4
# 135   False    True       True          False      4
# 136   False    True      False           True      4
# 137    True    True       True           True      4
# 138    True    True       True           True      4
# 139    True    True       True           True      4
# 140    True    True       True           True      4
# 141    True    True      False           True      3
# 142   False   False       True          False      3
# 143   False   False       True          False      3
# 144   False   False       True          False      3
# 145   False   False       True          False      3
# 146   False   False       True          False      3
# 147   False   False       True          False      3
# 148   False   False       True          False      3
# 149   False   False       True          False      3
# 150    True    True      False           True      3
# 151    True    True      False           True      3
# 152    True    True      False           True      3
# 153   False   False       True          False      3
# 154    True    True      False           True      3
# 155    True    True      False           True      3
# 156    True    True      False           True      3
# 157    True    True      False           True      3
# 158    True    True      False           True      3
# 159    True    True      False           True      3
# 160    True    True      False           True      3
# 161    True    True      False           True      3
# 162    True    True      False           True      3
# 163    True   False       True           True      3
# 164   False    True       True           True      3
# 165   False    True       True           True      3
# 166    True    True      False           True      3
# 167    True    True      False           True      3
# 168   False    True       True           True      3
# 169   False   False       True          False      3
# 170   False   False       True          False      3
# 171   False    True       True           True      3
# 172    True    True      False           True      3
# 173    True    True      False           True      3
# 174    True    True      False           True      3
# 175    True    True      False           True      3
# 176    True    True      False           True      3
# 177   False    True      False           True      3
# 178   False    True       True           True      3
# 179   False   False       True          False      3
# 180   False   False       True          False      3
# 181   False   False       True          False      3
# 182   False   False       True          False      3
# 183    True    True      False           True      3
# 184    True    True      False           True      3
# 185    True    True      False           True      3
# 186    True    True      False           True      3
# 187    True    True      False           True      3
# 188   False   False       True          False      3
# 189   False    True      False           True      3
# 190   False   False       True          False      3
# 191   False   False       True          False      3
# 192   False   False       True          False      3
# 193   False   False       True          False      3
# 194   False   False       True          False      3
# 195   False   False       True          False      3
# 196   False   False       True          False      3
# 197    True   False       True          False      3
# 198    True    True      False           True      3
# 199    True    True      False           True      3
# 200    True   False       True          False      3

# %%
drop_lstm_feture_selction_df.to_csv("C:/data/processing_data/dataset/drop_lstm_feture_selction.csv")

# %%
drop_lstm_dataframe_select
# Out:
#                                                Pearson  \
# 0                       APPROVED_AMT_DOWN_PAYMENT_MEAN
# 1                           ACTIVE_AMT_CREDIT_SUM_MEAN
# 2                       NAME_INCOME_TYPE_State servant
# 3                                 PREV_AMT_ANNUITY_MAX
# 4                                        LANDAREA_MODE
# 5    PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN
# 6                              BURO_AMT_CREDIT_SUM_MAX
# 7          PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN
# 8             ORGANIZATION_TYPE_Business Entity Type 3
# 9                                         LANDAREA_AVG
# 10                          PREV_AMT_DOWN_PAYMENT_MEAN
# 11                              INSTAL_AMT_PAYMENT_MIN
# 12                      PREV_NAME_CLIENT_TYPE_New_MEAN
# 13                           CLOSED_AMT_CREDIT_SUM_MAX
# 14                                       LANDAREA_MEDI
# 15                          CLOSED_AMT_CREDIT_SUM_MEAN
# 16                            BURO_AMT_CREDIT_SUM_MEAN
# 17                     ACTIVE_DAYS_CREDIT_ENDDATE_MEAN
# 18                           PREV_AMT_DOWN_PAYMENT_MAX
# 19                   NAME_FAMILY_STATUS_Civil marriage
# 20                PREV_NAME_CLIENT_TYPE_Refreshed_MEAN
# 21                     CC_AMT_RECEIVABLE_PRINCIPAL_VAR
# 22                     CC_CNT_DRAWINGS_POS_CURRENT_SUM
# 23   PREV_PRODUCT_COMBINATION_POS mobile with inter...
# 24                       APPROVED_AMT_GOODS_PRICE_MEAN
# 25                                CC_AMT_RECIVABLE_VAR
# 26                         CC_AMT_TOTAL_RECEIVABLE_VAR
# 27                             HOUR_APPR_PROCESS_START
# 28                                  CC_AMT_BALANCE_VAR
# 29                          NAME_FAMILY_STATUS_Married
# 30                       BURO_MONTHS_BALANCE_SIZE_MEAN
# 31                       APPROVED_AMT_APPLICATION_MEAN
# 32                        PREV_NAME_PORTFOLIO_POS_MEAN
# 33             NAME_FAMILY_STATUS_Single / not married
# 34                        APPROVED_AMT_APPLICATION_MAX
# 35                        APPROVED_AMT_GOODS_PRICE_MAX
# 36                        BURO_DAYS_CREDIT_ENDDATE_MAX
# 37                                PREV_AMT_ANNUITY_MIN
# 38                                          FLAG_PHONE
# 39            PREV_NAME_SELLER_INDUSTRY_Furniture_MEAN
# 40                             INSTAL_PAYMENT_DIFF_SUM
# 41                     CC_AMT_DRAWINGS_ATM_CURRENT_SUM
# 42               PREV_NAME_YIELD_GROUP_low_action_MEAN
# 43                               PREV_AMT_ANNUITY_MEAN
# 44                                     NEW_DOC_IND_STD
# 45                       APPROVED_AMT_DOWN_PAYMENT_MAX
# 46                             POS_MONTHS_BALANCE_MEAN
# 47                                      INSTAL_DBD_SUM
# 48             PREV_NAME_GOODS_CATEGORY_Furniture_MEAN
# 49                      CC_AMT_INST_MIN_REGULARITY_VAR
# 50                     APPROVED_RATE_DOWN_PAYMENT_MEAN
# 51                                     FLAG_WORK_PHONE
# 52                                     FLAG_DOCUMENT_6
# 53                         APPROVED_DAYS_DECISION_MEAN
# 54                            INSTAL_PAYMENT_DIFF_MEAN
# 55                  PREV_NAME_SELLER_INDUSTRY_XNA_MEAN
# 56                             POS_MONTHS_BALANCE_SIZE
# 57                                           POS_COUNT
# 58                     ORGANIZATION_TYPE_Self-employed
# 59                              ACTIVE_DAYS_CREDIT_MIN
# 60                 NAME_HOUSING_TYPE_House / apartment
# 61                                          AMT_CREDIT
# 62     PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN
# 63                            DEF_60_CNT_SOCIAL_CIRCLE
# 64     PREV_PRODUCT_COMBINATION_Cash Street: high_MEAN
# 65                         PREV_RATE_DOWN_PAYMENT_MEAN
# 66         PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN
# 67                       INSTAL_DAYS_ENTRY_PAYMENT_SUM
# 68                                PREV_CNT_PAYMENT_SUM
# 69                     CC_CNT_DRAWINGS_ATM_CURRENT_SUM
# 70   PREV_PRODUCT_COMBINATION_POS industry with int...
# 71                             OCCUPATION_TYPE_Drivers
# 72                         CC_CNT_DRAWINGS_CURRENT_SUM
# 73                      PREV_NAME_PORTFOLIO_Cards_MEAN
# 74                            DEF_30_CNT_SOCIAL_CIRCLE
# 75                         CC_AMT_DRAWINGS_CURRENT_MAX
# 76                         NEW_CREDIT_TO_ANNUITY_RATIO
# 77                                  NAME_CONTRACT_TYPE
# 78                               PREV_CNT_PAYMENT_MEAN
# 79                             BURO_STATUS_1_MEAN_MEAN
# 80                             LIVE_CITY_NOT_WORK_CITY
# 81                        PREV_NAME_PORTFOLIO_XNA_MEAN
# 82              PREV_CHANNEL_TYPE_AP+ (Cash loan)_MEAN
# 83                            WALLSMATERIAL_MODE_Panel
# 84                                      NEW_INC_BY_ORG
# 85      PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN
# 86                                   BASEMENTAREA_MODE
# 87                        BURO_DAYS_CREDIT_ENDDATE_MIN
# 88                        CC_AMT_DRAWINGS_CURRENT_MEAN
# 89                      INSTAL_DAYS_ENTRY_PAYMENT_MEAN
# 90                            NEW_PHONE_TO_BIRTH_RATIO
# 91                   PREV_NAME_GOODS_CATEGORY_XNA_MEAN
# 92                           APPROVED_AMT_ANNUITY_MEAN
# 93                      ACTIVE_DAYS_CREDIT_ENDDATE_MAX
# 94                                   BASEMENTAREA_MEDI
# 95                                      ELEVATORS_MODE
# 96                                    BASEMENTAREA_AVG
# 97                     CC_AMT_RECEIVABLE_PRINCIPAL_MIN
# 98                         CC_AMT_TOTAL_RECEIVABLE_MIN
# 99                                CC_AMT_RECIVABLE_MIN
# 100                           APPROVED_AMT_ANNUITY_MAX
# 101                                 CC_AMT_BALANCE_MIN
# 102                         PREV_RATE_DOWN_PAYMENT_MAX
# 103                                 DAYS_EMPLOYED_PERC
# 104                            PREV_DAYS_DECISION_MEAN
# 105                     CC_AMT_INST_MIN_REGULARITY_MAX
# 106                      PREV_NAME_TYPE_SUITE_nan_MEAN
# 107                   PREV_CODE_REJECT_REASON_XAP_MEAN
# 108                         REGION_POPULATION_RELATIVE
# 109                                     ELEVATORS_MEDI
# 110              PREV_NAME_YIELD_GROUP_low_normal_MEAN
# 111                                   NEW_DOC_IND_KURT
# 112                        CC_CNT_DRAWINGS_CURRENT_VAR
# 113                                      ELEVATORS_AVG
# 114                     APPROVED_RATE_DOWN_PAYMENT_MAX
# 115                    CC_AMT_RECEIVABLE_PRINCIPAL_MAX
# 116                                     ENTRANCES_MODE
# 117                      BURO_DAYS_CREDIT_ENDDATE_MEAN
# 118                                  OCCUPATION_TYPE_0
# 119                               CC_AMT_RECIVABLE_MAX
# 120                        CC_AMT_TOTAL_RECEIVABLE_MAX
# 121                                 CC_AMT_BALANCE_MAX
# 122                                    AMT_GOODS_PRICE
# 123                    PREV_NAME_PAYMENT_TYPE_XNA_MEAN
# 124       PREV_NAME_CONTRACT_TYPE_Revolving loans_MEAN
# 125                                     ENTRANCES_MEDI
# 126                                      ENTRANCES_AVG
# 127                 PREV_CODE_REJECT_REASON_LIMIT_MEAN
# 128                                    APARTMENTS_MODE
# 129              BURO_CREDIT_TYPE_Consumer credit_MEAN
# 130                     CLOSED_DAYS_CREDIT_ENDDATE_MIN
# 131                    PREV_NAME_YIELD_GROUP_high_MEAN
# 132          PREV_PRODUCT_COMBINATION_Card Street_MEAN
# 133                                    LIVINGAREA_MODE
# 134                             PREV_DAYS_DECISION_MIN
# 135                         APPROVED_DAYS_DECISION_MIN
# 136                                    APARTMENTS_MEDI
# 137                               WALLSMATERIAL_MODE_0
# 138                                     APARTMENTS_AVG
# 139                                   HOUSETYPE_MODE_0
# 140                                    LIVINGAREA_MEDI
# 141                    CC_AMT_INST_MIN_REGULARITY_MEAN
# 142                             CLOSED_DAYS_CREDIT_VAR
# 143                                     LIVINGAREA_AVG
# 144                       YEARS_BEGINEXPLUATATION_MODE
# 145            PREV_NAME_CONTRACT_STATUS_Approved_MEAN
# 146                                     TOTALAREA_MODE
# 147                        YEARS_BEGINEXPLUATATION_AVG
# 148                       YEARS_BEGINEXPLUATATION_MEDI
# 149                           OCCUPATION_TYPE_Laborers
# 150                      HOUSETYPE_MODE_block of flats
# 151                          NEW_PHONE_TO_EMPLOY_RATIO
# 152                                  DAYS_REGISTRATION
# 153                              EMERGENCYSTATE_MODE_0
# 154                            ACTIVE_DAYS_CREDIT_MEAN
# 155                             EMERGENCYSTATE_MODE_No
# 156                               BURO_DAYS_CREDIT_VAR
# 157                             ACTIVE_DAYS_CREDIT_MAX
# 158                                    FLAG_DOCUMENT_3
# 159                     PREV_NAME_YIELD_GROUP_XNA_MEAN
# 160                              ORGANIZATION_TYPE_XNA
# 161                                     FLAG_EMP_PHONE
# 162                         NAME_INCOME_TYPE_Pensioner
# 163                             REG_CITY_NOT_LIVE_CITY
# 164                                      DAYS_EMPLOYED
# 165                     BURO_CREDIT_ACTIVE_Active_MEAN
# 166                   CC_AMT_RECEIVABLE_PRINCIPAL_MEAN
# 167                       CC_CNT_DRAWINGS_CURRENT_MEAN
# 168                              CC_AMT_RECIVABLE_MEAN
# 169                       CC_AMT_TOTAL_RECEIVABLE_MEAN
# 170                                CC_AMT_BALANCE_MEAN
# 171  NAME_EDUCATION_TYPE_Secondary / secondary special
# 172                                     FLOORSMAX_MODE
# 173                             CLOSED_DAYS_CREDIT_MAX
# 174                                     FLOORSMAX_MEDI
# 175                                      FLOORSMAX_AVG
# 176                             REG_CITY_NOT_WORK_CITY
# 177                                    DAYS_ID_PUBLISH
# 178                               BURO_DAYS_CREDIT_MAX
# 179                                      CODE_GENDER_F
# 180                                      CODE_GENDER_M
# 181                    PREV_CODE_REJECT_REASON_HC_MEAN
# 182               NAME_EDUCATION_TYPE_Higher education
# 183                PREV_NAME_PRODUCT_TYPE_walk-in_MEAN
# 184                        CC_CNT_DRAWINGS_CURRENT_MAX
# 185                             DAYS_LAST_PHONE_CHANGE
# 186                           NAME_INCOME_TYPE_Working
# 187                     CLOSED_DAYS_CREDIT_UPDATE_MEAN
# 188                               REGION_RATING_CLIENT
# 189                        REGION_RATING_CLIENT_W_CITY
# 190                          NEW_CREDIT_TO_GOODS_RATIO
# 191                       BURO_DAYS_CREDIT_UPDATE_MEAN
# 192                            CLOSED_DAYS_CREDIT_MEAN
# 193                             CLOSED_DAYS_CREDIT_MIN
# 194                               BURO_DAYS_CREDIT_MIN
# 195                     BURO_CREDIT_ACTIVE_Closed_MEAN
# 196             PREV_NAME_CONTRACT_STATUS_Refused_MEAN
# 197                                         DAYS_BIRTH
# 198                              BURO_DAYS_CREDIT_MEAN
# 199                                       EXT_SOURCE_2
#
#                                                  Chi-2  \
# 0                                   NAME_CONTRACT_TYPE
# 1                                         FLAG_OWN_CAR
# 2                                           AMT_CREDIT
# 3                                      AMT_GOODS_PRICE
# 4                           REGION_POPULATION_RELATIVE
# 5                                           DAYS_BIRTH
# 6                                      DAYS_ID_PUBLISH
# 7                                       FLAG_EMP_PHONE
# 8                                      FLAG_WORK_PHONE
# 9                                           FLAG_PHONE
# 10                                REGION_RATING_CLIENT
# 11                         REGION_RATING_CLIENT_W_CITY
# 12                              REG_CITY_NOT_LIVE_CITY
# 13                              REG_CITY_NOT_WORK_CITY
# 14                             LIVE_CITY_NOT_WORK_CITY
# 15                                        EXT_SOURCE_2
# 16                                      APARTMENTS_AVG
# 17                                    BASEMENTAREA_AVG
# 18                         YEARS_BEGINEXPLUATATION_AVG
# 19                                       ELEVATORS_AVG
# 20                                       ENTRANCES_AVG
# 21                                       FLOORSMAX_AVG
# 22                                        LANDAREA_AVG
# 23                                      LIVINGAREA_AVG
# 24                                   NONLIVINGAREA_AVG
# 25                                     APARTMENTS_MODE
# 26                                   BASEMENTAREA_MODE
# 27                        YEARS_BEGINEXPLUATATION_MODE
# 28                                      ELEVATORS_MODE
# 29                                      ENTRANCES_MODE
# 30                                      FLOORSMAX_MODE
# 31                                       LANDAREA_MODE
# 32                                     LIVINGAREA_MODE
# 33                                  NONLIVINGAREA_MODE
# 34                                     APARTMENTS_MEDI
# 35                                   BASEMENTAREA_MEDI
# 36                        YEARS_BEGINEXPLUATATION_MEDI
# 37                                      ELEVATORS_MEDI
# 38                                      ENTRANCES_MEDI
# 39                                      FLOORSMAX_MEDI
# 40                                       LANDAREA_MEDI
# 41                                     LIVINGAREA_MEDI
# 42                                  NONLIVINGAREA_MEDI
# 43                                      TOTALAREA_MODE
# 44                              DAYS_LAST_PHONE_CHANGE
# 45                                     FLAG_DOCUMENT_3
# 46                                     FLAG_DOCUMENT_6
# 47                                     FLAG_DOCUMENT_8
# 48                                  DAYS_EMPLOYED_PERC
# 49                         NEW_CREDIT_TO_ANNUITY_RATIO
# 50                                    NEW_DOC_IND_KURT
# 51                                      NEW_INC_BY_ORG
# 52                            NEW_PHONE_TO_BIRTH_RATIO
# 53                                       CODE_GENDER_F
# 54                                       CODE_GENDER_M
# 55                              NAME_TYPE_SUITE_Family
# 56               NAME_INCOME_TYPE_Commercial associate
# 57                          NAME_INCOME_TYPE_Pensioner
# 58                      NAME_INCOME_TYPE_State servant
# 59                            NAME_INCOME_TYPE_Working
# 60                NAME_EDUCATION_TYPE_Higher education
# 61   NAME_EDUCATION_TYPE_Secondary / secondary special
# 62                   NAME_FAMILY_STATUS_Civil marriage
# 63                          NAME_FAMILY_STATUS_Married
# 64             NAME_FAMILY_STATUS_Single / not married
# 65                 NAME_HOUSING_TYPE_House / apartment
# 66                                   OCCUPATION_TYPE_0
# 67                          OCCUPATION_TYPE_Core staff
# 68                             OCCUPATION_TYPE_Drivers
# 69                            OCCUPATION_TYPE_Laborers
# 70                            OCCUPATION_TYPE_Managers
# 71                         OCCUPATION_TYPE_Sales staff
# 72            ORGANIZATION_TYPE_Business Entity Type 3
# 73                     ORGANIZATION_TYPE_Self-employed
# 74                               ORGANIZATION_TYPE_XNA
# 75                                    HOUSETYPE_MODE_0
# 76                       HOUSETYPE_MODE_block of flats
# 77                                WALLSMATERIAL_MODE_0
# 78                            WALLSMATERIAL_MODE_Panel
# 79                     WALLSMATERIAL_MODE_Stone, brick
# 80                               EMERGENCYSTATE_MODE_0
# 81                              EMERGENCYSTATE_MODE_No
# 82                                BURO_DAYS_CREDIT_MIN
# 83                                BURO_DAYS_CREDIT_MAX
# 84                               BURO_DAYS_CREDIT_MEAN
# 85                                BURO_DAYS_CREDIT_VAR
# 86                       BURO_MONTHS_BALANCE_SIZE_MEAN
# 87                      BURO_CREDIT_ACTIVE_Active_MEAN
# 88                      BURO_CREDIT_ACTIVE_Closed_MEAN
# 89                      BURO_CREDIT_TYPE_Car loan_MEAN
# 90               BURO_CREDIT_TYPE_Consumer credit_MEAN
# 91                   BURO_CREDIT_TYPE_Credit card_MEAN
# 92                      BURO_CREDIT_TYPE_Mortgage_MEAN
# 93                             BURO_STATUS_0_MEAN_MEAN
# 94                             BURO_STATUS_1_MEAN_MEAN
# 95                             BURO_STATUS_C_MEAN_MEAN
# 96                              ACTIVE_DAYS_CREDIT_MIN
# 97                             ACTIVE_DAYS_CREDIT_MEAN
# 98                              ACTIVE_DAYS_CREDIT_VAR
# 99                              CLOSED_DAYS_CREDIT_MIN
# 100                             CLOSED_DAYS_CREDIT_MAX
# 101                            CLOSED_DAYS_CREDIT_MEAN
# 102                             CLOSED_DAYS_CREDIT_VAR
# 103                     CLOSED_MONTHS_BALANCE_SIZE_SUM
# 104                              CC_MONTHS_BALANCE_VAR
# 105                                 CC_AMT_BALANCE_MAX
# 106                                CC_AMT_BALANCE_MEAN
# 107                                 CC_AMT_BALANCE_VAR
# 108                        CC_AMT_DRAWINGS_CURRENT_MAX
# 109                       CC_AMT_DRAWINGS_CURRENT_MEAN
# 110                     CC_AMT_INST_MIN_REGULARITY_MAX
# 111                    CC_AMT_INST_MIN_REGULARITY_MEAN
# 112                     CC_AMT_INST_MIN_REGULARITY_VAR
# 113                    CC_AMT_RECEIVABLE_PRINCIPAL_MAX
# 114                   CC_AMT_RECEIVABLE_PRINCIPAL_MEAN
# 115                    CC_AMT_RECEIVABLE_PRINCIPAL_SUM
# 116                    CC_AMT_RECEIVABLE_PRINCIPAL_VAR
# 117                               CC_AMT_RECIVABLE_MAX
# 118                              CC_AMT_RECIVABLE_MEAN
# 119                               CC_AMT_RECIVABLE_VAR
# 120                        CC_AMT_TOTAL_RECEIVABLE_MAX
# 121                       CC_AMT_TOTAL_RECEIVABLE_MEAN
# 122                        CC_AMT_TOTAL_RECEIVABLE_VAR
# 123                    CC_CNT_DRAWINGS_ATM_CURRENT_SUM
# 124                        CC_CNT_DRAWINGS_CURRENT_MAX
# 125                       CC_CNT_DRAWINGS_CURRENT_MEAN
# 126                        CC_CNT_DRAWINGS_CURRENT_SUM
# 127                        CC_CNT_DRAWINGS_CURRENT_VAR
# 128                   CC_CNT_INSTALMENT_MATURE_CUM_SUM
# 129                 CC_NAME_CONTRACT_STATUS_Active_MIN
# 130                CC_NAME_CONTRACT_STATUS_Active_MEAN
# 131                 CC_NAME_CONTRACT_STATUS_Active_SUM
# 132              CC_NAME_CONTRACT_STATUS_Completed_MAX
# 133                                           CC_COUNT
# 134                     INSTAL_DAYS_ENTRY_PAYMENT_MEAN
# 135                            POS_MONTHS_BALANCE_MEAN
# 136                            POS_MONTHS_BALANCE_SIZE
# 137                                          POS_COUNT
# 138                         PREV_RATE_DOWN_PAYMENT_MAX
# 139                        PREV_RATE_DOWN_PAYMENT_MEAN
# 140                             PREV_DAYS_DECISION_MIN
# 141                            PREV_DAYS_DECISION_MEAN
# 142                              PREV_CNT_PAYMENT_MEAN
# 143                               PREV_CNT_PAYMENT_SUM
# 144            PREV_NAME_CONTRACT_TYPE_Cash loans_MEAN
# 145        PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN
# 146       PREV_NAME_CONTRACT_TYPE_Revolving loans_MEAN
# 147            PREV_NAME_CONTRACT_STATUS_Approved_MEAN
# 148            PREV_NAME_CONTRACT_STATUS_Canceled_MEAN
# 149             PREV_NAME_CONTRACT_STATUS_Refused_MEAN
# 150  PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN
# 151                    PREV_NAME_PAYMENT_TYPE_XNA_MEAN
# 152                    PREV_CODE_REJECT_REASON_HC_MEAN
# 153                 PREV_CODE_REJECT_REASON_LIMIT_MEAN
# 154                   PREV_CODE_REJECT_REASON_XAP_MEAN
# 155                 PREV_NAME_TYPE_SUITE_Children_MEAN
# 156                   PREV_NAME_TYPE_SUITE_Family_MEAN
# 157                      PREV_NAME_TYPE_SUITE_nan_MEAN
# 158                     PREV_NAME_CLIENT_TYPE_New_MEAN
# 159               PREV_NAME_CLIENT_TYPE_Refreshed_MEAN
# 160  PREV_NAME_GOODS_CATEGORY_Clothing and Accessor...
# 161  PREV_NAME_GOODS_CATEGORY_Construction Material...
# 162  PREV_NAME_GOODS_CATEGORY_Consumer Electronics_...
# 163            PREV_NAME_GOODS_CATEGORY_Furniture_MEAN
# 164               PREV_NAME_GOODS_CATEGORY_Mobile_MEAN
# 165                  PREV_NAME_GOODS_CATEGORY_XNA_MEAN
# 166                     PREV_NAME_PORTFOLIO_Cards_MEAN
# 167                       PREV_NAME_PORTFOLIO_POS_MEAN
# 168                       PREV_NAME_PORTFOLIO_XNA_MEAN
# 169                PREV_NAME_PRODUCT_TYPE_walk-in_MEAN
# 170                 PREV_NAME_PRODUCT_TYPE_x-sell_MEAN
# 171             PREV_CHANNEL_TYPE_AP+ (Cash loan)_MEAN
# 172              PREV_CHANNEL_TYPE_Contact center_MEAN
# 173     PREV_CHANNEL_TYPE_Credit and cash offices_MEAN
# 174                       PREV_CHANNEL_TYPE_Stone_MEAN
# 175            PREV_NAME_SELLER_INDUSTRY_Clothing_MEAN
# 176        PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN
# 177        PREV_NAME_SELLER_INDUSTRY_Construction_MEAN
# 178  PREV_NAME_SELLER_INDUSTRY_Consumer electronics...
# 179           PREV_NAME_SELLER_INDUSTRY_Furniture_MEAN
# 180                 PREV_NAME_SELLER_INDUSTRY_XNA_MEAN
# 181                     PREV_NAME_YIELD_GROUP_XNA_MEAN
# 182                    PREV_NAME_YIELD_GROUP_high_MEAN
# 183              PREV_NAME_YIELD_GROUP_low_action_MEAN
# 184              PREV_NAME_YIELD_GROUP_low_normal_MEAN
# 185                  PREV_NAME_YIELD_GROUP_middle_MEAN
# 186          PREV_PRODUCT_COMBINATION_Card Street_MEAN
# 187                 PREV_PRODUCT_COMBINATION_Cash_MEAN
# 188    PREV_PRODUCT_COMBINATION_Cash Street: high_MEAN
# 189  PREV_PRODUCT_COMBINATION_Cash Street: middle_MEAN
# 190    PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN
# 191     PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN
# 192  PREV_PRODUCT_COMBINATION_POS household without...
# 193  PREV_PRODUCT_COMBINATION_POS industry with int...
# 194  PREV_PRODUCT_COMBINATION_POS mobile with inter...
# 195                           APPROVED_AMT_ANNUITY_MAX
# 196                     APPROVED_RATE_DOWN_PAYMENT_MAX
# 197                    APPROVED_RATE_DOWN_PAYMENT_MEAN
# 198                         APPROVED_DAYS_DECISION_MIN
# 199                        APPROVED_DAYS_DECISION_MEAN
#
#                                           RFE_LR  \
# 0                                     SK_ID_CURR
# 1                           BURO_DAYS_CREDIT_MIN
# 2                           BURO_DAYS_CREDIT_MAX
# 3                          BURO_DAYS_CREDIT_MEAN
# 4                           BURO_DAYS_CREDIT_VAR
# 5                   BURO_DAYS_CREDIT_ENDDATE_MIN
# 6                   BURO_DAYS_CREDIT_ENDDATE_MAX
# 7                  BURO_DAYS_CREDIT_ENDDATE_MEAN
# 8                   BURO_DAYS_CREDIT_UPDATE_MEAN
# 9               BURO_AMT_CREDIT_MAX_OVERDUE_MEAN
# 10                       BURO_AMT_CREDIT_SUM_MAX
# 11                      BURO_AMT_CREDIT_SUM_MEAN
# 12                       BURO_AMT_CREDIT_SUM_SUM
# 13                  BURO_AMT_CREDIT_SUM_DEBT_MAX
# 14                 BURO_AMT_CREDIT_SUM_DEBT_MEAN
# 15                  BURO_AMT_CREDIT_SUM_DEBT_SUM
# 16                BURO_AMT_CREDIT_SUM_LIMIT_MEAN
# 17                 BURO_AMT_CREDIT_SUM_LIMIT_SUM
# 18                   BURO_MONTHS_BALANCE_MIN_MIN
# 19                 BURO_MONTHS_BALANCE_SIZE_MEAN
# 20                  BURO_MONTHS_BALANCE_SIZE_SUM
# 21                        ACTIVE_DAYS_CREDIT_MIN
# 22                        ACTIVE_DAYS_CREDIT_MAX
# 23                       ACTIVE_DAYS_CREDIT_MEAN
# 24                        ACTIVE_DAYS_CREDIT_VAR
# 25                ACTIVE_DAYS_CREDIT_ENDDATE_MIN
# 26                ACTIVE_DAYS_CREDIT_ENDDATE_MAX
# 27               ACTIVE_DAYS_CREDIT_ENDDATE_MEAN
# 28                ACTIVE_DAYS_CREDIT_UPDATE_MEAN
# 29            ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN
# 30                     ACTIVE_AMT_CREDIT_SUM_MAX
# 31                    ACTIVE_AMT_CREDIT_SUM_MEAN
# 32                     ACTIVE_AMT_CREDIT_SUM_SUM
# 33                ACTIVE_AMT_CREDIT_SUM_DEBT_MAX
# 34               ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN
# 35                ACTIVE_AMT_CREDIT_SUM_DEBT_SUM
# 36              ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN
# 37               ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM
# 38                ACTIVE_MONTHS_BALANCE_SIZE_SUM
# 39                        CLOSED_DAYS_CREDIT_MIN
# 40                        CLOSED_DAYS_CREDIT_MAX
# 41                       CLOSED_DAYS_CREDIT_MEAN
# 42                        CLOSED_DAYS_CREDIT_VAR
# 43                CLOSED_DAYS_CREDIT_ENDDATE_MIN
# 44                CLOSED_DAYS_CREDIT_ENDDATE_MAX
# 45               CLOSED_DAYS_CREDIT_ENDDATE_MEAN
# 46                CLOSED_DAYS_CREDIT_UPDATE_MEAN
# 47            CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN
# 48                     CLOSED_AMT_CREDIT_SUM_MAX
# 49                    CLOSED_AMT_CREDIT_SUM_MEAN
# 50                     CLOSED_AMT_CREDIT_SUM_SUM
# 51                CLOSED_MONTHS_BALANCE_SIZE_SUM
# 52                NEW_RATIO_BURO_DAYS_CREDIT_VAR
# 53        NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MIN
# 54        NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MAX
# 55       NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MEAN
# 56             NEW_RATIO_BURO_AMT_CREDIT_SUM_MAX
# 57            NEW_RATIO_BURO_AMT_CREDIT_SUM_MEAN
# 58             NEW_RATIO_BURO_AMT_CREDIT_SUM_SUM
# 59                         CC_MONTHS_BALANCE_MIN
# 60                        CC_MONTHS_BALANCE_MEAN
# 61                         CC_MONTHS_BALANCE_SUM
# 62                         CC_MONTHS_BALANCE_VAR
# 63                            CC_AMT_BALANCE_MIN
# 64                            CC_AMT_BALANCE_MAX
# 65                           CC_AMT_BALANCE_MEAN
# 66                            CC_AMT_BALANCE_SUM
# 67                            CC_AMT_BALANCE_VAR
# 68                CC_AMT_CREDIT_LIMIT_ACTUAL_MIN
# 69                CC_AMT_CREDIT_LIMIT_ACTUAL_MAX
# 70               CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN
# 71                CC_AMT_CREDIT_LIMIT_ACTUAL_SUM
# 72               CC_AMT_DRAWINGS_ATM_CURRENT_SUM
# 73                   CC_AMT_DRAWINGS_CURRENT_MAX
# 74                  CC_AMT_DRAWINGS_CURRENT_MEAN
# 75                   CC_AMT_DRAWINGS_CURRENT_SUM
# 76             CC_AMT_DRAWINGS_OTHER_CURRENT_SUM
# 77               CC_AMT_DRAWINGS_POS_CURRENT_SUM
# 78                CC_AMT_INST_MIN_REGULARITY_MIN
# 79                CC_AMT_INST_MIN_REGULARITY_MAX
# 80               CC_AMT_INST_MIN_REGULARITY_MEAN
# 81                CC_AMT_INST_MIN_REGULARITY_SUM
# 82                CC_AMT_INST_MIN_REGULARITY_VAR
# 83                    CC_AMT_PAYMENT_CURRENT_SUM
# 84              CC_AMT_PAYMENT_TOTAL_CURRENT_MAX
# 85             CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN
# 86              CC_AMT_PAYMENT_TOTAL_CURRENT_SUM
# 87               CC_AMT_RECEIVABLE_PRINCIPAL_MIN
# 88               CC_AMT_RECEIVABLE_PRINCIPAL_MAX
# 89              CC_AMT_RECEIVABLE_PRINCIPAL_MEAN
# 90               CC_AMT_RECEIVABLE_PRINCIPAL_SUM
# 91               CC_AMT_RECEIVABLE_PRINCIPAL_VAR
# 92                          CC_AMT_RECIVABLE_MIN
# 93                          CC_AMT_RECIVABLE_MAX
# 94                         CC_AMT_RECIVABLE_MEAN
# 95                          CC_AMT_RECIVABLE_SUM
# 96                          CC_AMT_RECIVABLE_VAR
# 97                   CC_AMT_TOTAL_RECEIVABLE_MIN
# 98                   CC_AMT_TOTAL_RECEIVABLE_MAX
# 99                  CC_AMT_TOTAL_RECEIVABLE_MEAN
# 100                  CC_AMT_TOTAL_RECEIVABLE_SUM
# 101                  CC_AMT_TOTAL_RECEIVABLE_VAR
# 102                  CC_CNT_DRAWINGS_CURRENT_SUM
# 103                  CC_CNT_DRAWINGS_CURRENT_VAR
# 104             CC_CNT_INSTALMENT_MATURE_CUM_SUM
# 105             CC_CNT_INSTALMENT_MATURE_CUM_VAR
# 106                                CC_SK_DPD_MAX
# 107                                CC_SK_DPD_SUM
# 108                                CC_SK_DPD_VAR
# 109                            CC_SK_DPD_DEF_SUM
# 110                            CC_SK_DPD_DEF_VAR
# 111           CC_NAME_CONTRACT_STATUS_Active_SUM
# 112                                     CC_COUNT
# 113        INSTAL_NUM_INSTALMENT_VERSION_NUNIQUE
# 114                               INSTAL_DPD_MAX
# 115                               INSTAL_DPD_SUM
# 116                               INSTAL_DBD_MAX
# 117                              INSTAL_DBD_MEAN
# 118                               INSTAL_DBD_SUM
# 119                      INSTAL_PAYMENT_PERC_MAX
# 120                      INSTAL_PAYMENT_PERC_SUM
# 121                      INSTAL_PAYMENT_PERC_VAR
# 122                      INSTAL_PAYMENT_DIFF_MAX
# 123                     INSTAL_PAYMENT_DIFF_MEAN
# 124                      INSTAL_PAYMENT_DIFF_SUM
# 125                    INSTAL_AMT_INSTALMENT_MAX
# 126                   INSTAL_AMT_INSTALMENT_MEAN
# 127                    INSTAL_AMT_INSTALMENT_SUM
# 128                       INSTAL_AMT_PAYMENT_MIN
# 129                       INSTAL_AMT_PAYMENT_MAX
# 130                      INSTAL_AMT_PAYMENT_MEAN
# 131                       INSTAL_AMT_PAYMENT_SUM
# 132                INSTAL_DAYS_ENTRY_PAYMENT_MAX
# 133               INSTAL_DAYS_ENTRY_PAYMENT_MEAN
# 134                INSTAL_DAYS_ENTRY_PAYMENT_SUM
# 135                                 INSTAL_COUNT
# 136                       POS_MONTHS_BALANCE_MAX
# 137                      POS_MONTHS_BALANCE_MEAN
# 138                      POS_MONTHS_BALANCE_SIZE
# 139                               POS_SK_DPD_MAX
# 140                              POS_SK_DPD_MEAN
# 141         POS_NAME_CONTRACT_STATUS_Active_MEAN
# 142                                    POS_COUNT
# 143                         PREV_AMT_ANNUITY_MIN
# 144                         PREV_AMT_ANNUITY_MAX
# 145                        PREV_AMT_ANNUITY_MEAN
# 146                     PREV_AMT_APPLICATION_MIN
# 147                     PREV_AMT_APPLICATION_MAX
# 148                    PREV_AMT_APPLICATION_MEAN
# 149                          PREV_AMT_CREDIT_MIN
# 150                          PREV_AMT_CREDIT_MAX
# 151                         PREV_AMT_CREDIT_MEAN
# 152                     PREV_APP_CREDIT_PERC_MIN
# 153                     PREV_APP_CREDIT_PERC_MAX
# 154                    PREV_APP_CREDIT_PERC_MEAN
# 155                    PREV_AMT_DOWN_PAYMENT_MIN
# 156                    PREV_AMT_DOWN_PAYMENT_MAX
# 157                   PREV_AMT_DOWN_PAYMENT_MEAN
# 158                     PREV_AMT_GOODS_PRICE_MIN
# 159                     PREV_AMT_GOODS_PRICE_MAX
# 160                    PREV_AMT_GOODS_PRICE_MEAN
# 161             PREV_HOUR_APPR_PROCESS_START_MIN
# 162             PREV_HOUR_APPR_PROCESS_START_MAX
# 163            PREV_HOUR_APPR_PROCESS_START_MEAN
# 164                       PREV_DAYS_DECISION_MIN
# 165                       PREV_DAYS_DECISION_MAX
# 166                      PREV_DAYS_DECISION_MEAN
# 167                        PREV_CNT_PAYMENT_MEAN
# 168                         PREV_CNT_PAYMENT_SUM
# 169  PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN
# 170         PREV_NAME_CASH_LOAN_PURPOSE_XAP_MEAN
# 171      PREV_NAME_CONTRACT_STATUS_Approved_MEAN
# 172             PREV_CODE_REJECT_REASON_XAP_MEAN
# 173              PREV_NAME_PRODUCT_TYPE_XNA_MEAN
# 174                     APPROVED_AMT_ANNUITY_MIN
# 175                     APPROVED_AMT_ANNUITY_MAX
# 176                    APPROVED_AMT_ANNUITY_MEAN
# 177                 APPROVED_AMT_APPLICATION_MIN
# 178                 APPROVED_AMT_APPLICATION_MAX
# 179                APPROVED_AMT_APPLICATION_MEAN
# 180                      APPROVED_AMT_CREDIT_MIN
# 181                      APPROVED_AMT_CREDIT_MAX
# 182                     APPROVED_AMT_CREDIT_MEAN
# 183                 APPROVED_APP_CREDIT_PERC_MIN
# 184                 APPROVED_APP_CREDIT_PERC_MAX
# 185                APPROVED_APP_CREDIT_PERC_MEAN
# 186                APPROVED_AMT_DOWN_PAYMENT_MIN
# 187                APPROVED_AMT_DOWN_PAYMENT_MAX
# 188               APPROVED_AMT_DOWN_PAYMENT_MEAN
# 189                 APPROVED_AMT_GOODS_PRICE_MIN
# 190                 APPROVED_AMT_GOODS_PRICE_MAX
# 191                APPROVED_AMT_GOODS_PRICE_MEAN
# 192         APPROVED_HOUR_APPR_PROCESS_START_MIN
# 193         APPROVED_HOUR_APPR_PROCESS_START_MAX
# 194        APPROVED_HOUR_APPR_PROCESS_START_MEAN
# 195                   APPROVED_DAYS_DECISION_MIN
# 196                   APPROVED_DAYS_DECISION_MAX
# 197                  APPROVED_DAYS_DECISION_MEAN
# 198                    APPROVED_CNT_PAYMENT_MEAN
# 199                     APPROVED_CNT_PAYMENT_SUM
#
#                                                 RFE_RF  \
# 0                                           SK_ID_CURR
# 1                                     AMT_INCOME_TOTAL
# 2                                           AMT_CREDIT
# 3                                          AMT_ANNUITY
# 4                                      AMT_GOODS_PRICE
# 5                           REGION_POPULATION_RELATIVE
# 6                                           DAYS_BIRTH
# 7                                        DAYS_EMPLOYED
# 8                                    DAYS_REGISTRATION
# 9                                      DAYS_ID_PUBLISH
# 10                             HOUR_APPR_PROCESS_START
# 11                                        EXT_SOURCE_2
# 12                                      APARTMENTS_AVG
# 13                         YEARS_BEGINEXPLUATATION_AVG
# 14                                        LANDAREA_AVG
# 15                                      LIVINGAREA_AVG
# 16                                     APARTMENTS_MODE
# 17                        YEARS_BEGINEXPLUATATION_MODE
# 18                                     LIVINGAREA_MODE
# 19                                     APARTMENTS_MEDI
# 20                        YEARS_BEGINEXPLUATATION_MEDI
# 21                                     LIVINGAREA_MEDI
# 22                                      TOTALAREA_MODE
# 23                            OBS_30_CNT_SOCIAL_CIRCLE
# 24                            OBS_60_CNT_SOCIAL_CIRCLE
# 25                              DAYS_LAST_PHONE_CHANGE
# 26                                  DAYS_EMPLOYED_PERC
# 27                                  INCOME_CREDIT_PERC
# 28                                   INCOME_PER_PERSON
# 29                                 ANNUITY_INCOME_PERC
# 30                                        PAYMENT_RATE
# 31                         NEW_CREDIT_TO_ANNUITY_RATIO
# 32                           NEW_CREDIT_TO_GOODS_RATIO
# 33                                    NEW_INC_PER_CHLD
# 34                                      NEW_INC_BY_ORG
# 35                            NEW_PHONE_TO_BIRTH_RATIO
# 36                           NEW_PHONE_TO_EMPLOY_RATIO
# 37                                BURO_DAYS_CREDIT_MIN
# 38                                BURO_DAYS_CREDIT_MAX
# 39                               BURO_DAYS_CREDIT_MEAN
# 40                                BURO_DAYS_CREDIT_VAR
# 41                        BURO_DAYS_CREDIT_ENDDATE_MIN
# 42                        BURO_DAYS_CREDIT_ENDDATE_MAX
# 43                       BURO_DAYS_CREDIT_ENDDATE_MEAN
# 44                        BURO_DAYS_CREDIT_UPDATE_MEAN
# 45                    BURO_AMT_CREDIT_MAX_OVERDUE_MEAN
# 46                             BURO_AMT_CREDIT_SUM_MAX
# 47                            BURO_AMT_CREDIT_SUM_MEAN
# 48                             BURO_AMT_CREDIT_SUM_SUM
# 49                        BURO_AMT_CREDIT_SUM_DEBT_MAX
# 50                       BURO_AMT_CREDIT_SUM_DEBT_MEAN
# 51                        BURO_AMT_CREDIT_SUM_DEBT_SUM
# 52                        BURO_MONTHS_BALANCE_SIZE_SUM
# 53                      BURO_CREDIT_ACTIVE_Active_MEAN
# 54                      BURO_CREDIT_ACTIVE_Closed_MEAN
# 55                   BURO_CREDIT_TYPE_Credit card_MEAN
# 56                             BURO_STATUS_0_MEAN_MEAN
# 57                             BURO_STATUS_1_MEAN_MEAN
# 58                              ACTIVE_DAYS_CREDIT_MIN
# 59                              ACTIVE_DAYS_CREDIT_MAX
# 60                             ACTIVE_DAYS_CREDIT_MEAN
# 61                              ACTIVE_DAYS_CREDIT_VAR
# 62                      ACTIVE_DAYS_CREDIT_ENDDATE_MIN
# 63                      ACTIVE_DAYS_CREDIT_ENDDATE_MAX
# 64                     ACTIVE_DAYS_CREDIT_ENDDATE_MEAN
# 65                      ACTIVE_DAYS_CREDIT_UPDATE_MEAN
# 66                  ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN
# 67                           ACTIVE_AMT_CREDIT_SUM_MAX
# 68                          ACTIVE_AMT_CREDIT_SUM_MEAN
# 69                           ACTIVE_AMT_CREDIT_SUM_SUM
# 70                      ACTIVE_AMT_CREDIT_SUM_DEBT_MAX
# 71                     ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN
# 72                      ACTIVE_AMT_CREDIT_SUM_DEBT_SUM
# 73                              CLOSED_DAYS_CREDIT_MIN
# 74                              CLOSED_DAYS_CREDIT_MAX
# 75                             CLOSED_DAYS_CREDIT_MEAN
# 76                              CLOSED_DAYS_CREDIT_VAR
# 77                      CLOSED_DAYS_CREDIT_ENDDATE_MIN
# 78                      CLOSED_DAYS_CREDIT_ENDDATE_MAX
# 79                     CLOSED_DAYS_CREDIT_ENDDATE_MEAN
# 80                      CLOSED_DAYS_CREDIT_UPDATE_MEAN
# 81                           CLOSED_AMT_CREDIT_SUM_MAX
# 82                          CLOSED_AMT_CREDIT_SUM_MEAN
# 83                           CLOSED_AMT_CREDIT_SUM_SUM
# 84                      NEW_RATIO_BURO_DAYS_CREDIT_MIN
# 85                      NEW_RATIO_BURO_DAYS_CREDIT_MAX
# 86                     NEW_RATIO_BURO_DAYS_CREDIT_MEAN
# 87                      NEW_RATIO_BURO_DAYS_CREDIT_VAR
# 88              NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MIN
# 89              NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MAX
# 90             NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MEAN
# 91              NEW_RATIO_BURO_DAYS_CREDIT_UPDATE_MEAN
# 92                   NEW_RATIO_BURO_AMT_CREDIT_SUM_MAX
# 93                  NEW_RATIO_BURO_AMT_CREDIT_SUM_MEAN
# 94                   NEW_RATIO_BURO_AMT_CREDIT_SUM_SUM
# 95                        CC_CNT_DRAWINGS_CURRENT_MEAN
# 96                         CC_CNT_DRAWINGS_CURRENT_VAR
# 97                                      INSTAL_DPD_MAX
# 98                                     INSTAL_DPD_MEAN
# 99                                      INSTAL_DPD_SUM
# 100                                     INSTAL_DBD_MAX
# 101                                    INSTAL_DBD_MEAN
# 102                                     INSTAL_DBD_SUM
# 103                           INSTAL_PAYMENT_PERC_MEAN
# 104                            INSTAL_PAYMENT_PERC_SUM
# 105                            INSTAL_PAYMENT_PERC_VAR
# 106                            INSTAL_PAYMENT_DIFF_MAX
# 107                           INSTAL_PAYMENT_DIFF_MEAN
# 108                            INSTAL_PAYMENT_DIFF_SUM
# 109                            INSTAL_PAYMENT_DIFF_VAR
# 110                          INSTAL_AMT_INSTALMENT_MAX
# 111                         INSTAL_AMT_INSTALMENT_MEAN
# 112                          INSTAL_AMT_INSTALMENT_SUM
# 113                             INSTAL_AMT_PAYMENT_MIN
# 114                             INSTAL_AMT_PAYMENT_MAX
# 115                            INSTAL_AMT_PAYMENT_MEAN
# 116                             INSTAL_AMT_PAYMENT_SUM
# 117                      INSTAL_DAYS_ENTRY_PAYMENT_MAX
# 118                     INSTAL_DAYS_ENTRY_PAYMENT_MEAN
# 119                      INSTAL_DAYS_ENTRY_PAYMENT_SUM
# 120                                       INSTAL_COUNT
# 121                             POS_MONTHS_BALANCE_MAX
# 122                            POS_MONTHS_BALANCE_MEAN
# 123                            POS_MONTHS_BALANCE_SIZE
# 124                                POS_SK_DPD_DEF_MEAN
# 125               POS_NAME_CONTRACT_STATUS_Active_MEAN
# 126            POS_NAME_CONTRACT_STATUS_Completed_MEAN
# 127               POS_NAME_CONTRACT_STATUS_Signed_MEAN
# 128                                          POS_COUNT
# 129                               PREV_AMT_ANNUITY_MIN
# 130                               PREV_AMT_ANNUITY_MAX
# 131                              PREV_AMT_ANNUITY_MEAN
# 132                           PREV_AMT_APPLICATION_MIN
# 133                           PREV_AMT_APPLICATION_MAX
# 134                          PREV_AMT_APPLICATION_MEAN
# 135                                PREV_AMT_CREDIT_MIN
# 136                                PREV_AMT_CREDIT_MAX
# 137                               PREV_AMT_CREDIT_MEAN
# 138                           PREV_APP_CREDIT_PERC_MIN
# 139                           PREV_APP_CREDIT_PERC_MAX
# 140                          PREV_APP_CREDIT_PERC_MEAN
# 141                           PREV_APP_CREDIT_PERC_VAR
# 142                          PREV_AMT_DOWN_PAYMENT_MAX
# 143                         PREV_AMT_DOWN_PAYMENT_MEAN
# 144                           PREV_AMT_GOODS_PRICE_MIN
# 145                           PREV_AMT_GOODS_PRICE_MAX
# 146                          PREV_AMT_GOODS_PRICE_MEAN
# 147                   PREV_HOUR_APPR_PROCESS_START_MIN
# 148                   PREV_HOUR_APPR_PROCESS_START_MAX
# 149                  PREV_HOUR_APPR_PROCESS_START_MEAN
# 150                         PREV_RATE_DOWN_PAYMENT_MAX
# 151                        PREV_RATE_DOWN_PAYMENT_MEAN
# 152                             PREV_DAYS_DECISION_MIN
# 153                             PREV_DAYS_DECISION_MAX
# 154                            PREV_DAYS_DECISION_MEAN
# 155                              PREV_CNT_PAYMENT_MEAN
# 156                               PREV_CNT_PAYMENT_SUM
# 157      PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN
# 158            PREV_NAME_CONTRACT_STATUS_Approved_MEAN
# 159             PREV_NAME_CONTRACT_STATUS_Refused_MEAN
# 160  PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN
# 161                    PREV_NAME_PAYMENT_TYPE_XNA_MEAN
# 162                    PREV_CODE_REJECT_REASON_HC_MEAN
# 163                   PREV_CODE_REJECT_REASON_XAP_MEAN
# 164            PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN
# 165                      PREV_NAME_TYPE_SUITE_nan_MEAN
# 166                PREV_NAME_CLIENT_TYPE_Repeater_MEAN
# 167                       PREV_NAME_PORTFOLIO_XNA_MEAN
# 168                PREV_NAME_PRODUCT_TYPE_walk-in_MEAN
# 169                     PREV_NAME_YIELD_GROUP_XNA_MEAN
# 170                    PREV_NAME_YIELD_GROUP_high_MEAN
# 171                  PREV_NAME_YIELD_GROUP_middle_MEAN
# 172                           APPROVED_AMT_ANNUITY_MIN
# 173                           APPROVED_AMT_ANNUITY_MAX
# 174                          APPROVED_AMT_ANNUITY_MEAN
# 175                       APPROVED_AMT_APPLICATION_MIN
# 176                       APPROVED_AMT_APPLICATION_MAX
# 177                      APPROVED_AMT_APPLICATION_MEAN
# 178                            APPROVED_AMT_CREDIT_MIN
# 179                            APPROVED_AMT_CREDIT_MAX
# 180                           APPROVED_AMT_CREDIT_MEAN
# 181                       APPROVED_APP_CREDIT_PERC_MIN
# 182                       APPROVED_APP_CREDIT_PERC_MAX
# 183                      APPROVED_APP_CREDIT_PERC_MEAN
# 184                       APPROVED_APP_CREDIT_PERC_VAR
# 185                      APPROVED_AMT_DOWN_PAYMENT_MAX
# 186                     APPROVED_AMT_DOWN_PAYMENT_MEAN
# 187                       APPROVED_AMT_GOODS_PRICE_MIN
# 188                       APPROVED_AMT_GOODS_PRICE_MAX
# 189                      APPROVED_AMT_GOODS_PRICE_MEAN
# 190               APPROVED_HOUR_APPR_PROCESS_START_MIN
# 191               APPROVED_HOUR_APPR_PROCESS_START_MAX
# 192              APPROVED_HOUR_APPR_PROCESS_START_MEAN
# 193                     APPROVED_RATE_DOWN_PAYMENT_MAX
# 194                    APPROVED_RATE_DOWN_PAYMENT_MEAN
# 195                         APPROVED_DAYS_DECISION_MIN
# 196                         APPROVED_DAYS_DECISION_MAX
# 197                        APPROVED_DAYS_DECISION_MEAN
# 198                          APPROVED_CNT_PAYMENT_MEAN
# 199                           APPROVED_CNT_PAYMENT_SUM
#
#                                           embedding_LR  \
# 0                                         FLAG_OWN_CAR
# 1                                         CNT_CHILDREN
# 2                                           AMT_CREDIT
# 3                                          AMT_ANNUITY
# 4                                      AMT_GOODS_PRICE
# 5                           REGION_POPULATION_RELATIVE
# 6                                           DAYS_BIRTH
# 7                                        DAYS_EMPLOYED
# 8                                    DAYS_REGISTRATION
# 9                                      DAYS_ID_PUBLISH
# 10                                      FLAG_EMP_PHONE
# 11                                     FLAG_WORK_PHONE
# 12                         REGION_RATING_CLIENT_W_CITY
# 13                              REG_CITY_NOT_LIVE_CITY
# 14                                        EXT_SOURCE_2
# 15                                    BASEMENTAREA_AVG
# 16                                        LANDAREA_AVG
# 17                                   NONLIVINGAREA_AVG
# 18                                  NONLIVINGAREA_MODE
# 19                                     APARTMENTS_MEDI
# 20                                      ENTRANCES_MEDI
# 21                                      FLOORSMAX_MEDI
# 22                            DEF_30_CNT_SOCIAL_CIRCLE
# 23                            OBS_60_CNT_SOCIAL_CIRCLE
# 24                            DEF_60_CNT_SOCIAL_CIRCLE
# 25                              DAYS_LAST_PHONE_CHANGE
# 26                                     FLAG_DOCUMENT_3
# 27                                     FLAG_DOCUMENT_6
# 28                           AMT_REQ_CREDIT_BUREAU_QRT
# 29                          AMT_REQ_CREDIT_BUREAU_YEAR
# 30                                  DAYS_EMPLOYED_PERC
# 31                                 ANNUITY_INCOME_PERC
# 32                                        PAYMENT_RATE
# 33                         NEW_CREDIT_TO_ANNUITY_RATIO
# 34                           NEW_CREDIT_TO_GOODS_RATIO
# 35                                     NEW_DOC_IND_AVG
# 36                                     NEW_DOC_IND_STD
# 37                                    NEW_DOC_IND_KURT
# 38                                    NEW_LIVE_IND_SUM
# 39                                    NEW_INC_PER_CHLD
# 40                                       CODE_GENDER_F
# 41                          NAME_INCOME_TYPE_Pensioner
# 42                      NAME_INCOME_TYPE_State servant
# ...
# 121                            POS_MONTHS_BALANCE_SIZE
# 122                                    POS_SK_DPD_MEAN
# 123                                 POS_SK_DPD_DEF_MAX
# 124                                POS_SK_DPD_DEF_MEAN
# 125               POS_NAME_CONTRACT_STATUS_Active_MEAN
# 126            POS_NAME_CONTRACT_STATUS_Completed_MEAN
# 127               POS_NAME_CONTRACT_STATUS_Signed_MEAN
# 128                                          POS_COUNT
# 129                               PREV_AMT_ANNUITY_MIN
# 130                               PREV_AMT_ANNUITY_MAX
# 131                              PREV_AMT_ANNUITY_MEAN
# 132                           PREV_AMT_APPLICATION_MIN
# 133                           PREV_AMT_APPLICATION_MAX
# 134                          PREV_AMT_APPLICATION_MEAN
# 135                                PREV_AMT_CREDIT_MIN
# 136                                PREV_AMT_CREDIT_MAX
# 137                               PREV_AMT_CREDIT_MEAN
# 138                           PREV_APP_CREDIT_PERC_MIN
# 139                           PREV_APP_CREDIT_PERC_MAX
# 140                          PREV_APP_CREDIT_PERC_MEAN
# 141                           PREV_APP_CREDIT_PERC_VAR
# 142                          PREV_AMT_DOWN_PAYMENT_MAX
# 143                         PREV_AMT_DOWN_PAYMENT_MEAN
# 144                           PREV_AMT_GOODS_PRICE_MIN
# 145                           PREV_AMT_GOODS_PRICE_MAX
# 146                          PREV_AMT_GOODS_PRICE_MEAN
# 147                   PREV_HOUR_APPR_PROCESS_START_MIN
# 148                   PREV_HOUR_APPR_PROCESS_START_MAX
# 149                  PREV_HOUR_APPR_PROCESS_START_MEAN
# 150                         PREV_RATE_DOWN_PAYMENT_MAX
# 151                        PREV_RATE_DOWN_PAYMENT_MEAN
# 152                             PREV_DAYS_DECISION_MIN
# 153                             PREV_DAYS_DECISION_MAX
# 154                            PREV_DAYS_DECISION_MEAN
# 155                              PREV_CNT_PAYMENT_MEAN
# 156                               PREV_CNT_PAYMENT_SUM
# 157      PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN
# 158     PREV_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN
# 159            PREV_NAME_CONTRACT_STATUS_Approved_MEAN
# 160             PREV_NAME_CONTRACT_STATUS_Refused_MEAN
# 161  PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN
# 162                    PREV_NAME_PAYMENT_TYPE_XNA_MEAN
# 163                    PREV_CODE_REJECT_REASON_HC_MEAN
# 164                   PREV_CODE_REJECT_REASON_XAP_MEAN
# 165            PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN
# 166                      PREV_NAME_TYPE_SUITE_nan_MEAN
# 167                       PREV_NAME_PORTFOLIO_XNA_MEAN
# 168        PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN
# 169                     PREV_NAME_YIELD_GROUP_XNA_MEAN
# 170                    PREV_NAME_YIELD_GROUP_high_MEAN
# 171                  PREV_NAME_YIELD_GROUP_middle_MEAN
# 172                           APPROVED_AMT_ANNUITY_MIN
# 173                           APPROVED_AMT_ANNUITY_MAX
# 174                          APPROVED_AMT_ANNUITY_MEAN
# 175                       APPROVED_AMT_APPLICATION_MIN
# 176                       APPROVED_AMT_APPLICATION_MAX
# 177                      APPROVED_AMT_APPLICATION_MEAN
# 178                            APPROVED_AMT_CREDIT_MIN
# 179                            APPROVED_AMT_CREDIT_MAX
# 180                           APPROVED_AMT_CREDIT_MEAN
# 181                       APPROVED_APP_CREDIT_PERC_MIN
# 182                       APPROVED_APP_CREDIT_PERC_MAX
# 183                      APPROVED_APP_CREDIT_PERC_MEAN
# 184                       APPROVED_APP_CREDIT_PERC_VAR
# 185                      APPROVED_AMT_DOWN_PAYMENT_MAX
# 186                     APPROVED_AMT_DOWN_PAYMENT_MEAN
# 187                       APPROVED_AMT_GOODS_PRICE_MIN
# 188                       APPROVED_AMT_GOODS_PRICE_MAX
# 189                      APPROVED_AMT_GOODS_PRICE_MEAN
# 190               APPROVED_HOUR_APPR_PROCESS_START_MIN
# 191               APPROVED_HOUR_APPR_PROCESS_START_MAX
# 192              APPROVED_HOUR_APPR_PROCESS_START_MEAN
# 193                     APPROVED_RATE_DOWN_PAYMENT_MAX
# 194                    APPROVED_RATE_DOWN_PAYMENT_MEAN
# 195                         APPROVED_DAYS_DECISION_MIN
# 196                         APPROVED_DAYS_DECISION_MAX
# 197                        APPROVED_DAYS_DECISION_MEAN
# 198                          APPROVED_CNT_PAYMENT_MEAN
# 199                           APPROVED_CNT_PAYMENT_SUM
#
#                                            combination
# 0                              PREV_DAYS_DECISION_MEAN
# 1                     PREV_CODE_REJECT_REASON_XAP_MEAN
# 2                                 PREV_CNT_PAYMENT_SUM
# 3                                PREV_CNT_PAYMENT_MEAN
# 4                              POS_MONTHS_BALANCE_SIZE
# 5                              POS_MONTHS_BALANCE_MEAN
# 6                                            POS_COUNT
# 7                       INSTAL_DAYS_ENTRY_PAYMENT_MEAN
# 8                               CLOSED_DAYS_CREDIT_VAR
# 9                              CLOSED_DAYS_CREDIT_MEAN
# 10                         CC_CNT_DRAWINGS_CURRENT_VAR
# 11                                BURO_DAYS_CREDIT_VAR
# 12                                BURO_DAYS_CREDIT_MIN
# 13                               BURO_DAYS_CREDIT_MEAN
# 14                                BURO_DAYS_CREDIT_MAX
# 15                          APPROVED_DAYS_DECISION_MIN
# 16                         APPROVED_DAYS_DECISION_MEAN
# 17                            APPROVED_AMT_ANNUITY_MAX
# 18                              ACTIVE_DAYS_CREDIT_MIN
# 19                             ACTIVE_DAYS_CREDIT_MEAN
# 20                          REGION_POPULATION_RELATIVE
# 21                         PREV_RATE_DOWN_PAYMENT_MEAN
# 22                          PREV_RATE_DOWN_PAYMENT_MAX
# 23                     PREV_NAME_PAYMENT_TYPE_XNA_MEAN
# 24              PREV_NAME_CONTRACT_STATUS_Refused_MEAN
# 25             PREV_NAME_CONTRACT_STATUS_Approved_MEAN
# 26                              PREV_DAYS_DECISION_MIN
# 27                               PREV_AMT_ANNUITY_MEAN
# 28                                PREV_AMT_ANNUITY_MAX
# 29                         NEW_CREDIT_TO_ANNUITY_RATIO
# 30                             INSTAL_PAYMENT_DIFF_SUM
# 31                            INSTAL_PAYMENT_DIFF_MEAN
# 32                                      INSTAL_DBD_SUM
# 33                       INSTAL_DAYS_ENTRY_PAYMENT_SUM
# 34                              INSTAL_AMT_PAYMENT_MIN
# 35                                        EXT_SOURCE_2
# 36                              DAYS_LAST_PHONE_CHANGE
# 37                                     DAYS_ID_PUBLISH
# 38                                  DAYS_EMPLOYED_PERC
# 39                                          DAYS_BIRTH
# 40                      CLOSED_DAYS_CREDIT_UPDATE_MEAN
# 41                              CLOSED_DAYS_CREDIT_MIN
# 42                              CLOSED_DAYS_CREDIT_MAX
# 43                      CLOSED_DAYS_CREDIT_ENDDATE_MIN
# 44                             BURO_STATUS_1_MEAN_MEAN
# 45                        BURO_DAYS_CREDIT_UPDATE_MEAN
# 46                        BURO_DAYS_CREDIT_ENDDATE_MIN
# 47                      BURO_CREDIT_ACTIVE_Closed_MEAN
# 48                      BURO_CREDIT_ACTIVE_Active_MEAN
# 49                     APPROVED_RATE_DOWN_PAYMENT_MEAN
# 50                      APPROVED_RATE_DOWN_PAYMENT_MAX
# 51                       APPROVED_AMT_GOODS_PRICE_MEAN
# 52                           APPROVED_AMT_ANNUITY_MEAN
# 53                                     AMT_GOODS_PRICE
# 54                                          AMT_CREDIT
# 55                              ACTIVE_DAYS_CREDIT_VAR
# 56                              ACTIVE_DAYS_CREDIT_MAX
# 57                     ACTIVE_DAYS_CREDIT_ENDDATE_MEAN
# 58                      ACTIVE_DAYS_CREDIT_ENDDATE_MAX
# 59                          ACTIVE_AMT_CREDIT_SUM_MEAN
# 60                        YEARS_BEGINEXPLUATATION_MODE
# 61                        YEARS_BEGINEXPLUATATION_MEDI
# 62                         YEARS_BEGINEXPLUATATION_AVG
# 63                                      TOTALAREA_MODE
# 64                   PREV_NAME_YIELD_GROUP_middle_MEAN
# 65                     PREV_NAME_YIELD_GROUP_high_MEAN
# 66                      PREV_NAME_YIELD_GROUP_XNA_MEAN
# 67                       PREV_NAME_TYPE_SUITE_nan_MEAN
# 68         PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN
# 69                 PREV_NAME_PRODUCT_TYPE_walk-in_MEAN
# 70                        PREV_NAME_PORTFOLIO_XNA_MEAN
# 71   PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN
# 72         PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN
# 73                    PREV_HOUR_APPR_PROCESS_START_MIN
# 74                     PREV_CODE_REJECT_REASON_HC_MEAN
# 75                            PREV_APP_CREDIT_PERC_MIN
# 76                           PREV_AMT_GOODS_PRICE_MEAN
# 77                          PREV_AMT_DOWN_PAYMENT_MEAN
# 78                           PREV_AMT_DOWN_PAYMENT_MAX
# 79                                 PREV_AMT_CREDIT_MAX
# 80                                PREV_AMT_ANNUITY_MIN
# 81              NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MIN
# 82              NEW_RATIO_BURO_DAYS_CREDIT_ENDDATE_MAX
# 83                            NEW_PHONE_TO_BIRTH_RATIO
# 84                                      NEW_INC_BY_ORG
# 85                           NEW_CREDIT_TO_GOODS_RATIO
# 86                                     LIVINGAREA_MODE
# 87                                     LIVINGAREA_MEDI
# 88                                      LIVINGAREA_AVG
# 89                                        LANDAREA_AVG
# 90                             INSTAL_PAYMENT_DIFF_MAX
# 91                                      INSTAL_DPD_MAX
# 92                                     INSTAL_DBD_MEAN
# 93                                      INSTAL_DBD_MAX
# 94                       INSTAL_DAYS_ENTRY_PAYMENT_MAX
# 95                                        INSTAL_COUNT
# 96                              INSTAL_AMT_PAYMENT_SUM
# 97                             INSTAL_AMT_PAYMENT_MEAN
# 98                              INSTAL_AMT_PAYMENT_MAX
# 99                           INSTAL_AMT_INSTALMENT_SUM
# 100                                  DAYS_REGISTRATION
# 101                                      DAYS_EMPLOYED
# 102                     CLOSED_DAYS_CREDIT_ENDDATE_MAX
# 103                         CLOSED_AMT_CREDIT_SUM_MEAN
# 104                          CLOSED_AMT_CREDIT_SUM_MAX
# 105                       CC_CNT_DRAWINGS_CURRENT_MEAN
# 106                     CC_AMT_INST_MIN_REGULARITY_VAR
# 107                    CC_AMT_INST_MIN_REGULARITY_MEAN
# 108                        CC_AMT_DRAWINGS_CURRENT_MAX
# 109                                 CC_AMT_BALANCE_VAR
# 110                                CC_AMT_BALANCE_MEAN
# 111                                 CC_AMT_BALANCE_MAX
# 112                      BURO_MONTHS_BALANCE_SIZE_MEAN
# 113                      BURO_DAYS_CREDIT_ENDDATE_MEAN
# 114                       BURO_DAYS_CREDIT_ENDDATE_MAX
# 115                  BURO_CREDIT_TYPE_Credit card_MEAN
# 116              BURO_CREDIT_TYPE_Consumer credit_MEAN
# 117                           BURO_AMT_CREDIT_SUM_MEAN
# 118                            BURO_AMT_CREDIT_SUM_MAX
# 119                       BURO_AMT_CREDIT_SUM_DEBT_SUM
# 120                      BURO_AMT_CREDIT_SUM_DEBT_MEAN
# 121               APPROVED_HOUR_APPR_PROCESS_START_MIN
# 122              APPROVED_HOUR_APPR_PROCESS_START_MEAN
# 123                         APPROVED_DAYS_DECISION_MAX
# 124                           APPROVED_CNT_PAYMENT_SUM
# 125                       APPROVED_APP_CREDIT_PERC_MIN
# 126                       APPROVED_APP_CREDIT_PERC_MAX
# 127                       APPROVED_AMT_GOODS_PRICE_MAX
# 128                     APPROVED_AMT_DOWN_PAYMENT_MEAN
# 129                      APPROVED_AMT_DOWN_PAYMENT_MAX
# 130                            APPROVED_AMT_CREDIT_MAX
# 131                       APPROVED_AMT_APPLICATION_MIN
# 132                      APPROVED_AMT_APPLICATION_MEAN
# 133                       APPROVED_AMT_APPLICATION_MAX
# 134                                    APARTMENTS_MEDI
# 135                                     APARTMENTS_AVG
# 136                     ACTIVE_DAYS_CREDIT_UPDATE_MEAN
# 137                     ACTIVE_DAYS_CREDIT_ENDDATE_MIN
# 138                          ACTIVE_AMT_CREDIT_SUM_SUM
# 139                 ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 150
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199

# %%
drop_lstm_dataframe_select.to_csv("C:/data/processing_data/dataset/drop_lstm_dataframe_select.csv")

# %%
drop_lstm_data_train = pd.read_csv("C:/data/processing_data/dataset/drop_lstm_data_train.csv")
drop_lstm_data_val = pd.read_csv("C:/data/processing_data/dataset/drop_lstm_data_val.csv")
drop_lstm_data_test = pd.read_csv("C:/data/processing_data/dataset/drop_lstm_data_test.csv")

# %%
drop_lstm_dataframe_select = pd.read_csv("C:/data/processing_data/dataset/drop_lstm_dataframe_select.csv")

# %%
drop_lstm_combination_feature = [name for name in drop_lstm_dataframe_select['combination'].tolist() if len(name) > 2] # >2 过滤掉空字符
drop_lstm_combination_feature.append("TARGET")

# %%
drop_lstm_select_combination_train = drop_lstm_data_train.loc[:, drop_lstm_combination_feature]
drop_lstm_select_combination_train
# Out:
#         PREV_DAYS_DECISION_MEAN  PREV_CODE_REJECT_REASON_XAP_MEAN  \
# 0                        -720.5                            1.0000
# 1                        -945.0                            0.8000
# 2                       -1260.0                            1.0000
# 3                        -499.0                            0.8570
# 4                       -1557.0                            0.8570
# ...                         ...                               ...
# 246004                  -1578.0                            1.0000
# 246005                  -1304.0                            0.7856
# 246006                      0.0                            0.0000
# 246007                      0.0                            0.0000
# 246008                   -301.8                            0.5835
#
#         PREV_CNT_PAYMENT_SUM  PREV_CNT_PAYMENT_MEAN  POS_MONTHS_BALANCE_SIZE  \
# 0                       18.0                 18.000                     19.0
# 1                      120.0                 30.000                     45.0
# 2                      116.0                 14.500                    108.0
# 3                       10.0                  5.000                     11.0
# 4                       70.0                 11.664                     63.0
# ...                      ...                    ...                      ...
# 246004                  22.0                  7.332                     22.0
# 246005                 352.0                 25.140                    163.0
# 246006                   0.0                  0.000                      0.0
# 246007                   0.0                  0.000                      0.0
# 246008                  94.0                 13.430                     33.0
#
#         POS_MONTHS_BALANCE_MEAN  POS_COUNT  INSTAL_DAYS_ENTRY_PAYMENT_MEAN  \
# 0                        -38.00       19.0                         -1123.0
# 1                        -46.50       45.0                         -1481.0
# 2                        -34.66      108.0                         -1038.0
# 3                         -7.00       11.0                          -236.4
# 4                        -48.66       63.0                         -1439.0
# ...                         ...        ...                             ...
# 246004                   -59.50       22.0                         -1445.0
# 246005                   -31.40      163.0                          -964.0
# 246006                     0.00        0.0                             0.0
# 246007                     0.00        0.0                             0.0
# 246008                    -8.61       33.0                          -235.6
#
#         CLOSED_DAYS_CREDIT_VAR  CLOSED_DAYS_CREDIT_MEAN  ...  \
# 0                        0.000                      0.0  ...
# 1                   236306.250                  -1360.0  ...
# 2                        0.000                  -1153.0  ...
# 3                   308582.280                  -1474.0  ...
# 4                        0.000                      0.0  ...
# ...                        ...                      ...  ...
# 246004             1448700.600                  -1458.0  ...
# 246005                   0.000                   -128.0  ...
# 246006              107654.914                  -1733.0  ...
# 246007              427754.500                  -1122.0  ...
# 246008                   0.000                      0.0  ...
#
#         APPROVED_AMT_APPLICATION_MIN  APPROVED_AMT_APPLICATION_MEAN  \
# 0                            80995.5                      80995.500
# 1                            18724.5                      97741.500
# 2                            25380.0                     119352.375
# 3                            95373.0                     385186.500
# 4                            44955.0                     155761.200
# ...                              ...                            ...
# 246004                           0.0                      76708.500
# 246005                       51668.1                     189968.280
# 246006                           0.0                          0.000
# 246007                           0.0                          0.000
# 246008                       45000.0                      69477.300
#
#         APPROVED_AMT_APPLICATION_MAX  APARTMENTS_MEDI  APARTMENTS_AVG  \
# 0                            80995.5          1.36000         1.35200
# 1                           225000.0         -0.01892        -0.02235
# 2                           229500.0          0.68160         0.67530
# 3                           675000.0          1.64100         1.63000
# 4                           337500.0         -0.60100        -0.60250
# ...                              ...              ...             ...
# 246004                      180000.0         -0.60100        -0.60250
# 246005                      381226.6         -0.60100        -0.60250
# 246006                           0.0         -0.57900        -0.58060
# 246007                           0.0         -0.60100        -0.60250
# 246008                      113692.5         -0.60100        -0.60250
#
#         ACTIVE_DAYS_CREDIT_UPDATE_MEAN  ACTIVE_DAYS_CREDIT_ENDDATE_MIN  \
# 0                                 0.00                             0.0
# 1                              -258.00                          -842.0
# 2                               -28.00                          1007.0
# 3                               -24.00                           493.0
# 4                                 0.00                             0.0
# ...                                ...                             ...
# 246004                          -67.00                           897.0
# 246005                          -17.00                           642.0
# 246006                          -28.00                          1048.0
# 246007                          -38.66                           880.0
# 246008                          -23.00                           612.0
#
#         ACTIVE_AMT_CREDIT_SUM_SUM  ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN  TARGET
# 0                             0.0                               0.000       0
# 1                        370350.0                               0.000       0
# 2                       1146685.2                            2327.085       0
# 3                        396765.0                               0.000       0
# 4                             0.0                               0.000       0
# ...                           ...                                 ...     ...
# 246004                  3995595.0                               0.000       0
# 246005                   450000.0                               0.000       0
# 246006                   450000.0                               0.000       0
# 246007                   270000.0                               0.000       0
# 246008                   179073.0                               0.000       1
#
# [246009 rows x 141 columns]

# %%
drop_lstm_select_combination_val = drop_lstm_data_val.loc[:, drop_lstm_combination_feature]

# %%
drop_lstm_select_combination_test = drop_lstm_data_test.loc[:, drop_lstm_combination_feature]

# %%
drop_lstm_select_combination_train_X = drop_lstm_select_combination_train.drop(["TARGET"], axis = 1)
drop_lstm_select_combination_train_y = drop_lstm_select_combination_train["TARGET"]
drop_lstm_select_combination_train_X.shape
# Out:
# (246009, 140)

# %%
import imblearn
from imblearn.combine import SMOTETomek
start = time.time()
smt = SMOTETomek()
smt.fit(drop_lstm_select_combination_train_X, drop_lstm_select_combination_train_y)
X_train_drop_lstm_resample, y_train__drop_lstm_resample = smt.fit_resample(drop_lstm_select_combination_train_X, drop_lstm_select_combination_train_y)
end = time.time()
print("综合采样时间：", end-start)
# Out:
# 综合采样时间：8327.239233732223511

# %%
drop_lstm_resample_data = pd.concat([X_train_drop_lstm_resample, y_train__drop_lstm_resample], axis = 1)
drop_lstm_resample_data.to_csv("C:/data/processing_data/dataset/drop_lstm_train_resample.csv")

# %%
import gc
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
import lightgbm as lgb
from sklearn.metrics import f1_score,precision_score,recall_score,roc_auc_score,accuracy_score,roc_curve, plot_roc_curve
from sklearn import metrics
def val_lightgbm(train, val):
    
    print("Starting LightGBM. Train shape: {}, val shape: {}".format(train.shape, val.shape))
    feats = [f for f in train.columns if f not in ['TARGET','SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV','index']]
    
    
    gbm = lgb.LGBMClassifier(
            boosting_type='gbdt',
            num_leaves=106,
            max_depth=-1,
            learning_rate=0.012,
            n_estimators= 10000,
            objective='binary',
            class_weight=None,
            min_split_gain=0.0,
            min_child_weight=0.001,
            min_child_samples=390,
            subsample=0.717756,
            subsample_freq=1,
            colsample_bytree=0.614937,
            reg_alpha=0.512999,
            reg_lambda=0.382687,
            subsample_for_bin=80000,
            random_state=42,
            n_jobs=-1
        )
    X_train = train[feats].to_numpy()
    y_train = train['TARGET'].values  
    X_val = val[feats].to_numpy()                   
    y_val = val['TARGET'].values 
        
    gbm.fit(X_train,y_train)
    gbm_y_pre_train = gbm.predict(X_train)
    gbm_y_pre= gbm.predict(X_val)
    gbm_y_proba_train = gbm.predict_proba(X_train)
    gbm_y_proba= gbm.predict_proba(X_val)
    fpr,tpr,thresholds = roc_curve(y_val,gbm_y_proba[:,1])
    ks = max(tpr-fpr)
    
    print("==============================train==================================")
    gbm_accuracy_score_train = accuracy_score(y_train,gbm_y_pre_train)
    
    gbm_auc_train = roc_auc_score(y_train,gbm_y_proba_train[:,1])
    
    print('gbm_accuracy_score: %f,\ngbm_auc: %f'
          %(gbm_accuracy_score_train,
            gbm_auc_train))
    
    print("---------------------------------val---------------------------------")
    gbm_accuracy_score= accuracy_score(y_val,gbm_y_pre)
  
    gbm_auc = roc_auc_score(y_val,gbm_y_proba[:,1])
    print('gbm_accuracy_score: %f,\ngbm_auc: %f,\ngbm_ks:%f'
          %(gbm_accuracy_score,
        
    
            gbm_auc,
            ks))
    print("======================================================================")
    importance_df = pd.DataFrame()              
    importance_df["feature"] = feats
    importance_df["importance"] = gbm.feature_importances_
    
    
    return gbm,importance_df

def display_importances(feature_importance_df_):
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False)[:40].index
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    plt.figure(figsize=(8, 10))
    sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout

# %%
start = time.time()
gbm, feature_imp = val_lightgbm(drop_lstm_resample_data,drop_lstm_select_combination_val)
end = time.time()
print("训练时间：", end -start)
# Out:
# Starting LightGBM. Train shape: (452198, 141), val shape: (30751, 141)
# ==============================train==================================
# gbm_accuracy_score: 0.998910,
# gbm_auc: 1.000000
# ---------------------------------val---------------------------------
# gbm_accuracy_score: 0.918929,
# gbm_auc: 0.764486,
# gbm_ks:0.396506
# ======================================================================
# 训练时间： 939.7994265556335

# %%
def lightgbm_test(gbm, test):
    feats = [f for f in test.columns if f not in ['TARGET','SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV','index']] # 固定列了

    gbm_y_pre = gbm.predict(test[feats].to_numpy())
    gbm_y_proba= gbm.predict_proba(test[feats])  # 验证训练模型没有这个'Booster' object has no attribute 'predict_proba'属性
    fpr,tpr,thresholds = roc_curve(test["TARGET"],gbm_y_proba[:,1])
    ks = max(tpr-fpr)


    gbm_accuracy_score=accuracy_score(test["TARGET"],gbm_y_pre)

    gbm_auc=roc_auc_score(test["TARGET"],gbm_y_proba[:,1])
    print('gbm_accuracy_score: %f,\ngbm_auc: %f,\ngbm_ks:%f'
          %(gbm_accuracy_score,
            gbm_auc,
            ks))

# %%
lightgbm_test(gbm, drop_lstm_select_combination_test)
# Out:
# gbm_accuracy_score: 0.921076,
# gbm_auc: 0.752975,
# gbm_ks:0.374338

# %%
import joblib
joblib.dump(gbm, 'C:/data/processing_data/dataset/drop_lstm_data_modle.pkl')
# Out:
# ['C:/data/processing_data/dataset/drop_lstm_data_modle.pkl']

# %% [markdown]
# # 去掉特征选择部分

# %%
import time
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

def reduce_mem_usage(data, verbose = True):
    start_mem = data.memory_usage().sum() / 1024**2
    if verbose:
        print('Memory usage of dataframe: {:.2f} MB'.format(start_mem))
    
    for col in data.columns:
        col_type = data[col].dtype
        
        if col_type != object:
            c_min = data[col].min()
            c_max = data[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    data[col] = data[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    data[col] = data[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    data[col] = data[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    data[col] = data[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    data[col] = data[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    data[col] = data[col].astype(np.float32)
                else:
                    data[col] = data[col].astype(np.float64)

    end_mem = data.memory_usage().sum() / 1024**2
    if verbose:
        print('Memory usage after optimization: {:.2f} MB'.format(end_mem))
        print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return data

# %%
all_data = pd.read_csv("C:/data/processing_data/all_data.csv")
all_data = reduce_mem_usage(all_data)
# Out:
# Memory usage of dataframe: 1081.56 MB
# Memory usage after optimization: 340.48 MB
# Decreased by 68.5%

# %%
all_data.shape
# Out:
# (307511, 461)

# %%
def split_train(data,test_ratio):
   #  data = data.iloc[0:20000,:]
    np.random.seed(0)  # 设置随机种子确保实验可重复
    shuffled_indices=np.random.permutation(len(data)) # 随机片
    test_set_size=int(len(data)*test_ratio)
    test_indices =shuffled_indices[:test_set_size]
    train_indices=shuffled_indices[test_set_size:]
    return data.iloc[train_indices],data.iloc[test_indices]

# %%
no_select_all_data_train, no_select_all_data_valtest = split_train(all_data, 0.2)
no_select_all_data_val,no_select_all_data_test = split_train( no_select_all_data_valtest, 0.5)
no_select_all_data_train.to_csv("C:/data/processing_data/dataset/no_select_all_data_train.csv")
no_select_all_data_val.to_csv("C:/data/processing_data/dataset/no_select_all_data_val.csv")
no_select_all_data_test.to_csv("C:/data/processing_data/dataset/no_select_all_data_test.csv")

# %%
no_select_all_data_train_X = no_select_all_data_train.drop(["TARGET"], axis = 1)
no_select_all_data_train_y = no_select_all_data_train["TARGET"]
no_select_all_data_train_X.shape
# Out:
# (246009, 460)

# %%
import imblearn
from imblearn.combine import SMOTETomek
start = time.time()
smt = SMOTETomek()
smt.fit(no_select_all_data_train_X, no_select_all_data_train_y)
X_train_drop_lstm_resample, y_train__drop_lstm_resample = smt.fit_resample(no_select_all_data_train_X, no_select_all_data_train_y)
end = time.time()
print("综合采样时间：", end-start)
# Out:
# 综合采样时间：14314.96342658996582

# %%
no_select_all_data_resample_data = pd.concat([X_train_drop_lstm_resample, y_train__drop_lstm_resample], axis = 1)
no_select_all_data_resample_data.to_csv("C:/data/processing_data/dataset/no_select_all_data_train_resample.csv")

# %%
import gc
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
import lightgbm as lgb
from sklearn.metrics import f1_score,precision_score,recall_score,roc_auc_score,accuracy_score,roc_curve, plot_roc_curve
from sklearn import metrics
def val_lightgbm(train, val):
    
    print("Starting LightGBM. Train shape: {}, val shape: {}".format(train.shape, val.shape))
    feats = [f for f in train.columns if f not in ['TARGET','SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV','index']]
    
    
    gbm = lgb.LGBMClassifier(
            boosting_type='gbdt',
            num_leaves=106,
            max_depth=-1,
            learning_rate=0.012,
            n_estimators= 10000,
            objective='binary',
            class_weight=None,
            min_split_gain=0.0,
            min_child_weight=0.001,
            min_child_samples=390,
            subsample=0.717756,
            subsample_freq=1,
            colsample_bytree=0.614937,
            reg_alpha=0.512999,
            reg_lambda=0.382687,
            subsample_for_bin=80000,
            random_state=42,
            n_jobs=-1
        )
    X_train = train[feats].to_numpy()
    y_train = train['TARGET'].values  
    X_val = val[feats].to_numpy()                   
    y_val = val['TARGET'].values 
        
    gbm.fit(X_train,y_train)
    gbm_y_pre_train = gbm.predict(X_train)
    gbm_y_pre= gbm.predict(X_val)
    gbm_y_proba_train = gbm.predict_proba(X_train)
    gbm_y_proba= gbm.predict_proba(X_val)
    fpr,tpr,thresholds = roc_curve(y_val,gbm_y_proba[:,1])
    ks = max(tpr-fpr)
    
    print("==============================train==================================")
    gbm_accuracy_score_train = accuracy_score(y_train,gbm_y_pre_train)
    
    gbm_auc_train = roc_auc_score(y_train,gbm_y_proba_train[:,1])
    
    print('gbm_accuracy_score: %f,\ngbm_auc: %f'
          %(gbm_accuracy_score_train,
            gbm_auc_train))
    
    print("---------------------------------val---------------------------------")
    gbm_accuracy_score= accuracy_score(y_val,gbm_y_pre)
  
    gbm_auc = roc_auc_score(y_val,gbm_y_proba[:,1])
    print('gbm_accuracy_score: %f,\ngbm_auc: %f,\ngbm_ks:%f'
          %(gbm_accuracy_score,
        
    
            gbm_auc,
            ks))
    print("======================================================================")
    importance_df = pd.DataFrame()              
    importance_df["feature"] = feats
    importance_df["importance"] = gbm.feature_importances_
    
    
    return gbm,importance_df

def display_importances(feature_importance_df_):
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False)[:40].index
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    plt.figure(figsize=(8, 10))
    sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout

# %%
start = time.time()
gbm, feature_imp = val_lightgbm(no_select_all_data_resample_data,no_select_all_data_val)
end = time.time()
print("训练时间：", end -start)
# Out:
# Starting LightGBM. Train shape: (452456, 461), val shape: (30751, 461)
# ==============================train==================================
# gbm_accuracy_score: 0.999976,
# gbm_auc: 1.000000
# ---------------------------------val---------------------------------
# gbm_accuracy_score: 0.919125,
# gbm_auc: 0.788814,
# gbm_ks:0.428678
# ======================================================================
# 训练时间： 1993.1008563041687

# %%
def lightgbm_test(gbm, test):
    feats = [f for f in test.columns if f not in ['TARGET','SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV','index']] # 固定列了

    gbm_y_pre = gbm.predict(test[feats].to_numpy())
    gbm_y_proba= gbm.predict_proba(test[feats])  # 验证训练模型没有这个'Booster' object has no attribute 'predict_proba'属性
    fpr,tpr,thresholds = roc_curve(test["TARGET"],gbm_y_proba[:,1])
    ks = max(tpr-fpr)


    gbm_accuracy_score=accuracy_score(test["TARGET"],gbm_y_pre)

    gbm_auc=roc_auc_score(test["TARGET"],gbm_y_proba[:,1])
    print('gbm_accuracy_score: %f,\ngbm_auc: %f,\ngbm_ks:%f'
          %(gbm_accuracy_score,
            gbm_auc,
            ks))

# %%
lightgbm_test(gbm, no_select_all_data_test)
# Out:
# gbm_accuracy_score: 0.918507,
# gbm_auc: 0.785006,
# gbm_ks:0.428309

# %%
import joblib
joblib.dump(gbm, 'C:/data/processing_data/dataset/no_select_all_data_modle.pkl')
# Out:
# ['C:/data/processing_data/dataset/no_select_all_data_modle.pkl']

# %% [markdown]
# # 去掉两个部分

# %%
import time
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")
def reduce_mem_usage(data, verbose = True):
    start_mem = data.memory_usage().sum() / 1024**2
    if verbose:
        print('Memory usage of dataframe: {:.2f} MB'.format(start_mem))
    
    for col in data.columns:
        col_type = data[col].dtype
        
        if col_type != object:
            c_min = data[col].min()
            c_max = data[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    data[col] = data[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    data[col] = data[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    data[col] = data[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    data[col] = data[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    data[col] = data[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    data[col] = data[col].astype(np.float32)
                else:
                    data[col] = data[col].astype(np.float64)

    end_mem = data.memory_usage().sum() / 1024**2
    if verbose:
        print('Memory usage after optimization: {:.2f} MB'.format(end_mem))
        print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return data

def split_train(data,test_ratio):
   #  data = data.iloc[0:20000,:]
    np.random.seed(0)  # 设置随机种子确保实验可重复
    shuffled_indices=np.random.permutation(len(data)) # 随机片
    test_set_size=int(len(data)*test_ratio)
    test_indices =shuffled_indices[:test_set_size]
    train_indices=shuffled_indices[test_set_size:]
    return data.iloc[train_indices],data.iloc[test_indices]

# %%
all_data = pd.read_csv("C:/data/processing_data/all_data.csv")
all_data = reduce_mem_usage(all_data)
# Out:
# Memory usage of dataframe: 1081.56 MB
# Memory usage after optimization: 340.48 MB
# Decreased by 68.5%

# %%
columns = all_data.columns.tolist()

# %%
droplist = [i for i in columns if "LSTM_" in i]

# %%
drop_lstm_data = all_data.drop(columns = droplist, axis = 1)

# %%
drop_lstm_data.shape
# Out:
# (307511, 445)

# %%
drop_lstm_data_train, drop_lstm_data_valtest = split_train(drop_lstm_data, 0.2)
drop_lstm_data_val,drop_lstm_data_test = split_train(drop_lstm_data_valtest, 0.5)

# %%
drop_lstm_train_X = drop_lstm_data_train.drop(["TARGET"], axis = 1)
drop_lstm_train_y = drop_lstm_data_train["TARGET"]
drop_lstm_train_X.shape
# Out:
# (246009, 444)

# %%
import imblearn
from imblearn.combine import SMOTETomek
start = time.time()
smt = SMOTE()
smt.fit(drop_lstm_train_X, drop_lstm_train_y)
X_train_drop_lstm_resample, y_train__drop_lstm_resample = smt.fit_resample(drop_lstm_train_X, drop_lstm_train_y)
end = time.time()
print("综合采样时间：", end-start)
# Out:
# 综合采样时间：12215.759775400161743

# %%
# drop_lstm_resample_data = pd.concat([X_train_drop_lstm_resample, y_train__drop_lstm_resample], axis = 1)
# drop_lstm_resample_data.to_csv("C:/data/processing_data/dataset/drop_lstm_no_select_train_resample.csv")

# %%
import gc
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
import lightgbm as lgb
from sklearn.metrics import f1_score,precision_score,recall_score,roc_auc_score,accuracy_score,roc_curve, plot_roc_curve
from sklearn import metrics
def val_lightgbm(train, val):
    
    print("Starting LightGBM. Train shape: {}, val shape: {}".format(train.shape, val.shape))
    feats = [f for f in train.columns if f not in ['TARGET','SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV','index']]
    
    
    gbm = lgb.LGBMClassifier(
            boosting_type='gbdt',
            num_leaves=106,
            max_depth=-1,
            learning_rate=0.012,
            n_estimators= 10000,
            objective='binary',
            class_weight=None,
            min_split_gain=0.0,
            min_child_weight=0.001,
            min_child_samples=390,
            subsample=0.717756,
            subsample_freq=1,
            colsample_bytree=0.614937,
            reg_alpha=0.512999,
            reg_lambda=0.382687,
            subsample_for_bin=80000,
            random_state=42,
            n_jobs=-1
        )
    X_train = train[feats].to_numpy()
    y_train = train['TARGET'].values  
    X_val = val[feats].to_numpy()                   
    y_val = val['TARGET'].values 
        
    gbm.fit(X_train,y_train)
    gbm_y_pre_train = gbm.predict(X_train)
    gbm_y_pre= gbm.predict(X_val)
    gbm_y_proba_train = gbm.predict_proba(X_train)
    gbm_y_proba= gbm.predict_proba(X_val)
    fpr,tpr,thresholds = roc_curve(y_val,gbm_y_proba[:,1])
    ks = max(tpr-fpr)
    
    print("==============================train==================================")
    gbm_accuracy_score_train = accuracy_score(y_train,gbm_y_pre_train)
    
    gbm_auc_train = roc_auc_score(y_train,gbm_y_proba_train[:,1])
    
    print('gbm_accuracy_score: %f,\ngbm_auc: %f'
          %(gbm_accuracy_score_train,
            gbm_auc_train))
    
    print("---------------------------------val---------------------------------")
    gbm_accuracy_score= accuracy_score(y_val,gbm_y_pre)
  
    gbm_auc = roc_auc_score(y_val,gbm_y_proba[:,1])
    print('gbm_accuracy_score: %f,\ngbm_auc: %f,\ngbm_ks:%f'
          %(gbm_accuracy_score,
        
    
            gbm_auc,
            ks))
    print("======================================================================")
    importance_df = pd.DataFrame()              
    importance_df["feature"] = feats
    importance_df["importance"] = gbm.feature_importances_
    
    
    return gbm,importance_df

def display_importances(feature_importance_df_):
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False)[:40].index
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    plt.figure(figsize=(8, 10))
    sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout

# %%
start = time.time()
gbm, feature_imp = val_lightgbm(drop_lstm_resample_data,drop_lstm_data_val)
end = time.time()
print("训练时间：", end -start)
# Out:
# Starting LightGBM. Train shape: (452076, 445), val shape: (30751, 445)
# ==============================train==================================
# gbm_accuracy_score:0.957069,
# gbm_auc: 0.986956
# ---------------------------------val---------------------------------
# gbm_accuracy_score: 0.921141,
# gbm_auc: 0.752374,
# gbm_ks:0.360665
# ======================================================================
# 训练时间： 2026.3907496929169

# %%
# drop_lstm_resample_data.to_csv("C:/data/processing_data/dataset/no_select_no_lstm_data_train.csv")

# %%
# drop_lstm_data_val.to_csv("C:/data/processing_data/dataset/no_select_no_lstm_data_val.csv")

# %%
# drop_lstm_data_test.to_csv("C:/data/processing_data/dataset/no_select_no_lstm_data_test.csv")

# %%
def lightgbm_test(gbm, test):
    feats = [f for f in test.columns if f not in ['TARGET','SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV','index']] # 固定列了

    gbm_y_pre = gbm.predict(test[feats].to_numpy())
    gbm_y_proba= gbm.predict_proba(test[feats])  # 验证训练模型没有这个'Booster' object has no attribute 'predict_proba'属性
    fpr,tpr,thresholds = roc_curve(test["TARGET"],gbm_y_proba[:,1])
    ks = max(tpr-fpr)


    gbm_accuracy_score=accuracy_score(test["TARGET"],gbm_y_pre)

    gbm_auc=roc_auc_score(test["TARGET"],gbm_y_proba[:,1])
    print('gbm_accuracy_score: %f,\ngbm_auc: %f,\ngbm_ks:%f'
          %(gbm_accuracy_score,
            gbm_auc,
            ks))

# %%
start = time.time()
lightgbm_test(gbm, drop_lstm_data_test)
end = time.time()
# Out:
# gbm_accuracy_score: 0.919124,
# gbm_auc: 0.741755,
# gbm_ks:0.356715

# %%
# feature_imp.sort_values(by="importance" , inplace=True, ascending=False)

# %% [markdown]
# # 一个用户需要花费多长时间

# %%
import joblib
import pandas as pd
gbm = joblib.load('C:/data/processing_data/dataset/drop_lstm_data_modle.pkl')

# %%
def lightgbm_test(gbm, test):
    feats = [f for f in test.columns if f not in ['TARGET','SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV','index']] # 固定列了

    gbm_y_pre = gbm.predict(test[feats].to_numpy())
    gbm_y_proba= gbm.predict_proba(test[feats])  # 验证训练模型没有这个'Booster' object has no attribute 'predict_proba'属性
    fpr,tpr,thresholds = roc_curve(test["TARGET"],gbm_y_proba[:,1])
    ks = max(tpr-fpr)


    gbm_accuracy_score=accuracy_score(test["TARGET"],gbm_y_pre)

    gbm_auc=roc_auc_score(test["TARGET"],gbm_y_proba[:,1])
    print('gbm_accuracy_score: %f,\ngbm_auc: %f,\ngbm_ks:%f'
          %(gbm_accuracy_score,
            gbm_auc,
            ks))

# %%
drop_lstm_data_test = pd.read_csv("C:/data/processing_data/dataset/drop_lstm_data_test.csv")

# %%
drop_lstm_dataframe_select = pd.read_csv("C:/data/processing_data/dataset/drop_lstm_dataframe_select.csv")
drop_lstm_combination_feature = [name for name in drop_lstm_dataframe_select['combination'].tolist() if len(name) > 2] # >2 过滤掉空字符
drop_lstm_combination_feature.append("TARGET")
drop_lstm_select_combination_test = drop_lstm_data_test.loc[:, drop_lstm_combination_feature]

# %%
drop_lstm_select_combination_test .shape
# Out:
# (30751, 141)

# %%
import time
import gc
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
import lightgbm as lgb
from sklearn.metrics import f1_score,precision_score,recall_score,roc_auc_score,accuracy_score,roc_curve, plot_roc_curve
from sklearn import metrics
start = time.time()
lightgbm_test(gbm, drop_lstm_select_combination_test)
end = time.time()
# Out:
# gbm_accuracy_score: 0.921076,
# gbm_auc: 0.752975,
# gbm_ks:0.374338

# %%
print(end - start)
# Out:
# 17.87284207344055

# %%
17.87284207344055/30751
# Out:
# 0.0005812117353400069

# %% [markdown]
# # 特征选择花费的时间

# %%
import pandas as pd

# %%
drop_lstm_data_train = pd.read_csv("C:/data/processing_data/dataset/drop_lstm_data_train.csv")
drop_lstm_data_val = pd.read_csv("C:/data/processing_data/dataset/drop_lstm_data_val.csv")
drop_lstm_data_test = pd.read_csv("C:/data/processing_data/dataset/drop_lstm_data_test.csv")

# %%
drop_lstm_select_combination_train_X = drop_lstm_data_train.drop(["TARGET"], axis = 1)
drop_lstm_select_combination_train_y = drop_lstm_data_train["TARGET"]
drop_lstm_select_combination_train_X.shape
# Out:
# (246009, 445)

# %%
import imblearn
import time
from imblearn.combine import SMOTETomek
start = time.time()
smt = SMOTETomek()
smt.fit(drop_lstm_select_combination_train_X, drop_lstm_select_combination_train_y)
X_train_drop_lstm_resample, y_train__drop_lstm_resample = smt.fit_resample(drop_lstm_select_combination_train_X, drop_lstm_select_combination_train_y)
end = time.time()
print("综合采样时间：", end-start)
# Out:
# 综合采样时间： 3988.7160544395447
